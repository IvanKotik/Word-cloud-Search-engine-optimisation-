# %%
import PyPDF2
import re
import requests
# import urllib.request
# import numpy as np
import pandas as pd
from itertools import combinations 
from itertools import permutations
from itertools import chain

# %%
id_pdf = "id-0001"

# %%
def download_pdf(url, file_name, headers):
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        with open(file_name, "wb") as f:
            f.write(response.content)
    else:
        print(response.status_code)

# %%
if __name__ == "__main__":
    # Define HTTP Headers
    headers = {
        "User-Agent": "Chrome/51.0.2704.103"
    }
    # Define URL
    url = "https://quantinar.s3.eu-west-3.amazonaws.com/" \
          "courselet_components%2F214%2F1649337741164476519520220205+" \
          "SFE+Slides+Chapter+2.1+The+Basics+of+Option+Management.pdf"
    # Define image file name
    file_name = "{}.pdf".format(id_pdf)
    # Download image
    download_pdf(url, file_name, headers)

# %%
imported_pdf = open(file_name, 'rb')
transformed_pdf = PyPDF2.PdfFileReader(imported_pdf)
totalpages = transformed_pdf.numPages
pdf_output = [transformed_pdf.getPage(i) for i in range(totalpages)]
pdf_output = [pdf_output[i].extractText() for i in range(totalpages)]
pdf_output
# Out:
# ['Ladislaus von Bortkiewicz Professor of Statistics Humboldt-Universität zu Berlin BRC Blockchain Research Center lvb.wiwi.hu-berlin.de Charles University, WISE XMU, NYCU ⽟⼭學者 Jürgen Franke  Wolfgang Härdle Christian Hafner  Statistics of Financial Markets\n20220205 SFE Slides Chapter 2 The Basics of Option Management.key',
#  'Chapter 2:  The Basics of Option Management ',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000YArbitrage Theory\n3\n⊡buy and sell an asset on different stock markets for different prices  ⊡two portfolios with the same current value, same maturity, but different values at maturity ArbitrageArbitrage exists if there is a trading strategy which produces a riskless proﬁt with non zero probability. Example',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n4Consider two portfolios  and  with current value  and , respectively. Suppose that for some  the terminal value  , and that for some : ABWA(t)WB(t)TWA(T)=WB(T)t<TBy short selling  and buying , and investing the difference BAinto a savings account with interest , the investor does not invest proprietary capital. rArbitrage StrategyWA(t)/uni2264WB(t)/uni0394(t)=WB(t)−WA(t)/uni22650',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n5However, in  there will be risk-less proﬁt of: THe even could be inﬁnitely rich!!This violates the principle of no arbitrage, and thus it must hold: WA(T)−WB(T)+/uni0394(T)=/uni0394(t)er(T−t)>0WA(t)=WB(t),\xa0for\xa0all\xa0t',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n6Basic assumption for the remainder: No Arbitrage i.e., prices of derivatives must not permit arbitrage.',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000YPerfect Financial Market\n7⊡debit interest rate = credit interest rate  ⊡no transaction costs  ⊡no taxes  ⊡short-selling is allowed  ⊡stocks are unlimitedly divisible  ⊡no arbitrage ',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n8Price of a forward contract KTStVK,T(St,/uni03C4)Delivery price: Maturity date: Underlying price: Price at time t:',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n9Proposition 2.1 Under the assumption of a perfect market and the additional assumption of a constant interest rate  during the time interval  the following holds:r/uni03C4=T−t1.With no dividend payments or costs of carry, we have and .Ft=Ster/uni03C4V(St,/uni03C4)=VK,T(St,/uni03C4)=St−Ke−r/uni03C4',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n102.If  is the value of all earnings and costs related to the underlying during the time period  calculated at time t, we have:Dt/uni03C4and . Ft=(St−Dt)er/uni03C43.If we have continuous costs of carry, b, then the value of the forward contract at time t is:and . Ft=Steb/uni03C4V(St,/uni03C4)=VK,T(St,/uni03C4)=St−Dt−Ke−r/uni03C4V(St,/uni03C4)=VK,T(St,/uni03C4)=Ste(b−r)/uni03C4−Ke−r/uni03C4',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n11Proof:  [case 1] There are no dividend payments. Portfolio A a long position in a forward contract with strike , maturity date  and a long position in a zero bond with nominal value  and expiration . KTKT\nPortfolio A = Portfolio B VK,T(St,/uni03C4)+Ke−r/uni03C4=St(2.1)andPortfolio B a long position in the asset. Both portfolios have the same value  at time , and hence by no arbitrage must have the same value at time , STTt',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n12We have to show that : VFt,T(/uni22C5)=0Inserting  in  for  yields: FT=Stet/uni03C4(2.1)KThus,  and hence .  VFt,T(St,/uni03C4)+Ste−r/uni03C4er/uni03C4=StVFt,/uni03C4(St,/uni03C4)=0VFt,T(St,/uni03C4)+Fte−r/uni03C4=St',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n13[cases 2 and 3] Assume the asset pays discrete dividends . DtPortfolio B a long position in the asset and a short position in a zerobond with current value  at time  and expiration date . DttTBoth portfolios have the same value  at time , and hence by no arbitrage must have the same value at time ,  STTtPortfolio A = Portfolio B Portfolio A a long position in a forward contract with strike , maturity date  and a long position in a zerobond with nominal value  and expiration .KTKTVK,T(St,/uni03C4)+Ke−r/uni03C4=St−Dt(2.2)and',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n14We have to show that :VFt,T(/uni22C5)=0VFt,T(St,/uni03C4)+Fte−r/uni03C4=StThus,  and hence .VFt,T(St,/uni03C4)+Ste−r/uni03C4er/uni03C4=StVFt,T(St,/uni03C4)=0Inserting  in  for  yields: Ft=Stet/uni03C4(2.1)Klink (press Z to return to this page)',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n15If we have continuous dividend payment  we change portfolio B to Portfolio B, buy  shares of the asset and reinvest all dividend payments in the asset.de(b−r)/uni03C4=e−d/uni03C4The result follows by similar arguments as in the discrete dividend case.Again for  we have .Ft=Steb/uni03C4VK,T(St,/uni03C4)=0VK,T(St,/uni03C4)+Ke−r/uni03C4=e−d/uni03C4St',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n16Example: Forward contract with discrete dividendsCoupon payments of  in  and  months from now Continuous interest rate for   months:606126(12)We have for     :and the value of the forward contract is: The forward price  is .FtFt=(St−Dt)er/uni03C4=871.26Dt=60e−0.09/uni22C512+60e−0.10=111.65(2.3)VK,T(St,/uni03C4)=900−111.65−910e−0.10=−35.05(2.4)Consider a forward contract on a ﬁve-year bond with:Bond price at time : Delivery price: Time to maturity:tSt=900K=910/uni03C4=T−t=1\xa0year,   r6=9%r12=10%Dt',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n17Example: Forward contract with continuous dividends\nThen the forward price is . For  we have a premium  if  a discount . If  and  then .Ft=Steb/uni03C4=Ste(r−d)/uni03C4r>dSt<Ftr<dSt>Ftr>dK=StVSt,T=St(e−d/uni03C4−e−r/uni03C4)>0The forward contract at delivery price  is more expensive than the spot price, as the investor proﬁts from the higher interest rates in the domestic currency till . StTdr(rA)StAssumeCost of carryDividend yieldDomestic (American) interest raterA=db=r−dUSD exchange rate',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n18Proposition 2.2 If the interest rate is constant during the maturity of the contract, the future and the forward price are equal.Proof: Let  days,  be the forward price at the end of day ,  be the future price at the end of day  and let  be the daily interest rate, at which daily proﬁt loss calculations occur. We consider two portfolios:/uni03C4=NF0Ftt=0,…,N/uni03C1Portfolio A buy  forward contracts and buy a zerobond with nominal value  and with  days to expiration.eN/uni03C1FeN/uni03C1NPortfolio B buy future contracts such that there are  contracts in the portfolio at the end of day  and buy a zerobond with nominal value  and  days to expiration.e(t+1)/uni03C1teN/uni03C1F0N',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n19Portfolio A After day , i.e. at the expiration date, portfolio A contains a total of  zerobonds which are used to fulﬁl the forward contract, i.e. to buy  underlying at the delivery price . Thus the total value of portfolio A at the end of day  is .NFeN/uni03C1eN/uni03C1FNSNeN/uni03C1',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n20Portfolio B Now consider portfolio B with future contracts. The proﬁt-loss calculation of the  futures at the beginning of day  yields . Throughout the day more futures are bought into the portfolio so that at the end of the day a total of  futures are in the portfolio (remember that no cash-ﬂow is triggered by this purchase). The change of the portfolio value has a future value on day  of:et/uni03C1t(Ft−Ft−1)et/uni03C1e(t+1)/uni03C1N(Ft−Ft−1)et/uni03C1/uni22C5e(N−t)/uni03C1=(Ft−Ft−1)eN/uni03C1(2.5)',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n21Since changes in the value of the future are settled every day, the cumulative return on day  is:NN/uni2211t=1(Ft−Ft−1)eN/uni03C1=(FN−F0)eN/uni03C1(2.6)Together with the zerobond it follows that the value of portfolio B at  is , which is exactly . The same holds for portfolio A. Thus assuming no arbitrage the two portfolios must have the same value at day .t=NFN−F0eN/uni03C1+F0eN/uni03C1FNeN/uni03C1=SNeN/uni03C1t=0',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n22As the future and the forward contract have a value of zero at day , only the prices of zerobonds have to be considered.  It follows that:t=00+FeN/uni03C1=0+F0eN/uni03C1F=F0and',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000YOption Pricing\n23Payoff functions The payoff function of a call is   The payoff function of a put is .max(ST−K,\xa00)max(K−ST,\xa00)Intrinsic value Intrinsic value of a call is  Intrinsic value of a put .max(St−K,\xa00)max(K−St,\xa00)',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n24In the money (ITM) An option is called ITM if its intrinsic value is nonzero.At the money (ATM) An option is called ATM if .St/uni2248KOut of the money (OTM) An option is called OTM if its intrinsic value is zero.',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000YElementary Properties of Option Prices\n25⊡option prices are non-negative ⊡the price of a European option at maturity  is equal to the price of an American option at maturity  ⊡the price of an American option is larger or equal than its intrinsic value (this is not true for European options)TT',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n26⊡for two American options  and  differing only by time to maturity, , the following holds:Cam1Cam2T1/uni2264T2CamK,T1(St,T1−t)/uni2264CamK,T2(St,T2−t)PamK,T1(St,T1−t)/uni2264PamK,T2(St,T2−t)Since:CamK,T2(St,T2−T1)/uni2265intrinsic\xa0value\xa0=max(St−K,\xa00)=CamK,T1(St,\xa00)\xa0,\xa0/uni2200t(not true in general for European options)',
#  'SFEThe Basics of Option Management \n01000200030004000X5001000Y\n27⊡the price of an American option is always bigger than or equal to the price of the corresponding European option ⊡call prices are monotone decreasing functions of strike prices ⊡put prices are monotone increasing functions of strike prices']

# %%
pdf_output = [re.sub(pattern = "http[^ ]*", repl = " ", string = pdf_output[i]) for i in range(totalpages)]
pdf_output = [re.sub(pattern = "(\)|\(|,|\.|!|=|:|\[|\]|\{|\}|\'|\"|#|<|>|\%|\&|\?|\*|\/|-|\$|\+|\d)", repl = " ", string = pdf_output[i]) for i in range(totalpages)]
pdf_output = [re.sub(pattern = "\s{2,}", repl = " ", string = pdf_output[i]) for i in range(totalpages)]
pdf_output = [re.sub(pattern = " \w ", repl = " ", string = pdf_output[i]) for i in range(totalpages)]
pdf_output = [re.sub(pattern = " \w ", repl = " ", string = pdf_output[i]) for i in range(totalpages)]
pdf_output
# Out:
# ['Ladislaus von Bortkiewicz Professor of Statistics Humboldt Universität zu Berlin BRC Blockchain Research Center lvb wiwi hu berlin de Charles University WISE XMU NYCU ⽟⼭學者 Jürgen Franke Wolfgang Härdle Christian Hafner Statistics of Financial Markets SFE Slides Chapter The Basics of Option Management key',
#  'Chapter The Basics of Option Management ',
#  'SFEThe Basics of Option Management YArbitrage Theory ⊡buy and sell an asset on different stock markets for different prices ⊡two portfolios with the same current value same maturity but different values at maturity ArbitrageArbitrage exists if there is trading strategy which produces riskless proﬁt with non zero probability Example',
#  'SFEThe Basics of Option Management Consider two portfolios and with current value and respectively Suppose that for some the terminal value and that for some ABWA WB TWA WB TBy short selling and buying and investing the difference BAinto savings account with interest the investor does not invest proprietary capital rArbitrage StrategyWA uni WB uni WB −WA uni ',
#  'SFEThe Basics of Option Management However in there will be risk less proﬁt of THe even could be inﬁnitely rich This violates the principle of no arbitrage and thus it must hold WA −WB uni uni er T−t WA WB for\xa0all\xa0t',
#  'SFEThe Basics of Option Management Basic assumption for the remainder No Arbitrage prices of derivatives must not permit arbitrage ',
#  'SFEThe Basics of Option Management YPerfect Financial Market ⊡debit interest rate credit interest rate ⊡no transaction costs ⊡no taxes ⊡short selling is allowed ⊡stocks are unlimitedly divisible ⊡no arbitrage ',
#  'SFEThe Basics of Option Management Price of forward contract KTStVK St uni Delivery price Maturity date Underlying price Price at time ',
#  'SFEThe Basics of Option Management Proposition Under the assumption of perfect market and the additional assumption of constant interest rate during the time interval the following holds uni T−t With no dividend payments or costs of carry we have and Ft Ster uni St uni VK St uni St−Ke−r uni ',
#  'SFEThe Basics of Option Management If is the value of all earnings and costs related to the underlying during the time period calculated at time we have Dt uni and Ft St−Dt er uni If we have continuous costs of carry then the value of the forward contract at time is and Ft Steb uni St uni VK St uni St−Dt−Ke−r uni St uni VK St uni Ste b−r uni −Ke−r uni ',
#  'SFEThe Basics of Option Management Proof case There are no dividend payments Portfolio long position in forward contract with strike maturity date and long position in zero bond with nominal value and expiration KTKT\nPortfolio Portfolio VK St uni Ke−r uni St andPortfolio long position in the asset Both portfolios have the same value at time and hence by no arbitrage must have the same value at time STTt',
#  'SFEThe Basics of Option Management We have to show that VFt uni Inserting in for yields FT Stet uni KThus and hence VFt St uni Ste−r uni er uni StVFt uni St uni VFt St uni Fte−r uni St',
#  'SFEThe Basics of Option Management cases and Assume the asset pays discrete dividends DtPortfolio long position in the asset and short position in zerobond with current value at time and expiration date DttTBoth portfolios have the same value at time and hence by no arbitrage must have the same value at time STTtPortfolio Portfolio Portfolio long position in forward contract with strike maturity date and long position in zerobond with nominal value and expiration KTKTVK St uni Ke−r uni St−Dt and',
#  'SFEThe Basics of Option Management We have to show that VFt uni VFt St uni Fte−r uni StThus and hence VFt St uni Ste−r uni er uni StVFt St uni Inserting in for yields Ft Stet uni Klink press to return to this page ',
#  'SFEThe Basics of Option Management If we have continuous dividend payment we change portfolio to Portfolio buy shares of the asset and reinvest all dividend payments in the asset de b−r uni e−d uni The result follows by similar arguments as in the discrete dividend case Again for we have Ft Steb uni VK St uni VK St uni Ke−r uni e−d uni St',
#  'SFEThe Basics of Option Management Example Forward contract with discrete dividendsCoupon payments of in and months from now Continuous interest rate for months We have for and the value of the forward contract is The forward price is FtFt St−Dt er uni Dt e− uni e− VK St uni − − e− − Consider forward contract on ﬁve year bond with Bond price at time Delivery price Time to maturity tSt uni T−t year Dt',
#  'SFEThe Basics of Option Management Example Forward contract with continuous dividends\nThen the forward price is For we have premium if discount If and then Ft Steb uni Ste r−d uni dSt Ftr dSt Ftr dK StVSt St e−d uni −e−r uni The forward contract at delivery price is more expensive than the spot price as the investor proﬁts from the higher interest rates in the domestic currency till StTdr rA StAssumeCost of carryDividend yieldDomestic American interest raterA db r−dUSD exchange rate',
#  'SFEThe Basics of Option Management Proposition If the interest rate is constant during the maturity of the contract the future and the forward price are equal Proof Let days be the forward price at the end of day be the future price at the end of day and let be the daily interest rate at which daily proﬁt loss calculations occur We consider two portfolios uni NF Ftt … uni Portfolio buy forward contracts and buy zerobond with nominal value and with days to expiration eN uni FeN uni NPortfolio buy future contracts such that there are contracts in the portfolio at the end of day and buy zerobond with nominal value and days to expiration uni teN uni N',
#  'SFEThe Basics of Option Management Portfolio After day at the expiration date portfolio contains total of zerobonds which are used to fulﬁl the forward contract to buy underlying at the delivery price Thus the total value of portfolio at the end of day is NFeN uni eN uni FNSNeN uni ',
#  'SFEThe Basics of Option Management Portfolio Now consider portfolio with future contracts The proﬁt loss calculation of the futures at the beginning of day yields Throughout the day more futures are bought into the portfolio so that at the end of the day total of futures are in the portfolio remember that no cash ﬂow is triggered by this purchase The change of the portfolio value has future value on day of et uni Ft−Ft− et uni uni Ft−Ft− et uni uni N−t uni Ft−Ft− eN uni ',
#  'SFEThe Basics of Option Management Since changes in the value of the future are settled every day the cumulative return on day is NN uni Ft−Ft− eN uni FN−F eN uni Together with the zerobond it follows that the value of portfolio at is which is exactly The same holds for portfolio Thus assuming no arbitrage the two portfolios must have the same value at day NFN−F eN uni eN uni FNeN uni SNeN uni ',
#  'SFEThe Basics of Option Management As the future and the forward contract have value of zero at day only the prices of zerobonds have to be considered It follows that FeN uni eN uni and',
#  'SFEThe Basics of Option Management YOption Pricing Payoff functions The payoff function of call is The payoff function of put is max ST−K max K−ST Intrinsic value Intrinsic value of call is Intrinsic value of put max St−K max K−St ',
#  'SFEThe Basics of Option Management In the money ITM An option is called ITM if its intrinsic value is nonzero At the money ATM An option is called ATM if St uni KOut of the money OTM An option is called OTM if its intrinsic value is zero ',
#  'SFEThe Basics of Option Management YElementary Properties of Option Prices ⊡option prices are non negative ⊡the price of European option at maturity is equal to the price of an American option at maturity ⊡the price of an American option is larger or equal than its intrinsic value this is not true for European options TT',
#  'SFEThe Basics of Option Management ⊡for two American options and differing only by time to maturity the following holds Cam Cam uni CamK St −t uni CamK St −t PamK St −t uni PamK St −t Since CamK St −T uni intrinsic\xa0value max St−K CamK St uni not true in general for European options ',
#  'SFEThe Basics of Option Management ⊡the price of an American option is always bigger than or equal to the price of the corresponding European option ⊡call prices are monotone decreasing functions of strike prices ⊡put prices are monotone increasing functions of strike prices']

# %%
word_list = [pdf_output[i].split(" ") for i in range(totalpages)]
word_list = pd.DataFrame(word_list)

# %%
three_word = [[word_list.iloc[j, i], word_list.iloc[j, i+1], word_list.iloc[j, i+2]] for j in range(totalpages) for i in range(len(word_list) - 2) ]
two_word = [[word_list.iloc[j, i], word_list.iloc[j, i+1]] for j in range(totalpages)  for i in range(len(word_list) - 1)]
one_word = [word_list.iloc[j, i] for j in range(totalpages) for i in range(len(word_list))]

# %%
three_word_list = [[p for p in permutations(three_word[k])][1:] for k in range(len(three_word))]
three_word_list
# Out:
# [[('Ladislaus', 'Bortkiewicz', 'von'),
#   ('von', 'Ladislaus', 'Bortkiewicz'),
#   ('von', 'Bortkiewicz', 'Ladislaus'),
#   ('Bortkiewicz', 'Ladislaus', 'von'),
#   ('Bortkiewicz', 'von', 'Ladislaus')],
#  [('von', 'Professor', 'Bortkiewicz'),
#   ('Bortkiewicz', 'von', 'Professor'),
#   ('Bortkiewicz', 'Professor', 'von'),
#   ('Professor', 'von', 'Bortkiewicz'),
#   ('Professor', 'Bortkiewicz', 'von')],
#  [('Bortkiewicz', 'of', 'Professor'),
#   ('Professor', 'Bortkiewicz', 'of'),
#   ('Professor', 'of', 'Bortkiewicz'),
#   ('of', 'Bortkiewicz', 'Professor'),
#   ('of', 'Professor', 'Bortkiewicz')],
#  [('Professor', 'Statistics', 'of'),
#   ('of', 'Professor', 'Statistics'),
#   ('of', 'Statistics', 'Professor'),
#   ('Statistics', 'Professor', 'of'),
#   ('Statistics', 'of', 'Professor')],
#  [('of', 'Humboldt', 'Statistics'),
#   ('Statistics', 'of', 'Humboldt'),
#   ('Statistics', 'Humboldt', 'of'),
#   ('Humboldt', 'of', 'Statistics'),
#   ('Humboldt', 'Statistics', 'of')],
#  [('Statistics', 'Universität', 'Humboldt'),
#   ('Humboldt', 'Statistics', 'Universität'),
#   ('Humboldt', 'Universität', 'Statistics'),
#   ('Universität', 'Statistics', 'Humboldt'),
#   ('Universität', 'Humboldt', 'Statistics')],
#  [('Humboldt', 'zu', 'Universität'),
#   ('Universität', 'Humboldt', 'zu'),
#   ('Universität', 'zu', 'Humboldt'),
#   ('zu', 'Humboldt', 'Universität'),
#   ('zu', 'Universität', 'Humboldt')],
#  [('Universität', 'Berlin', 'zu'),
#   ('zu', 'Universität', 'Berlin'),
#   ('zu', 'Berlin', 'Universität'),
#   ('Berlin', 'Universität', 'zu'),
#   ('Berlin', 'zu', 'Universität')],
#  [('zu', 'BRC', 'Berlin'),
#   ('Berlin', 'zu', 'BRC'),
#   ('Berlin', 'BRC', 'zu'),
#   ('BRC', 'zu', 'Berlin'),
#   ('BRC', 'Berlin', 'zu')],
#  [('Berlin', 'Blockchain', 'BRC'),
#   ('BRC', 'Berlin', 'Blockchain'),
#   ('BRC', 'Blockchain', 'Berlin'),
#   ('Blockchain', 'Berlin', 'BRC'),
#   ('Blockchain', 'BRC', 'Berlin')],
#  [('BRC', 'Research', 'Blockchain'),
#   ('Blockchain', 'BRC', 'Research'),
#   ('Blockchain', 'Research', 'BRC'),
#   ('Research', 'BRC', 'Blockchain'),
#   ('Research', 'Blockchain', 'BRC')],
#  [('Blockchain', 'Center', 'Research'),
#   ('Research', 'Blockchain', 'Center'),
#   ('Research', 'Center', 'Blockchain'),
#   ('Center', 'Blockchain', 'Research'),
#   ('Center', 'Research', 'Blockchain')],
#  [('Research', 'lvb', 'Center'),
#   ('Center', 'Research', 'lvb'),
#   ('Center', 'lvb', 'Research'),
#   ('lvb', 'Research', 'Center'),
#   ('lvb', 'Center', 'Research')],
#  [('Center', 'wiwi', 'lvb'),
#   ('lvb', 'Center', 'wiwi'),
#   ('lvb', 'wiwi', 'Center'),
#   ('wiwi', 'Center', 'lvb'),
#   ('wiwi', 'lvb', 'Center')],
#  [('lvb', 'hu', 'wiwi'),
#   ('wiwi', 'lvb', 'hu'),
#   ('wiwi', 'hu', 'lvb'),
#   ('hu', 'lvb', 'wiwi'),
#   ('hu', 'wiwi', 'lvb')],
#  [('wiwi', 'berlin', 'hu'),
#   ('hu', 'wiwi', 'berlin'),
#   ('hu', 'berlin', 'wiwi'),
#   ('berlin', 'wiwi', 'hu'),
#   ('berlin', 'hu', 'wiwi')],
#  [('hu', 'de', 'berlin'),
#   ('berlin', 'hu', 'de'),
#   ('berlin', 'de', 'hu'),
#   ('de', 'hu', 'berlin'),
#   ('de', 'berlin', 'hu')],
#  [('berlin', 'Charles', 'de'),
#   ('de', 'berlin', 'Charles'),
#   ('de', 'Charles', 'berlin'),
#   ('Charles', 'berlin', 'de'),
#   ('Charles', 'de', 'berlin')],
#  [('de', 'University', 'Charles'),
#   ('Charles', 'de', 'University'),
#   ('Charles', 'University', 'de'),
#   ('University', 'de', 'Charles'),
#   ('University', 'Charles', 'de')],
#  [('Charles', 'WISE', 'University'),
#   ('University', 'Charles', 'WISE'),
#   ('University', 'WISE', 'Charles'),
#   ('WISE', 'Charles', 'University'),
#   ('WISE', 'University', 'Charles')],
#  [('University', 'XMU', 'WISE'),
#   ('WISE', 'University', 'XMU'),
#   ('WISE', 'XMU', 'University'),
#   ('XMU', 'University', 'WISE'),
#   ('XMU', 'WISE', 'University')],
#  [('WISE', 'NYCU', 'XMU'),
#   ('XMU', 'WISE', 'NYCU'),
#   ('XMU', 'NYCU', 'WISE'),
#   ('NYCU', 'WISE', 'XMU'),
#   ('NYCU', 'XMU', 'WISE')],
#  [('XMU', '⽟⼭學者', 'NYCU'),
#   ('NYCU', 'XMU', '⽟⼭學者'),
#   ('NYCU', '⽟⼭學者', 'XMU'),
#   ('⽟⼭學者', 'XMU', 'NYCU'),
#   ('⽟⼭學者', 'NYCU', 'XMU')],
#  [('NYCU', 'Jürgen', '⽟⼭學者'),
#   ('⽟⼭學者', 'NYCU', 'Jürgen'),
#   ('⽟⼭學者', 'Jürgen', 'NYCU'),
#   ('Jürgen', 'NYCU', '⽟⼭學者'),
#   ('Jürgen', '⽟⼭學者', 'NYCU')],
#  [('⽟⼭學者', 'Franke', 'Jürgen'),
#   ('Jürgen', '⽟⼭學者', 'Franke'),
#   ('Jürgen', 'Franke', '⽟⼭學者'),
#   ('Franke', '⽟⼭學者', 'Jürgen'),
#   ('Franke', 'Jürgen', '⽟⼭學者')],
#  [('Chapter', 'Basics', 'The'),
#   ('The', 'Chapter', 'Basics'),
#   ('The', 'Basics', 'Chapter'),
#   ('Basics', 'Chapter', 'The'),
#   ('Basics', 'The', 'Chapter')],
#  [('The', 'of', 'Basics'),
#   ('Basics', 'The', 'of'),
#   ('Basics', 'of', 'The'),
#   ('of', 'The', 'Basics'),
#   ('of', 'Basics', 'The')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', '', 'Management'),
#   ('Management', 'Option', ''),
#   ('Management', '', 'Option'),
#   ('', 'Option', 'Management'),
#   ('', 'Management', 'Option')],
#  [('Management', None, ''),
#   ('', 'Management', None),
#   ('', None, 'Management'),
#   (None, 'Management', ''),
#   (None, '', 'Management')],
#  [('', None, None),
#   (None, '', None),
#   (None, None, ''),
#   (None, '', None),
#   (None, None, '')],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'YArbitrage', 'Management'),
#   ('Management', 'Option', 'YArbitrage'),
#   ('Management', 'YArbitrage', 'Option'),
#   ('YArbitrage', 'Option', 'Management'),
#   ('YArbitrage', 'Management', 'Option')],
#  [('Management', 'Theory', 'YArbitrage'),
#   ('YArbitrage', 'Management', 'Theory'),
#   ('YArbitrage', 'Theory', 'Management'),
#   ('Theory', 'Management', 'YArbitrage'),
#   ('Theory', 'YArbitrage', 'Management')],
#  [('YArbitrage', '⊡buy', 'Theory'),
#   ('Theory', 'YArbitrage', '⊡buy'),
#   ('Theory', '⊡buy', 'YArbitrage'),
#   ('⊡buy', 'YArbitrage', 'Theory'),
#   ('⊡buy', 'Theory', 'YArbitrage')],
#  [('Theory', 'and', '⊡buy'),
#   ('⊡buy', 'Theory', 'and'),
#   ('⊡buy', 'and', 'Theory'),
#   ('and', 'Theory', '⊡buy'),
#   ('and', '⊡buy', 'Theory')],
#  [('⊡buy', 'sell', 'and'),
#   ('and', '⊡buy', 'sell'),
#   ('and', 'sell', '⊡buy'),
#   ('sell', '⊡buy', 'and'),
#   ('sell', 'and', '⊡buy')],
#  [('and', 'an', 'sell'),
#   ('sell', 'and', 'an'),
#   ('sell', 'an', 'and'),
#   ('an', 'and', 'sell'),
#   ('an', 'sell', 'and')],
#  [('sell', 'asset', 'an'),
#   ('an', 'sell', 'asset'),
#   ('an', 'asset', 'sell'),
#   ('asset', 'sell', 'an'),
#   ('asset', 'an', 'sell')],
#  [('an', 'on', 'asset'),
#   ('asset', 'an', 'on'),
#   ('asset', 'on', 'an'),
#   ('on', 'an', 'asset'),
#   ('on', 'asset', 'an')],
#  [('asset', 'different', 'on'),
#   ('on', 'asset', 'different'),
#   ('on', 'different', 'asset'),
#   ('different', 'asset', 'on'),
#   ('different', 'on', 'asset')],
#  [('on', 'stock', 'different'),
#   ('different', 'on', 'stock'),
#   ('different', 'stock', 'on'),
#   ('stock', 'on', 'different'),
#   ('stock', 'different', 'on')],
#  [('different', 'markets', 'stock'),
#   ('stock', 'different', 'markets'),
#   ('stock', 'markets', 'different'),
#   ('markets', 'different', 'stock'),
#   ('markets', 'stock', 'different')],
#  [('stock', 'for', 'markets'),
#   ('markets', 'stock', 'for'),
#   ('markets', 'for', 'stock'),
#   ('for', 'stock', 'markets'),
#   ('for', 'markets', 'stock')],
#  [('markets', 'different', 'for'),
#   ('for', 'markets', 'different'),
#   ('for', 'different', 'markets'),
#   ('different', 'markets', 'for'),
#   ('different', 'for', 'markets')],
#  [('for', 'prices', 'different'),
#   ('different', 'for', 'prices'),
#   ('different', 'prices', 'for'),
#   ('prices', 'for', 'different'),
#   ('prices', 'different', 'for')],
#  [('different', '⊡two', 'prices'),
#   ('prices', 'different', '⊡two'),
#   ('prices', '⊡two', 'different'),
#   ('⊡two', 'different', 'prices'),
#   ('⊡two', 'prices', 'different')],
#  [('prices', 'portfolios', '⊡two'),
#   ('⊡two', 'prices', 'portfolios'),
#   ('⊡two', 'portfolios', 'prices'),
#   ('portfolios', 'prices', '⊡two'),
#   ('portfolios', '⊡two', 'prices')],
#  [('⊡two', 'with', 'portfolios'),
#   ('portfolios', '⊡two', 'with'),
#   ('portfolios', 'with', '⊡two'),
#   ('with', '⊡two', 'portfolios'),
#   ('with', 'portfolios', '⊡two')],
#  [('portfolios', 'the', 'with'),
#   ('with', 'portfolios', 'the'),
#   ('with', 'the', 'portfolios'),
#   ('the', 'portfolios', 'with'),
#   ('the', 'with', 'portfolios')],
#  [('with', 'same', 'the'),
#   ('the', 'with', 'same'),
#   ('the', 'same', 'with'),
#   ('same', 'with', 'the'),
#   ('same', 'the', 'with')],
#  [('the', 'current', 'same'),
#   ('same', 'the', 'current'),
#   ('same', 'current', 'the'),
#   ('current', 'the', 'same'),
#   ('current', 'same', 'the')],
#  [('same', 'value', 'current'),
#   ('current', 'same', 'value'),
#   ('current', 'value', 'same'),
#   ('value', 'same', 'current'),
#   ('value', 'current', 'same')],
#  [('current', 'same', 'value'),
#   ('value', 'current', 'same'),
#   ('value', 'same', 'current'),
#   ('same', 'current', 'value'),
#   ('same', 'value', 'current')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'Consider', 'Management'),
#   ('Management', 'Option', 'Consider'),
#   ('Management', 'Consider', 'Option'),
#   ('Consider', 'Option', 'Management'),
#   ('Consider', 'Management', 'Option')],
#  [('Management', 'two', 'Consider'),
#   ('Consider', 'Management', 'two'),
#   ('Consider', 'two', 'Management'),
#   ('two', 'Management', 'Consider'),
#   ('two', 'Consider', 'Management')],
#  [('Consider', 'portfolios', 'two'),
#   ('two', 'Consider', 'portfolios'),
#   ('two', 'portfolios', 'Consider'),
#   ('portfolios', 'Consider', 'two'),
#   ('portfolios', 'two', 'Consider')],
#  [('two', 'and', 'portfolios'),
#   ('portfolios', 'two', 'and'),
#   ('portfolios', 'and', 'two'),
#   ('and', 'two', 'portfolios'),
#   ('and', 'portfolios', 'two')],
#  [('portfolios', 'with', 'and'),
#   ('and', 'portfolios', 'with'),
#   ('and', 'with', 'portfolios'),
#   ('with', 'portfolios', 'and'),
#   ('with', 'and', 'portfolios')],
#  [('and', 'current', 'with'),
#   ('with', 'and', 'current'),
#   ('with', 'current', 'and'),
#   ('current', 'and', 'with'),
#   ('current', 'with', 'and')],
#  [('with', 'value', 'current'),
#   ('current', 'with', 'value'),
#   ('current', 'value', 'with'),
#   ('value', 'with', 'current'),
#   ('value', 'current', 'with')],
#  [('current', 'and', 'value'),
#   ('value', 'current', 'and'),
#   ('value', 'and', 'current'),
#   ('and', 'current', 'value'),
#   ('and', 'value', 'current')],
#  [('value', 'respectively', 'and'),
#   ('and', 'value', 'respectively'),
#   ('and', 'respectively', 'value'),
#   ('respectively', 'value', 'and'),
#   ('respectively', 'and', 'value')],
#  [('and', 'Suppose', 'respectively'),
#   ('respectively', 'and', 'Suppose'),
#   ('respectively', 'Suppose', 'and'),
#   ('Suppose', 'and', 'respectively'),
#   ('Suppose', 'respectively', 'and')],
#  [('respectively', 'that', 'Suppose'),
#   ('Suppose', 'respectively', 'that'),
#   ('Suppose', 'that', 'respectively'),
#   ('that', 'respectively', 'Suppose'),
#   ('that', 'Suppose', 'respectively')],
#  [('Suppose', 'for', 'that'),
#   ('that', 'Suppose', 'for'),
#   ('that', 'for', 'Suppose'),
#   ('for', 'Suppose', 'that'),
#   ('for', 'that', 'Suppose')],
#  [('that', 'some', 'for'),
#   ('for', 'that', 'some'),
#   ('for', 'some', 'that'),
#   ('some', 'that', 'for'),
#   ('some', 'for', 'that')],
#  [('for', 'the', 'some'),
#   ('some', 'for', 'the'),
#   ('some', 'the', 'for'),
#   ('the', 'for', 'some'),
#   ('the', 'some', 'for')],
#  [('some', 'terminal', 'the'),
#   ('the', 'some', 'terminal'),
#   ('the', 'terminal', 'some'),
#   ('terminal', 'some', 'the'),
#   ('terminal', 'the', 'some')],
#  [('the', 'value', 'terminal'),
#   ('terminal', 'the', 'value'),
#   ('terminal', 'value', 'the'),
#   ('value', 'the', 'terminal'),
#   ('value', 'terminal', 'the')],
#  [('terminal', 'and', 'value'),
#   ('value', 'terminal', 'and'),
#   ('value', 'and', 'terminal'),
#   ('and', 'terminal', 'value'),
#   ('and', 'value', 'terminal')],
#  [('value', 'that', 'and'),
#   ('and', 'value', 'that'),
#   ('and', 'that', 'value'),
#   ('that', 'value', 'and'),
#   ('that', 'and', 'value')],
#  [('and', 'for', 'that'),
#   ('that', 'and', 'for'),
#   ('that', 'for', 'and'),
#   ('for', 'and', 'that'),
#   ('for', 'that', 'and')],
#  [('that', 'some', 'for'),
#   ('for', 'that', 'some'),
#   ('for', 'some', 'that'),
#   ('some', 'that', 'for'),
#   ('some', 'for', 'that')],
#  [('for', 'ABWA', 'some'),
#   ('some', 'for', 'ABWA'),
#   ('some', 'ABWA', 'for'),
#   ('ABWA', 'for', 'some'),
#   ('ABWA', 'some', 'for')],
#  [('some', 'WB', 'ABWA'),
#   ('ABWA', 'some', 'WB'),
#   ('ABWA', 'WB', 'some'),
#   ('WB', 'some', 'ABWA'),
#   ('WB', 'ABWA', 'some')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'However', 'Management'),
#   ('Management', 'Option', 'However'),
#   ('Management', 'However', 'Option'),
#   ('However', 'Option', 'Management'),
#   ('However', 'Management', 'Option')],
#  [('Management', 'in', 'However'),
#   ('However', 'Management', 'in'),
#   ('However', 'in', 'Management'),
#   ('in', 'Management', 'However'),
#   ('in', 'However', 'Management')],
#  [('However', 'there', 'in'),
#   ('in', 'However', 'there'),
#   ('in', 'there', 'However'),
#   ('there', 'However', 'in'),
#   ('there', 'in', 'However')],
#  [('in', 'will', 'there'),
#   ('there', 'in', 'will'),
#   ('there', 'will', 'in'),
#   ('will', 'in', 'there'),
#   ('will', 'there', 'in')],
#  [('there', 'be', 'will'),
#   ('will', 'there', 'be'),
#   ('will', 'be', 'there'),
#   ('be', 'there', 'will'),
#   ('be', 'will', 'there')],
#  [('will', 'risk', 'be'),
#   ('be', 'will', 'risk'),
#   ('be', 'risk', 'will'),
#   ('risk', 'will', 'be'),
#   ('risk', 'be', 'will')],
#  [('be', 'less', 'risk'),
#   ('risk', 'be', 'less'),
#   ('risk', 'less', 'be'),
#   ('less', 'be', 'risk'),
#   ('less', 'risk', 'be')],
#  [('risk', 'proﬁt', 'less'),
#   ('less', 'risk', 'proﬁt'),
#   ('less', 'proﬁt', 'risk'),
#   ('proﬁt', 'risk', 'less'),
#   ('proﬁt', 'less', 'risk')],
#  [('less', 'of', 'proﬁt'),
#   ('proﬁt', 'less', 'of'),
#   ('proﬁt', 'of', 'less'),
#   ('of', 'less', 'proﬁt'),
#   ('of', 'proﬁt', 'less')],
#  [('proﬁt', 'THe', 'of'),
#   ('of', 'proﬁt', 'THe'),
#   ('of', 'THe', 'proﬁt'),
#   ('THe', 'proﬁt', 'of'),
#   ('THe', 'of', 'proﬁt')],
#  [('of', 'even', 'THe'),
#   ('THe', 'of', 'even'),
#   ('THe', 'even', 'of'),
#   ('even', 'of', 'THe'),
#   ('even', 'THe', 'of')],
#  [('THe', 'could', 'even'),
#   ('even', 'THe', 'could'),
#   ('even', 'could', 'THe'),
#   ('could', 'THe', 'even'),
#   ('could', 'even', 'THe')],
#  [('even', 'be', 'could'),
#   ('could', 'even', 'be'),
#   ('could', 'be', 'even'),
#   ('be', 'even', 'could'),
#   ('be', 'could', 'even')],
#  [('could', 'inﬁnitely', 'be'),
#   ('be', 'could', 'inﬁnitely'),
#   ('be', 'inﬁnitely', 'could'),
#   ('inﬁnitely', 'could', 'be'),
#   ('inﬁnitely', 'be', 'could')],
#  [('be', 'rich', 'inﬁnitely'),
#   ('inﬁnitely', 'be', 'rich'),
#   ('inﬁnitely', 'rich', 'be'),
#   ('rich', 'be', 'inﬁnitely'),
#   ('rich', 'inﬁnitely', 'be')],
#  [('inﬁnitely', 'This', 'rich'),
#   ('rich', 'inﬁnitely', 'This'),
#   ('rich', 'This', 'inﬁnitely'),
#   ('This', 'inﬁnitely', 'rich'),
#   ('This', 'rich', 'inﬁnitely')],
#  [('rich', 'violates', 'This'),
#   ('This', 'rich', 'violates'),
#   ('This', 'violates', 'rich'),
#   ('violates', 'rich', 'This'),
#   ('violates', 'This', 'rich')],
#  [('This', 'the', 'violates'),
#   ('violates', 'This', 'the'),
#   ('violates', 'the', 'This'),
#   ('the', 'This', 'violates'),
#   ('the', 'violates', 'This')],
#  [('violates', 'principle', 'the'),
#   ('the', 'violates', 'principle'),
#   ('the', 'principle', 'violates'),
#   ('principle', 'violates', 'the'),
#   ('principle', 'the', 'violates')],
#  [('the', 'of', 'principle'),
#   ('principle', 'the', 'of'),
#   ('principle', 'of', 'the'),
#   ('of', 'the', 'principle'),
#   ('of', 'principle', 'the')],
#  [('principle', 'no', 'of'),
#   ('of', 'principle', 'no'),
#   ('of', 'no', 'principle'),
#   ('no', 'principle', 'of'),
#   ('no', 'of', 'principle')],
#  [('of', 'arbitrage', 'no'),
#   ('no', 'of', 'arbitrage'),
#   ('no', 'arbitrage', 'of'),
#   ('arbitrage', 'of', 'no'),
#   ('arbitrage', 'no', 'of')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'Basic', 'Management'),
#   ('Management', 'Option', 'Basic'),
#   ('Management', 'Basic', 'Option'),
#   ('Basic', 'Option', 'Management'),
#   ('Basic', 'Management', 'Option')],
#  [('Management', 'assumption', 'Basic'),
#   ('Basic', 'Management', 'assumption'),
#   ('Basic', 'assumption', 'Management'),
#   ('assumption', 'Management', 'Basic'),
#   ('assumption', 'Basic', 'Management')],
#  [('Basic', 'for', 'assumption'),
#   ('assumption', 'Basic', 'for'),
#   ('assumption', 'for', 'Basic'),
#   ('for', 'Basic', 'assumption'),
#   ('for', 'assumption', 'Basic')],
#  [('assumption', 'the', 'for'),
#   ('for', 'assumption', 'the'),
#   ('for', 'the', 'assumption'),
#   ('the', 'assumption', 'for'),
#   ('the', 'for', 'assumption')],
#  [('for', 'remainder', 'the'),
#   ('the', 'for', 'remainder'),
#   ('the', 'remainder', 'for'),
#   ('remainder', 'for', 'the'),
#   ('remainder', 'the', 'for')],
#  [('the', 'No', 'remainder'),
#   ('remainder', 'the', 'No'),
#   ('remainder', 'No', 'the'),
#   ('No', 'the', 'remainder'),
#   ('No', 'remainder', 'the')],
#  [('remainder', 'Arbitrage', 'No'),
#   ('No', 'remainder', 'Arbitrage'),
#   ('No', 'Arbitrage', 'remainder'),
#   ('Arbitrage', 'remainder', 'No'),
#   ('Arbitrage', 'No', 'remainder')],
#  [('No', 'prices', 'Arbitrage'),
#   ('Arbitrage', 'No', 'prices'),
#   ('Arbitrage', 'prices', 'No'),
#   ('prices', 'No', 'Arbitrage'),
#   ('prices', 'Arbitrage', 'No')],
#  [('Arbitrage', 'of', 'prices'),
#   ('prices', 'Arbitrage', 'of'),
#   ('prices', 'of', 'Arbitrage'),
#   ('of', 'Arbitrage', 'prices'),
#   ('of', 'prices', 'Arbitrage')],
#  [('prices', 'derivatives', 'of'),
#   ('of', 'prices', 'derivatives'),
#   ('of', 'derivatives', 'prices'),
#   ('derivatives', 'prices', 'of'),
#   ('derivatives', 'of', 'prices')],
#  [('of', 'must', 'derivatives'),
#   ('derivatives', 'of', 'must'),
#   ('derivatives', 'must', 'of'),
#   ('must', 'of', 'derivatives'),
#   ('must', 'derivatives', 'of')],
#  [('derivatives', 'not', 'must'),
#   ('must', 'derivatives', 'not'),
#   ('must', 'not', 'derivatives'),
#   ('not', 'derivatives', 'must'),
#   ('not', 'must', 'derivatives')],
#  [('must', 'permit', 'not'),
#   ('not', 'must', 'permit'),
#   ('not', 'permit', 'must'),
#   ('permit', 'must', 'not'),
#   ('permit', 'not', 'must')],
#  [('not', 'arbitrage', 'permit'),
#   ('permit', 'not', 'arbitrage'),
#   ('permit', 'arbitrage', 'not'),
#   ('arbitrage', 'not', 'permit'),
#   ('arbitrage', 'permit', 'not')],
#  [('permit', '', 'arbitrage'),
#   ('arbitrage', 'permit', ''),
#   ('arbitrage', '', 'permit'),
#   ('', 'permit', 'arbitrage'),
#   ('', 'arbitrage', 'permit')],
#  [('arbitrage', None, ''),
#   ('', 'arbitrage', None),
#   ('', None, 'arbitrage'),
#   (None, 'arbitrage', ''),
#   (None, '', 'arbitrage')],
#  [('', None, None),
#   (None, '', None),
#   (None, None, ''),
#   (None, '', None),
#   (None, None, '')],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'YPerfect', 'Management'),
#   ('Management', 'Option', 'YPerfect'),
#   ('Management', 'YPerfect', 'Option'),
#   ('YPerfect', 'Option', 'Management'),
#   ('YPerfect', 'Management', 'Option')],
#  [('Management', 'Financial', 'YPerfect'),
#   ('YPerfect', 'Management', 'Financial'),
#   ('YPerfect', 'Financial', 'Management'),
#   ('Financial', 'Management', 'YPerfect'),
#   ('Financial', 'YPerfect', 'Management')],
#  [('YPerfect', 'Market', 'Financial'),
#   ('Financial', 'YPerfect', 'Market'),
#   ('Financial', 'Market', 'YPerfect'),
#   ('Market', 'YPerfect', 'Financial'),
#   ('Market', 'Financial', 'YPerfect')],
#  [('Financial', '⊡debit', 'Market'),
#   ('Market', 'Financial', '⊡debit'),
#   ('Market', '⊡debit', 'Financial'),
#   ('⊡debit', 'Financial', 'Market'),
#   ('⊡debit', 'Market', 'Financial')],
#  [('Market', 'interest', '⊡debit'),
#   ('⊡debit', 'Market', 'interest'),
#   ('⊡debit', 'interest', 'Market'),
#   ('interest', 'Market', '⊡debit'),
#   ('interest', '⊡debit', 'Market')],
#  [('⊡debit', 'rate', 'interest'),
#   ('interest', '⊡debit', 'rate'),
#   ('interest', 'rate', '⊡debit'),
#   ('rate', '⊡debit', 'interest'),
#   ('rate', 'interest', '⊡debit')],
#  [('interest', 'credit', 'rate'),
#   ('rate', 'interest', 'credit'),
#   ('rate', 'credit', 'interest'),
#   ('credit', 'interest', 'rate'),
#   ('credit', 'rate', 'interest')],
#  [('rate', 'interest', 'credit'),
#   ('credit', 'rate', 'interest'),
#   ('credit', 'interest', 'rate'),
#   ('interest', 'rate', 'credit'),
#   ('interest', 'credit', 'rate')],
#  [('credit', 'rate', 'interest'),
#   ('interest', 'credit', 'rate'),
#   ('interest', 'rate', 'credit'),
#   ('rate', 'credit', 'interest'),
#   ('rate', 'interest', 'credit')],
#  [('interest', '⊡no', 'rate'),
#   ('rate', 'interest', '⊡no'),
#   ('rate', '⊡no', 'interest'),
#   ('⊡no', 'interest', 'rate'),
#   ('⊡no', 'rate', 'interest')],
#  [('rate', 'transaction', '⊡no'),
#   ('⊡no', 'rate', 'transaction'),
#   ('⊡no', 'transaction', 'rate'),
#   ('transaction', 'rate', '⊡no'),
#   ('transaction', '⊡no', 'rate')],
#  [('⊡no', 'costs', 'transaction'),
#   ('transaction', '⊡no', 'costs'),
#   ('transaction', 'costs', '⊡no'),
#   ('costs', '⊡no', 'transaction'),
#   ('costs', 'transaction', '⊡no')],
#  [('transaction', '⊡no', 'costs'),
#   ('costs', 'transaction', '⊡no'),
#   ('costs', '⊡no', 'transaction'),
#   ('⊡no', 'transaction', 'costs'),
#   ('⊡no', 'costs', 'transaction')],
#  [('costs', 'taxes', '⊡no'),
#   ('⊡no', 'costs', 'taxes'),
#   ('⊡no', 'taxes', 'costs'),
#   ('taxes', 'costs', '⊡no'),
#   ('taxes', '⊡no', 'costs')],
#  [('⊡no', '⊡short', 'taxes'),
#   ('taxes', '⊡no', '⊡short'),
#   ('taxes', '⊡short', '⊡no'),
#   ('⊡short', '⊡no', 'taxes'),
#   ('⊡short', 'taxes', '⊡no')],
#  [('taxes', 'selling', '⊡short'),
#   ('⊡short', 'taxes', 'selling'),
#   ('⊡short', 'selling', 'taxes'),
#   ('selling', 'taxes', '⊡short'),
#   ('selling', '⊡short', 'taxes')],
#  [('⊡short', 'is', 'selling'),
#   ('selling', '⊡short', 'is'),
#   ('selling', 'is', '⊡short'),
#   ('is', '⊡short', 'selling'),
#   ('is', 'selling', '⊡short')],
#  [('selling', 'allowed', 'is'),
#   ('is', 'selling', 'allowed'),
#   ('is', 'allowed', 'selling'),
#   ('allowed', 'selling', 'is'),
#   ('allowed', 'is', 'selling')],
#  [('is', '⊡stocks', 'allowed'),
#   ('allowed', 'is', '⊡stocks'),
#   ('allowed', '⊡stocks', 'is'),
#   ('⊡stocks', 'is', 'allowed'),
#   ('⊡stocks', 'allowed', 'is')],
#  [('allowed', 'are', '⊡stocks'),
#   ('⊡stocks', 'allowed', 'are'),
#   ('⊡stocks', 'are', 'allowed'),
#   ('are', 'allowed', '⊡stocks'),
#   ('are', '⊡stocks', 'allowed')],
#  [('⊡stocks', 'unlimitedly', 'are'),
#   ('are', '⊡stocks', 'unlimitedly'),
#   ('are', 'unlimitedly', '⊡stocks'),
#   ('unlimitedly', '⊡stocks', 'are'),
#   ('unlimitedly', 'are', '⊡stocks')],
#  [('are', 'divisible', 'unlimitedly'),
#   ('unlimitedly', 'are', 'divisible'),
#   ('unlimitedly', 'divisible', 'are'),
#   ('divisible', 'are', 'unlimitedly'),
#   ('divisible', 'unlimitedly', 'are')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'Price', 'Management'),
#   ('Management', 'Option', 'Price'),
#   ('Management', 'Price', 'Option'),
#   ('Price', 'Option', 'Management'),
#   ('Price', 'Management', 'Option')],
#  [('Management', 'of', 'Price'),
#   ('Price', 'Management', 'of'),
#   ('Price', 'of', 'Management'),
#   ('of', 'Management', 'Price'),
#   ('of', 'Price', 'Management')],
#  [('Price', 'forward', 'of'),
#   ('of', 'Price', 'forward'),
#   ('of', 'forward', 'Price'),
#   ('forward', 'Price', 'of'),
#   ('forward', 'of', 'Price')],
#  [('of', 'contract', 'forward'),
#   ('forward', 'of', 'contract'),
#   ('forward', 'contract', 'of'),
#   ('contract', 'of', 'forward'),
#   ('contract', 'forward', 'of')],
#  [('forward', 'KTStVK', 'contract'),
#   ('contract', 'forward', 'KTStVK'),
#   ('contract', 'KTStVK', 'forward'),
#   ('KTStVK', 'forward', 'contract'),
#   ('KTStVK', 'contract', 'forward')],
#  [('contract', 'St', 'KTStVK'),
#   ('KTStVK', 'contract', 'St'),
#   ('KTStVK', 'St', 'contract'),
#   ('St', 'contract', 'KTStVK'),
#   ('St', 'KTStVK', 'contract')],
#  [('KTStVK', 'uni', 'St'),
#   ('St', 'KTStVK', 'uni'),
#   ('St', 'uni', 'KTStVK'),
#   ('uni', 'KTStVK', 'St'),
#   ('uni', 'St', 'KTStVK')],
#  [('St', 'Delivery', 'uni'),
#   ('uni', 'St', 'Delivery'),
#   ('uni', 'Delivery', 'St'),
#   ('Delivery', 'St', 'uni'),
#   ('Delivery', 'uni', 'St')],
#  [('uni', 'price', 'Delivery'),
#   ('Delivery', 'uni', 'price'),
#   ('Delivery', 'price', 'uni'),
#   ('price', 'uni', 'Delivery'),
#   ('price', 'Delivery', 'uni')],
#  [('Delivery', 'Maturity', 'price'),
#   ('price', 'Delivery', 'Maturity'),
#   ('price', 'Maturity', 'Delivery'),
#   ('Maturity', 'Delivery', 'price'),
#   ('Maturity', 'price', 'Delivery')],
#  [('price', 'date', 'Maturity'),
#   ('Maturity', 'price', 'date'),
#   ('Maturity', 'date', 'price'),
#   ('date', 'price', 'Maturity'),
#   ('date', 'Maturity', 'price')],
#  [('Maturity', 'Underlying', 'date'),
#   ('date', 'Maturity', 'Underlying'),
#   ('date', 'Underlying', 'Maturity'),
#   ('Underlying', 'Maturity', 'date'),
#   ('Underlying', 'date', 'Maturity')],
#  [('date', 'price', 'Underlying'),
#   ('Underlying', 'date', 'price'),
#   ('Underlying', 'price', 'date'),
#   ('price', 'date', 'Underlying'),
#   ('price', 'Underlying', 'date')],
#  [('Underlying', 'Price', 'price'),
#   ('price', 'Underlying', 'Price'),
#   ('price', 'Price', 'Underlying'),
#   ('Price', 'Underlying', 'price'),
#   ('Price', 'price', 'Underlying')],
#  [('price', 'at', 'Price'),
#   ('Price', 'price', 'at'),
#   ('Price', 'at', 'price'),
#   ('at', 'price', 'Price'),
#   ('at', 'Price', 'price')],
#  [('Price', 'time', 'at'),
#   ('at', 'Price', 'time'),
#   ('at', 'time', 'Price'),
#   ('time', 'Price', 'at'),
#   ('time', 'at', 'Price')],
#  [('at', '', 'time'),
#   ('time', 'at', ''),
#   ('time', '', 'at'),
#   ('', 'at', 'time'),
#   ('', 'time', 'at')],
#  [('time', None, ''),
#   ('', 'time', None),
#   ('', None, 'time'),
#   (None, 'time', ''),
#   (None, '', 'time')],
#  [('', None, None),
#   (None, '', None),
#   (None, None, ''),
#   (None, '', None),
#   (None, None, '')],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [(None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None),
#   (None, None, None)],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'Proposition', 'Management'),
#   ('Management', 'Option', 'Proposition'),
#   ('Management', 'Proposition', 'Option'),
#   ('Proposition', 'Option', 'Management'),
#   ('Proposition', 'Management', 'Option')],
#  [('Management', 'Under', 'Proposition'),
#   ('Proposition', 'Management', 'Under'),
#   ('Proposition', 'Under', 'Management'),
#   ('Under', 'Management', 'Proposition'),
#   ('Under', 'Proposition', 'Management')],
#  [('Proposition', 'the', 'Under'),
#   ('Under', 'Proposition', 'the'),
#   ('Under', 'the', 'Proposition'),
#   ('the', 'Proposition', 'Under'),
#   ('the', 'Under', 'Proposition')],
#  [('Under', 'assumption', 'the'),
#   ('the', 'Under', 'assumption'),
#   ('the', 'assumption', 'Under'),
#   ('assumption', 'Under', 'the'),
#   ('assumption', 'the', 'Under')],
#  [('the', 'of', 'assumption'),
#   ('assumption', 'the', 'of'),
#   ('assumption', 'of', 'the'),
#   ('of', 'the', 'assumption'),
#   ('of', 'assumption', 'the')],
#  [('assumption', 'perfect', 'of'),
#   ('of', 'assumption', 'perfect'),
#   ('of', 'perfect', 'assumption'),
#   ('perfect', 'assumption', 'of'),
#   ('perfect', 'of', 'assumption')],
#  [('of', 'market', 'perfect'),
#   ('perfect', 'of', 'market'),
#   ('perfect', 'market', 'of'),
#   ('market', 'of', 'perfect'),
#   ('market', 'perfect', 'of')],
#  [('perfect', 'and', 'market'),
#   ('market', 'perfect', 'and'),
#   ('market', 'and', 'perfect'),
#   ('and', 'perfect', 'market'),
#   ('and', 'market', 'perfect')],
#  [('market', 'the', 'and'),
#   ('and', 'market', 'the'),
#   ('and', 'the', 'market'),
#   ('the', 'market', 'and'),
#   ('the', 'and', 'market')],
#  [('and', 'additional', 'the'),
#   ('the', 'and', 'additional'),
#   ('the', 'additional', 'and'),
#   ('additional', 'and', 'the'),
#   ('additional', 'the', 'and')],
#  [('the', 'assumption', 'additional'),
#   ('additional', 'the', 'assumption'),
#   ('additional', 'assumption', 'the'),
#   ('assumption', 'the', 'additional'),
#   ('assumption', 'additional', 'the')],
#  [('additional', 'of', 'assumption'),
#   ('assumption', 'additional', 'of'),
#   ('assumption', 'of', 'additional'),
#   ('of', 'additional', 'assumption'),
#   ('of', 'assumption', 'additional')],
#  [('assumption', 'constant', 'of'),
#   ('of', 'assumption', 'constant'),
#   ('of', 'constant', 'assumption'),
#   ('constant', 'assumption', 'of'),
#   ('constant', 'of', 'assumption')],
#  [('of', 'interest', 'constant'),
#   ('constant', 'of', 'interest'),
#   ('constant', 'interest', 'of'),
#   ('interest', 'of', 'constant'),
#   ('interest', 'constant', 'of')],
#  [('constant', 'rate', 'interest'),
#   ('interest', 'constant', 'rate'),
#   ('interest', 'rate', 'constant'),
#   ('rate', 'constant', 'interest'),
#   ('rate', 'interest', 'constant')],
#  [('interest', 'during', 'rate'),
#   ('rate', 'interest', 'during'),
#   ('rate', 'during', 'interest'),
#   ('during', 'interest', 'rate'),
#   ('during', 'rate', 'interest')],
#  [('rate', 'the', 'during'),
#   ('during', 'rate', 'the'),
#   ('during', 'the', 'rate'),
#   ('the', 'rate', 'during'),
#   ('the', 'during', 'rate')],
#  [('during', 'time', 'the'),
#   ('the', 'during', 'time'),
#   ('the', 'time', 'during'),
#   ('time', 'during', 'the'),
#   ('time', 'the', 'during')],
#  [('the', 'interval', 'time'),
#   ('time', 'the', 'interval'),
#   ('time', 'interval', 'the'),
#   ('interval', 'the', 'time'),
#   ('interval', 'time', 'the')],
#  [('time', 'the', 'interval'),
#   ('interval', 'time', 'the'),
#   ('interval', 'the', 'time'),
#   ('the', 'time', 'interval'),
#   ('the', 'interval', 'time')],
#  [('interval', 'following', 'the'),
#   ('the', 'interval', 'following'),
#   ('the', 'following', 'interval'),
#   ('following', 'interval', 'the'),
#   ('following', 'the', 'interval')],
#  [('the', 'holds', 'following'),
#   ('following', 'the', 'holds'),
#   ('following', 'holds', 'the'),
#   ('holds', 'the', 'following'),
#   ('holds', 'following', 'the')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'If', 'Management'),
#   ('Management', 'Option', 'If'),
#   ('Management', 'If', 'Option'),
#   ('If', 'Option', 'Management'),
#   ('If', 'Management', 'Option')],
#  [('Management', 'is', 'If'),
#   ('If', 'Management', 'is'),
#   ('If', 'is', 'Management'),
#   ('is', 'Management', 'If'),
#   ('is', 'If', 'Management')],
#  [('If', 'the', 'is'),
#   ('is', 'If', 'the'),
#   ('is', 'the', 'If'),
#   ('the', 'If', 'is'),
#   ('the', 'is', 'If')],
#  [('is', 'value', 'the'),
#   ('the', 'is', 'value'),
#   ('the', 'value', 'is'),
#   ('value', 'is', 'the'),
#   ('value', 'the', 'is')],
#  [('the', 'of', 'value'),
#   ('value', 'the', 'of'),
#   ('value', 'of', 'the'),
#   ('of', 'the', 'value'),
#   ('of', 'value', 'the')],
#  [('value', 'all', 'of'),
#   ('of', 'value', 'all'),
#   ('of', 'all', 'value'),
#   ('all', 'value', 'of'),
#   ('all', 'of', 'value')],
#  [('of', 'earnings', 'all'),
#   ('all', 'of', 'earnings'),
#   ('all', 'earnings', 'of'),
#   ('earnings', 'of', 'all'),
#   ('earnings', 'all', 'of')],
#  [('all', 'and', 'earnings'),
#   ('earnings', 'all', 'and'),
#   ('earnings', 'and', 'all'),
#   ('and', 'all', 'earnings'),
#   ('and', 'earnings', 'all')],
#  [('earnings', 'costs', 'and'),
#   ('and', 'earnings', 'costs'),
#   ('and', 'costs', 'earnings'),
#   ('costs', 'earnings', 'and'),
#   ('costs', 'and', 'earnings')],
#  [('and', 'related', 'costs'),
#   ('costs', 'and', 'related'),
#   ('costs', 'related', 'and'),
#   ('related', 'and', 'costs'),
#   ('related', 'costs', 'and')],
#  [('costs', 'to', 'related'),
#   ('related', 'costs', 'to'),
#   ('related', 'to', 'costs'),
#   ('to', 'costs', 'related'),
#   ('to', 'related', 'costs')],
#  [('related', 'the', 'to'),
#   ('to', 'related', 'the'),
#   ('to', 'the', 'related'),
#   ('the', 'related', 'to'),
#   ('the', 'to', 'related')],
#  [('to', 'underlying', 'the'),
#   ('the', 'to', 'underlying'),
#   ('the', 'underlying', 'to'),
#   ('underlying', 'to', 'the'),
#   ('underlying', 'the', 'to')],
#  [('the', 'during', 'underlying'),
#   ('underlying', 'the', 'during'),
#   ('underlying', 'during', 'the'),
#   ('during', 'the', 'underlying'),
#   ('during', 'underlying', 'the')],
#  [('underlying', 'the', 'during'),
#   ('during', 'underlying', 'the'),
#   ('during', 'the', 'underlying'),
#   ('the', 'underlying', 'during'),
#   ('the', 'during', 'underlying')],
#  [('during', 'time', 'the'),
#   ('the', 'during', 'time'),
#   ('the', 'time', 'during'),
#   ('time', 'during', 'the'),
#   ('time', 'the', 'during')],
#  [('the', 'period', 'time'),
#   ('time', 'the', 'period'),
#   ('time', 'period', 'the'),
#   ('period', 'the', 'time'),
#   ('period', 'time', 'the')],
#  [('time', 'calculated', 'period'),
#   ('period', 'time', 'calculated'),
#   ('period', 'calculated', 'time'),
#   ('calculated', 'time', 'period'),
#   ('calculated', 'period', 'time')],
#  [('period', 'at', 'calculated'),
#   ('calculated', 'period', 'at'),
#   ('calculated', 'at', 'period'),
#   ('at', 'period', 'calculated'),
#   ('at', 'calculated', 'period')],
#  [('calculated', 'time', 'at'),
#   ('at', 'calculated', 'time'),
#   ('at', 'time', 'calculated'),
#   ('time', 'calculated', 'at'),
#   ('time', 'at', 'calculated')],
#  [('at', 'we', 'time'),
#   ('time', 'at', 'we'),
#   ('time', 'we', 'at'),
#   ('we', 'at', 'time'),
#   ('we', 'time', 'at')],
#  [('time', 'have', 'we'),
#   ('we', 'time', 'have'),
#   ('we', 'have', 'time'),
#   ('have', 'time', 'we'),
#   ('have', 'we', 'time')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'Proof', 'Management'),
#   ('Management', 'Option', 'Proof'),
#   ('Management', 'Proof', 'Option'),
#   ('Proof', 'Option', 'Management'),
#   ('Proof', 'Management', 'Option')],
#  [('Management', 'case', 'Proof'),
#   ('Proof', 'Management', 'case'),
#   ('Proof', 'case', 'Management'),
#   ('case', 'Management', 'Proof'),
#   ('case', 'Proof', 'Management')],
#  [('Proof', 'There', 'case'),
#   ('case', 'Proof', 'There'),
#   ('case', 'There', 'Proof'),
#   ('There', 'Proof', 'case'),
#   ('There', 'case', 'Proof')],
#  [('case', 'are', 'There'),
#   ('There', 'case', 'are'),
#   ('There', 'are', 'case'),
#   ('are', 'case', 'There'),
#   ('are', 'There', 'case')],
#  [('There', 'no', 'are'),
#   ('are', 'There', 'no'),
#   ('are', 'no', 'There'),
#   ('no', 'There', 'are'),
#   ('no', 'are', 'There')],
#  [('are', 'dividend', 'no'),
#   ('no', 'are', 'dividend'),
#   ('no', 'dividend', 'are'),
#   ('dividend', 'are', 'no'),
#   ('dividend', 'no', 'are')],
#  [('no', 'payments', 'dividend'),
#   ('dividend', 'no', 'payments'),
#   ('dividend', 'payments', 'no'),
#   ('payments', 'no', 'dividend'),
#   ('payments', 'dividend', 'no')],
#  [('dividend', 'Portfolio', 'payments'),
#   ('payments', 'dividend', 'Portfolio'),
#   ('payments', 'Portfolio', 'dividend'),
#   ('Portfolio', 'dividend', 'payments'),
#   ('Portfolio', 'payments', 'dividend')],
#  [('payments', 'long', 'Portfolio'),
#   ('Portfolio', 'payments', 'long'),
#   ('Portfolio', 'long', 'payments'),
#   ('long', 'payments', 'Portfolio'),
#   ('long', 'Portfolio', 'payments')],
#  [('Portfolio', 'position', 'long'),
#   ('long', 'Portfolio', 'position'),
#   ('long', 'position', 'Portfolio'),
#   ('position', 'Portfolio', 'long'),
#   ('position', 'long', 'Portfolio')],
#  [('long', 'in', 'position'),
#   ('position', 'long', 'in'),
#   ('position', 'in', 'long'),
#   ('in', 'long', 'position'),
#   ('in', 'position', 'long')],
#  [('position', 'forward', 'in'),
#   ('in', 'position', 'forward'),
#   ('in', 'forward', 'position'),
#   ('forward', 'position', 'in'),
#   ('forward', 'in', 'position')],
#  [('in', 'contract', 'forward'),
#   ('forward', 'in', 'contract'),
#   ('forward', 'contract', 'in'),
#   ('contract', 'in', 'forward'),
#   ('contract', 'forward', 'in')],
#  [('forward', 'with', 'contract'),
#   ('contract', 'forward', 'with'),
#   ('contract', 'with', 'forward'),
#   ('with', 'forward', 'contract'),
#   ('with', 'contract', 'forward')],
#  [('contract', 'strike', 'with'),
#   ('with', 'contract', 'strike'),
#   ('with', 'strike', 'contract'),
#   ('strike', 'contract', 'with'),
#   ('strike', 'with', 'contract')],
#  [('with', 'maturity', 'strike'),
#   ('strike', 'with', 'maturity'),
#   ('strike', 'maturity', 'with'),
#   ('maturity', 'with', 'strike'),
#   ('maturity', 'strike', 'with')],
#  [('strike', 'date', 'maturity'),
#   ('maturity', 'strike', 'date'),
#   ('maturity', 'date', 'strike'),
#   ('date', 'strike', 'maturity'),
#   ('date', 'maturity', 'strike')],
#  [('maturity', 'and', 'date'),
#   ('date', 'maturity', 'and'),
#   ('date', 'and', 'maturity'),
#   ('and', 'maturity', 'date'),
#   ('and', 'date', 'maturity')],
#  [('date', 'long', 'and'),
#   ('and', 'date', 'long'),
#   ('and', 'long', 'date'),
#   ('long', 'date', 'and'),
#   ('long', 'and', 'date')],
#  [('and', 'position', 'long'),
#   ('long', 'and', 'position'),
#   ('long', 'position', 'and'),
#   ('position', 'and', 'long'),
#   ('position', 'long', 'and')],
#  [('long', 'in', 'position'),
#   ('position', 'long', 'in'),
#   ('position', 'in', 'long'),
#   ('in', 'long', 'position'),
#   ('in', 'position', 'long')],
#  [('position', 'zero', 'in'),
#   ('in', 'position', 'zero'),
#   ('in', 'zero', 'position'),
#   ('zero', 'position', 'in'),
#   ('zero', 'in', 'position')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'We', 'Management'),
#   ('Management', 'Option', 'We'),
#   ('Management', 'We', 'Option'),
#   ('We', 'Option', 'Management'),
#   ('We', 'Management', 'Option')],
#  [('Management', 'have', 'We'),
#   ('We', 'Management', 'have'),
#   ('We', 'have', 'Management'),
#   ('have', 'Management', 'We'),
#   ('have', 'We', 'Management')],
#  [('We', 'to', 'have'),
#   ('have', 'We', 'to'),
#   ('have', 'to', 'We'),
#   ('to', 'We', 'have'),
#   ('to', 'have', 'We')],
#  [('have', 'show', 'to'),
#   ('to', 'have', 'show'),
#   ('to', 'show', 'have'),
#   ('show', 'have', 'to'),
#   ('show', 'to', 'have')],
#  [('to', 'that', 'show'),
#   ('show', 'to', 'that'),
#   ('show', 'that', 'to'),
#   ('that', 'to', 'show'),
#   ('that', 'show', 'to')],
#  [('show', 'VFt', 'that'),
#   ('that', 'show', 'VFt'),
#   ('that', 'VFt', 'show'),
#   ('VFt', 'show', 'that'),
#   ('VFt', 'that', 'show')],
#  [('that', 'uni', 'VFt'),
#   ('VFt', 'that', 'uni'),
#   ('VFt', 'uni', 'that'),
#   ('uni', 'that', 'VFt'),
#   ('uni', 'VFt', 'that')],
#  [('VFt', 'Inserting', 'uni'),
#   ('uni', 'VFt', 'Inserting'),
#   ('uni', 'Inserting', 'VFt'),
#   ('Inserting', 'VFt', 'uni'),
#   ('Inserting', 'uni', 'VFt')],
#  [('uni', 'in', 'Inserting'),
#   ('Inserting', 'uni', 'in'),
#   ('Inserting', 'in', 'uni'),
#   ('in', 'uni', 'Inserting'),
#   ('in', 'Inserting', 'uni')],
#  [('Inserting', 'for', 'in'),
#   ('in', 'Inserting', 'for'),
#   ('in', 'for', 'Inserting'),
#   ('for', 'Inserting', 'in'),
#   ('for', 'in', 'Inserting')],
#  [('in', 'yields', 'for'),
#   ('for', 'in', 'yields'),
#   ('for', 'yields', 'in'),
#   ('yields', 'in', 'for'),
#   ('yields', 'for', 'in')],
#  [('for', 'FT', 'yields'),
#   ('yields', 'for', 'FT'),
#   ('yields', 'FT', 'for'),
#   ('FT', 'for', 'yields'),
#   ('FT', 'yields', 'for')],
#  [('yields', 'Stet', 'FT'),
#   ('FT', 'yields', 'Stet'),
#   ('FT', 'Stet', 'yields'),
#   ('Stet', 'yields', 'FT'),
#   ('Stet', 'FT', 'yields')],
#  [('FT', 'uni', 'Stet'),
#   ('Stet', 'FT', 'uni'),
#   ('Stet', 'uni', 'FT'),
#   ('uni', 'FT', 'Stet'),
#   ('uni', 'Stet', 'FT')],
#  [('Stet', 'KThus', 'uni'),
#   ('uni', 'Stet', 'KThus'),
#   ('uni', 'KThus', 'Stet'),
#   ('KThus', 'Stet', 'uni'),
#   ('KThus', 'uni', 'Stet')],
#  [('uni', 'and', 'KThus'),
#   ('KThus', 'uni', 'and'),
#   ('KThus', 'and', 'uni'),
#   ('and', 'uni', 'KThus'),
#   ('and', 'KThus', 'uni')],
#  [('KThus', 'hence', 'and'),
#   ('and', 'KThus', 'hence'),
#   ('and', 'hence', 'KThus'),
#   ('hence', 'KThus', 'and'),
#   ('hence', 'and', 'KThus')],
#  [('and', 'VFt', 'hence'),
#   ('hence', 'and', 'VFt'),
#   ('hence', 'VFt', 'and'),
#   ('VFt', 'and', 'hence'),
#   ('VFt', 'hence', 'and')],
#  [('hence', 'St', 'VFt'),
#   ('VFt', 'hence', 'St'),
#   ('VFt', 'St', 'hence'),
#   ('St', 'hence', 'VFt'),
#   ('St', 'VFt', 'hence')],
#  [('VFt', 'uni', 'St'),
#   ('St', 'VFt', 'uni'),
#   ('St', 'uni', 'VFt'),
#   ('uni', 'VFt', 'St'),
#   ('uni', 'St', 'VFt')],
#  [('St', 'Ste−r', 'uni'),
#   ('uni', 'St', 'Ste−r'),
#   ('uni', 'Ste−r', 'St'),
#   ('Ste−r', 'St', 'uni'),
#   ('Ste−r', 'uni', 'St')],
#  [('uni', 'uni', 'Ste−r'),
#   ('Ste−r', 'uni', 'uni'),
#   ('Ste−r', 'uni', 'uni'),
#   ('uni', 'uni', 'Ste−r'),
#   ('uni', 'Ste−r', 'uni')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'cases', 'Management'),
#   ('Management', 'Option', 'cases'),
#   ('Management', 'cases', 'Option'),
#   ('cases', 'Option', 'Management'),
#   ('cases', 'Management', 'Option')],
#  [('Management', 'and', 'cases'),
#   ('cases', 'Management', 'and'),
#   ('cases', 'and', 'Management'),
#   ('and', 'Management', 'cases'),
#   ('and', 'cases', 'Management')],
#  [('cases', 'Assume', 'and'),
#   ('and', 'cases', 'Assume'),
#   ('and', 'Assume', 'cases'),
#   ('Assume', 'cases', 'and'),
#   ('Assume', 'and', 'cases')],
#  [('and', 'the', 'Assume'),
#   ('Assume', 'and', 'the'),
#   ('Assume', 'the', 'and'),
#   ('the', 'and', 'Assume'),
#   ('the', 'Assume', 'and')],
#  [('Assume', 'asset', 'the'),
#   ('the', 'Assume', 'asset'),
#   ('the', 'asset', 'Assume'),
#   ('asset', 'Assume', 'the'),
#   ('asset', 'the', 'Assume')],
#  [('the', 'pays', 'asset'),
#   ('asset', 'the', 'pays'),
#   ('asset', 'pays', 'the'),
#   ('pays', 'the', 'asset'),
#   ('pays', 'asset', 'the')],
#  [('asset', 'discrete', 'pays'),
# ...
#   ('max', 'is', 'put')],
#  [('is', 'ST−K', 'max'),
#   ('max', 'is', 'ST−K'),
#   ('max', 'ST−K', 'is'),
#   ('ST−K', 'is', 'max'),
#   ('ST−K', 'max', 'is')],
#  [('max', 'max', 'ST−K'),
#   ('ST−K', 'max', 'max'),
#   ('ST−K', 'max', 'max'),
#   ('max', 'max', 'ST−K'),
#   ('max', 'ST−K', 'max')],
#  [('ST−K', 'K−ST', 'max'),
#   ('max', 'ST−K', 'K−ST'),
#   ('max', 'K−ST', 'ST−K'),
#   ('K−ST', 'ST−K', 'max'),
#   ('K−ST', 'max', 'ST−K')],
#  [('max', 'Intrinsic', 'K−ST'),
#   ('K−ST', 'max', 'Intrinsic'),
#   ('K−ST', 'Intrinsic', 'max'),
#   ('Intrinsic', 'max', 'K−ST'),
#   ('Intrinsic', 'K−ST', 'max')],
#  [('K−ST', 'value', 'Intrinsic'),
#   ('Intrinsic', 'K−ST', 'value'),
#   ('Intrinsic', 'value', 'K−ST'),
#   ('value', 'K−ST', 'Intrinsic'),
#   ('value', 'Intrinsic', 'K−ST')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'In', 'Management'),
#   ('Management', 'Option', 'In'),
#   ('Management', 'In', 'Option'),
#   ('In', 'Option', 'Management'),
#   ('In', 'Management', 'Option')],
#  [('Management', 'the', 'In'),
#   ('In', 'Management', 'the'),
#   ('In', 'the', 'Management'),
#   ('the', 'Management', 'In'),
#   ('the', 'In', 'Management')],
#  [('In', 'money', 'the'),
#   ('the', 'In', 'money'),
#   ('the', 'money', 'In'),
#   ('money', 'In', 'the'),
#   ('money', 'the', 'In')],
#  [('the', 'ITM', 'money'),
#   ('money', 'the', 'ITM'),
#   ('money', 'ITM', 'the'),
#   ('ITM', 'the', 'money'),
#   ('ITM', 'money', 'the')],
#  [('money', 'An', 'ITM'),
#   ('ITM', 'money', 'An'),
#   ('ITM', 'An', 'money'),
#   ('An', 'money', 'ITM'),
#   ('An', 'ITM', 'money')],
#  [('ITM', 'option', 'An'),
#   ('An', 'ITM', 'option'),
#   ('An', 'option', 'ITM'),
#   ('option', 'ITM', 'An'),
#   ('option', 'An', 'ITM')],
#  [('An', 'is', 'option'),
#   ('option', 'An', 'is'),
#   ('option', 'is', 'An'),
#   ('is', 'An', 'option'),
#   ('is', 'option', 'An')],
#  [('option', 'called', 'is'),
#   ('is', 'option', 'called'),
#   ('is', 'called', 'option'),
#   ('called', 'option', 'is'),
#   ('called', 'is', 'option')],
#  [('is', 'ITM', 'called'),
#   ('called', 'is', 'ITM'),
#   ('called', 'ITM', 'is'),
#   ('ITM', 'is', 'called'),
#   ('ITM', 'called', 'is')],
#  [('called', 'if', 'ITM'),
#   ('ITM', 'called', 'if'),
#   ('ITM', 'if', 'called'),
#   ('if', 'called', 'ITM'),
#   ('if', 'ITM', 'called')],
#  [('ITM', 'its', 'if'),
#   ('if', 'ITM', 'its'),
#   ('if', 'its', 'ITM'),
#   ('its', 'ITM', 'if'),
#   ('its', 'if', 'ITM')],
#  [('if', 'intrinsic', 'its'),
#   ('its', 'if', 'intrinsic'),
#   ('its', 'intrinsic', 'if'),
#   ('intrinsic', 'if', 'its'),
#   ('intrinsic', 'its', 'if')],
#  [('its', 'value', 'intrinsic'),
#   ('intrinsic', 'its', 'value'),
#   ('intrinsic', 'value', 'its'),
#   ('value', 'its', 'intrinsic'),
#   ('value', 'intrinsic', 'its')],
#  [('intrinsic', 'is', 'value'),
#   ('value', 'intrinsic', 'is'),
#   ('value', 'is', 'intrinsic'),
#   ('is', 'intrinsic', 'value'),
#   ('is', 'value', 'intrinsic')],
#  [('value', 'nonzero', 'is'),
#   ('is', 'value', 'nonzero'),
#   ('is', 'nonzero', 'value'),
#   ('nonzero', 'value', 'is'),
#   ('nonzero', 'is', 'value')],
#  [('is', 'At', 'nonzero'),
#   ('nonzero', 'is', 'At'),
#   ('nonzero', 'At', 'is'),
#   ('At', 'is', 'nonzero'),
#   ('At', 'nonzero', 'is')],
#  [('nonzero', 'the', 'At'),
#   ('At', 'nonzero', 'the'),
#   ('At', 'the', 'nonzero'),
#   ('the', 'nonzero', 'At'),
#   ('the', 'At', 'nonzero')],
#  [('At', 'money', 'the'),
#   ('the', 'At', 'money'),
#   ('the', 'money', 'At'),
#   ('money', 'At', 'the'),
#   ('money', 'the', 'At')],
#  [('the', 'ATM', 'money'),
#   ('money', 'the', 'ATM'),
#   ('money', 'ATM', 'the'),
#   ('ATM', 'the', 'money'),
#   ('ATM', 'money', 'the')],
#  [('money', 'An', 'ATM'),
#   ('ATM', 'money', 'An'),
#   ('ATM', 'An', 'money'),
#   ('An', 'money', 'ATM'),
#   ('An', 'ATM', 'money')],
#  [('ATM', 'option', 'An'),
#   ('An', 'ATM', 'option'),
#   ('An', 'option', 'ATM'),
#   ('option', 'ATM', 'An'),
#   ('option', 'An', 'ATM')],
#  [('An', 'is', 'option'),
#   ('option', 'An', 'is'),
#   ('option', 'is', 'An'),
#   ('is', 'An', 'option'),
#   ('is', 'option', 'An')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', 'YElementary', 'Management'),
#   ('Management', 'Option', 'YElementary'),
#   ('Management', 'YElementary', 'Option'),
#   ('YElementary', 'Option', 'Management'),
#   ('YElementary', 'Management', 'Option')],
#  [('Management', 'Properties', 'YElementary'),
#   ('YElementary', 'Management', 'Properties'),
#   ('YElementary', 'Properties', 'Management'),
#   ('Properties', 'Management', 'YElementary'),
#   ('Properties', 'YElementary', 'Management')],
#  [('YElementary', 'of', 'Properties'),
#   ('Properties', 'YElementary', 'of'),
#   ('Properties', 'of', 'YElementary'),
#   ('of', 'YElementary', 'Properties'),
#   ('of', 'Properties', 'YElementary')],
#  [('Properties', 'Option', 'of'),
#   ('of', 'Properties', 'Option'),
#   ('of', 'Option', 'Properties'),
#   ('Option', 'Properties', 'of'),
#   ('Option', 'of', 'Properties')],
#  [('of', 'Prices', 'Option'),
#   ('Option', 'of', 'Prices'),
#   ('Option', 'Prices', 'of'),
#   ('Prices', 'of', 'Option'),
#   ('Prices', 'Option', 'of')],
#  [('Option', '⊡option', 'Prices'),
#   ('Prices', 'Option', '⊡option'),
#   ('Prices', '⊡option', 'Option'),
#   ('⊡option', 'Option', 'Prices'),
#   ('⊡option', 'Prices', 'Option')],
#  [('Prices', 'prices', '⊡option'),
#   ('⊡option', 'Prices', 'prices'),
#   ('⊡option', 'prices', 'Prices'),
#   ('prices', 'Prices', '⊡option'),
#   ('prices', '⊡option', 'Prices')],
#  [('⊡option', 'are', 'prices'),
#   ('prices', '⊡option', 'are'),
#   ('prices', 'are', '⊡option'),
#   ('are', '⊡option', 'prices'),
#   ('are', 'prices', '⊡option')],
#  [('prices', 'non', 'are'),
#   ('are', 'prices', 'non'),
#   ('are', 'non', 'prices'),
#   ('non', 'prices', 'are'),
#   ('non', 'are', 'prices')],
#  [('are', 'negative', 'non'),
#   ('non', 'are', 'negative'),
#   ('non', 'negative', 'are'),
#   ('negative', 'are', 'non'),
#   ('negative', 'non', 'are')],
#  [('non', '⊡the', 'negative'),
#   ('negative', 'non', '⊡the'),
#   ('negative', '⊡the', 'non'),
#   ('⊡the', 'non', 'negative'),
#   ('⊡the', 'negative', 'non')],
#  [('negative', 'price', '⊡the'),
#   ('⊡the', 'negative', 'price'),
#   ('⊡the', 'price', 'negative'),
#   ('price', 'negative', '⊡the'),
#   ('price', '⊡the', 'negative')],
#  [('⊡the', 'of', 'price'),
#   ('price', '⊡the', 'of'),
#   ('price', 'of', '⊡the'),
#   ('of', '⊡the', 'price'),
#   ('of', 'price', '⊡the')],
#  [('price', 'European', 'of'),
#   ('of', 'price', 'European'),
#   ('of', 'European', 'price'),
#   ('European', 'price', 'of'),
#   ('European', 'of', 'price')],
#  [('of', 'option', 'European'),
#   ('European', 'of', 'option'),
#   ('European', 'option', 'of'),
#   ('option', 'of', 'European'),
#   ('option', 'European', 'of')],
#  [('European', 'at', 'option'),
#   ('option', 'European', 'at'),
#   ('option', 'at', 'European'),
#   ('at', 'European', 'option'),
#   ('at', 'option', 'European')],
#  [('option', 'maturity', 'at'),
#   ('at', 'option', 'maturity'),
#   ('at', 'maturity', 'option'),
#   ('maturity', 'option', 'at'),
#   ('maturity', 'at', 'option')],
#  [('at', 'is', 'maturity'),
#   ('maturity', 'at', 'is'),
#   ('maturity', 'is', 'at'),
#   ('is', 'at', 'maturity'),
#   ('is', 'maturity', 'at')],
#  [('maturity', 'equal', 'is'),
#   ('is', 'maturity', 'equal'),
#   ('is', 'equal', 'maturity'),
#   ('equal', 'maturity', 'is'),
#   ('equal', 'is', 'maturity')],
#  [('is', 'to', 'equal'),
#   ('equal', 'is', 'to'),
#   ('equal', 'to', 'is'),
#   ('to', 'is', 'equal'),
#   ('to', 'equal', 'is')],
#  [('equal', 'the', 'to'),
#   ('to', 'equal', 'the'),
#   ('to', 'the', 'equal'),
#   ('the', 'equal', 'to'),
#   ('the', 'to', 'equal')],
#  [('to', 'price', 'the'),
#   ('the', 'to', 'price'),
#   ('the', 'price', 'to'),
#   ('price', 'to', 'the'),
#   ('price', 'the', 'to')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', '⊡for', 'Management'),
#   ('Management', 'Option', '⊡for'),
#   ('Management', '⊡for', 'Option'),
#   ('⊡for', 'Option', 'Management'),
#   ('⊡for', 'Management', 'Option')],
#  [('Management', 'two', '⊡for'),
#   ('⊡for', 'Management', 'two'),
#   ('⊡for', 'two', 'Management'),
#   ('two', 'Management', '⊡for'),
#   ('two', '⊡for', 'Management')],
#  [('⊡for', 'American', 'two'),
#   ('two', '⊡for', 'American'),
#   ('two', 'American', '⊡for'),
#   ('American', '⊡for', 'two'),
#   ('American', 'two', '⊡for')],
#  [('two', 'options', 'American'),
#   ('American', 'two', 'options'),
#   ('American', 'options', 'two'),
#   ('options', 'two', 'American'),
#   ('options', 'American', 'two')],
#  [('American', 'and', 'options'),
#   ('options', 'American', 'and'),
#   ('options', 'and', 'American'),
#   ('and', 'American', 'options'),
#   ('and', 'options', 'American')],
#  [('options', 'differing', 'and'),
#   ('and', 'options', 'differing'),
#   ('and', 'differing', 'options'),
#   ('differing', 'options', 'and'),
#   ('differing', 'and', 'options')],
#  [('and', 'only', 'differing'),
#   ('differing', 'and', 'only'),
#   ('differing', 'only', 'and'),
#   ('only', 'and', 'differing'),
#   ('only', 'differing', 'and')],
#  [('differing', 'by', 'only'),
#   ('only', 'differing', 'by'),
#   ('only', 'by', 'differing'),
#   ('by', 'differing', 'only'),
#   ('by', 'only', 'differing')],
#  [('only', 'time', 'by'),
#   ('by', 'only', 'time'),
#   ('by', 'time', 'only'),
#   ('time', 'only', 'by'),
#   ('time', 'by', 'only')],
#  [('by', 'to', 'time'),
#   ('time', 'by', 'to'),
#   ('time', 'to', 'by'),
#   ('to', 'by', 'time'),
#   ('to', 'time', 'by')],
#  [('time', 'maturity', 'to'),
#   ('to', 'time', 'maturity'),
#   ('to', 'maturity', 'time'),
#   ('maturity', 'time', 'to'),
#   ('maturity', 'to', 'time')],
#  [('to', 'the', 'maturity'),
#   ('maturity', 'to', 'the'),
#   ('maturity', 'the', 'to'),
#   ('the', 'to', 'maturity'),
#   ('the', 'maturity', 'to')],
#  [('maturity', 'following', 'the'),
#   ('the', 'maturity', 'following'),
#   ('the', 'following', 'maturity'),
#   ('following', 'maturity', 'the'),
#   ('following', 'the', 'maturity')],
#  [('the', 'holds', 'following'),
#   ('following', 'the', 'holds'),
#   ('following', 'holds', 'the'),
#   ('holds', 'the', 'following'),
#   ('holds', 'following', 'the')],
#  [('following', 'Cam', 'holds'),
#   ('holds', 'following', 'Cam'),
#   ('holds', 'Cam', 'following'),
#   ('Cam', 'following', 'holds'),
#   ('Cam', 'holds', 'following')],
#  [('holds', 'Cam', 'Cam'),
#   ('Cam', 'holds', 'Cam'),
#   ('Cam', 'Cam', 'holds'),
#   ('Cam', 'holds', 'Cam'),
#   ('Cam', 'Cam', 'holds')],
#  [('Cam', 'uni', 'Cam'),
#   ('Cam', 'Cam', 'uni'),
#   ('Cam', 'uni', 'Cam'),
#   ('uni', 'Cam', 'Cam'),
#   ('uni', 'Cam', 'Cam')],
#  [('Cam', 'CamK', 'uni'),
#   ('uni', 'Cam', 'CamK'),
#   ('uni', 'CamK', 'Cam'),
#   ('CamK', 'Cam', 'uni'),
#   ('CamK', 'uni', 'Cam')],
#  [('uni', 'St', 'CamK'),
#   ('CamK', 'uni', 'St'),
#   ('CamK', 'St', 'uni'),
#   ('St', 'uni', 'CamK'),
#   ('St', 'CamK', 'uni')],
#  [('CamK', '−t', 'St'),
#   ('St', 'CamK', '−t'),
#   ('St', '−t', 'CamK'),
#   ('−t', 'CamK', 'St'),
#   ('−t', 'St', 'CamK')],
#  [('St', 'uni', '−t'),
#   ('−t', 'St', 'uni'),
#   ('−t', 'uni', 'St'),
#   ('uni', 'St', '−t'),
#   ('uni', '−t', 'St')],
#  [('−t', 'CamK', 'uni'),
#   ('uni', '−t', 'CamK'),
#   ('uni', 'CamK', '−t'),
#   ('CamK', '−t', 'uni'),
#   ('CamK', 'uni', '−t')],
#  [('SFEThe', 'of', 'Basics'),
#   ('Basics', 'SFEThe', 'of'),
#   ('Basics', 'of', 'SFEThe'),
#   ('of', 'SFEThe', 'Basics'),
#   ('of', 'Basics', 'SFEThe')],
#  [('Basics', 'Option', 'of'),
#   ('of', 'Basics', 'Option'),
#   ('of', 'Option', 'Basics'),
#   ('Option', 'Basics', 'of'),
#   ('Option', 'of', 'Basics')],
#  [('of', 'Management', 'Option'),
#   ('Option', 'of', 'Management'),
#   ('Option', 'Management', 'of'),
#   ('Management', 'of', 'Option'),
#   ('Management', 'Option', 'of')],
#  [('Option', '⊡the', 'Management'),
#   ('Management', 'Option', '⊡the'),
#   ('Management', '⊡the', 'Option'),
#   ('⊡the', 'Option', 'Management'),
#   ('⊡the', 'Management', 'Option')],
#  [('Management', 'price', '⊡the'),
#   ('⊡the', 'Management', 'price'),
#   ('⊡the', 'price', 'Management'),
#   ('price', 'Management', '⊡the'),
#   ('price', '⊡the', 'Management')],
#  [('⊡the', 'of', 'price'),
#   ('price', '⊡the', 'of'),
#   ('price', 'of', '⊡the'),
#   ('of', '⊡the', 'price'),
#   ('of', 'price', '⊡the')],
#  [('price', 'an', 'of'),
#   ('of', 'price', 'an'),
#   ('of', 'an', 'price'),
#   ('an', 'price', 'of'),
#   ('an', 'of', 'price')],
#  [('of', 'American', 'an'),
#   ('an', 'of', 'American'),
#   ('an', 'American', 'of'),
#   ('American', 'of', 'an'),
#   ('American', 'an', 'of')],
#  [('an', 'option', 'American'),
#   ('American', 'an', 'option'),
#   ('American', 'option', 'an'),
#   ('option', 'an', 'American'),
#   ('option', 'American', 'an')],
#  [('American', 'is', 'option'),
#   ('option', 'American', 'is'),
#   ('option', 'is', 'American'),
#   ('is', 'American', 'option'),
#   ('is', 'option', 'American')],
#  [('option', 'always', 'is'),
#   ('is', 'option', 'always'),
#   ('is', 'always', 'option'),
#   ('always', 'option', 'is'),
#   ('always', 'is', 'option')],
#  [('is', 'bigger', 'always'),
#   ('always', 'is', 'bigger'),
#   ('always', 'bigger', 'is'),
#   ('bigger', 'is', 'always'),
#   ('bigger', 'always', 'is')],
#  [('always', 'than', 'bigger'),
#   ('bigger', 'always', 'than'),
#   ('bigger', 'than', 'always'),
#   ('than', 'always', 'bigger'),
#   ('than', 'bigger', 'always')],
#  [('bigger', 'or', 'than'),
#   ('than', 'bigger', 'or'),
#   ('than', 'or', 'bigger'),
#   ('or', 'bigger', 'than'),
#   ('or', 'than', 'bigger')],
#  [('than', 'equal', 'or'),
#   ('or', 'than', 'equal'),
#   ('or', 'equal', 'than'),
#   ('equal', 'than', 'or'),
#   ('equal', 'or', 'than')],
#  [('or', 'to', 'equal'),
#   ('equal', 'or', 'to'),
#   ('equal', 'to', 'or'),
#   ('to', 'or', 'equal'),
#   ('to', 'equal', 'or')],
#  [('equal', 'the', 'to'),
#   ('to', 'equal', 'the'),
#   ('to', 'the', 'equal'),
#   ('the', 'equal', 'to'),
#   ('the', 'to', 'equal')],
#  [('to', 'price', 'the'),
#   ('the', 'to', 'price'),
#   ('the', 'price', 'to'),
#   ('price', 'to', 'the'),
#   ('price', 'the', 'to')],
#  [('the', 'of', 'price'),
#   ('price', 'the', 'of'),
#   ('price', 'of', 'the'),
#   ('of', 'the', 'price'),
#   ('of', 'price', 'the')],
#  [('price', 'the', 'of'),
#   ('of', 'price', 'the'),
#   ('of', 'the', 'price'),
#   ('the', 'price', 'of'),
#   ('the', 'of', 'price')],
#  [('of', 'corresponding', 'the'),
#   ('the', 'of', 'corresponding'),
#   ('the', 'corresponding', 'of'),
#   ('corresponding', 'of', 'the'),
#   ('corresponding', 'the', 'of')],
#  [('the', 'European', 'corresponding'),
#   ('corresponding', 'the', 'European'),
#   ('corresponding', 'European', 'the'),
#   ('European', 'the', 'corresponding'),
#   ('European', 'corresponding', 'the')],
#  [('corresponding', 'option', 'European'),
#   ('European', 'corresponding', 'option'),
#   ('European', 'option', 'corresponding'),
#   ('option', 'corresponding', 'European'),
#   ('option', 'European', 'corresponding')],
#  [('European', '⊡call', 'option'),
#   ('option', 'European', '⊡call'),
#   ('option', '⊡call', 'European'),
#   ('⊡call', 'European', 'option'),
#   ('⊡call', 'option', 'European')],
#  [('option', 'prices', '⊡call'),
#   ('⊡call', 'option', 'prices'),
#   ('⊡call', 'prices', 'option'),
#   ('prices', 'option', '⊡call'),
#   ('prices', '⊡call', 'option')]]

# %%
three_word_set = set(list(chain(*three_word_list)))
three_word_set
# Out:
# {('for', 'that', 'Suppose'),
#  ('will', 'there', 'in'),
#  ('Management', 'is', 'If'),
#  ('the', 'during', 'constant'),
#  ('yields', 'for', 'in'),
#  ('European', 'corresponding', 'the'),
#  ('that', 'value', 'and'),
#  ('of', 'Professor', 'Bortkiewicz'),
#  ('risk', 'less', 'be'),
#  ('the', 'in', 'position'),
#  ('remainder', 'for', 'the'),
#  ('be', 'considered', 'to'),
#  ('from', 'Continuous', 'now'),
#  ('we', 'payment', 'change'),
#  ('day', 'yields', 'of'),
#  ('St', 'uni', 'CamK'),
#  ('current', 'with', 'and'),
#  ('VFt', 'and', 'hence'),
#  ('some', 'terminal', 'the'),
#  ('price', 'date', 'Underlying'),
#  ('time', 'at', 'we'),
#  ('dividends\nThen', 'the', 'continuous'),
#  ('zero', 'position', 'in'),
#  ('the', 'related', 'to'),
#  ('portfolios', 'with', '⊡two'),
#  ('every', 'the', 'day'),
#  ('put', 'max', 'is'),
#  ('dividend', 'no', 'are'),
#  ('from', 'months', 'now'),
#  ('interest', '⊡no', 'rate'),
#  ('premium', 'discount', 'if'),
#  ('of', 'beginning', 'the'),
#  ('consider', 'portfolio', 'Now'),
#  ('at', 'day', 'zero'),
#  ('all', 'payments', 'dividend'),
#  ('NN', 'is', 'uni'),
#  ('and', 'only', 'differing'),
#  ('differing', 'by', 'only'),
#  ('its', 'ITM', 'if'),
#  ('always', 'than', 'bigger'),
#  ('and', 'related', 'costs'),
#  ('forward', 'the', 'and'),
#  ('rate', 'constant', 'interest'),
#  ('Price', 'Management', 'Option'),
#  ('uni', 'Fte−r', 'uni'),
#  ('Statistics', 'Humboldt', 'of'),
#  ('of', 'yields', 'day'),
#  ('and', 'discount', 'If'),
#  ('be', 'could', 'even'),
#  ('Portfolio', 'dividend', 'payments'),
#  ('be', 'to', 'have'),
#  ('assumption', 'the', 'additional'),
#  ('be', 'have', 'to'),
#  ('Center', 'Research', 'lvb'),
#  ('the', 'interval', 'following'),
#  ('forward', 'price', 'the'),
#  ('long', 'date', 'and'),
#  ('Franke', 'Jürgen', '⽟⼭學者'),
#  ('After', 'day', 'Portfolio'),
#  ('the', 'with', 'portfolios'),
#  ('rate', '⊡no', 'interest'),
#  ('value', 'is', 'the'),
#  ('Management', 'Properties', 'YElementary'),
#  ('in', 'position', 'zerobond'),
#  ('Proposition', 'Option', 'Management'),
#  ('and', 'short', 'asset'),
#  ('time', 'at', 'Price'),
#  ('asset', 'Assume', 'the'),
#  ('buy', 'shares', 'Portfolio'),
#  ('respectively', 'that', 'Suppose'),
#  ('in', 'position', 'forward'),
#  ('St', 'KTStVK', 'contract'),
#  ('to', 'or', 'equal'),
#  ('forward', 'Price', 'of'),
#  ('shares', 'Portfolio', 'buy'),
#  ('have', 'zerobonds', 'of'),
#  ('at', 'time', 'Price'),
#  ('contract', 'continuous', 'with'),
#  ('Theory', 'YArbitrage', 'Management'),
#  ('long', 'Portfolio', 'payments'),
#  ('Maturity', 'price', 'Delivery'),
#  ('dividendsCoupon', 'of', 'payments'),
#  ('unlimitedly', 'are', '⊡stocks'),
#  ('during', 'underlying', 'the'),
#  ('contracts', 'with', 'future'),
#  ('is', 'selling', '⊡short'),
#  ('for', 'remainder', 'the'),
#  ('Management', 'YArbitrage', 'Option'),
#  ('call', 'The', 'is'),
#  ('contract', 'of', 'the'),
#  ('⊡buy', 'sell', 'and'),
#  ('dividend', 'are', 'no'),
#  ('VFt', 'St', 'hence'),
#  ('return', 'day', 'on'),
#  ('at', 'option', 'European'),
#  ('contract', 'St', 'KTStVK'),
#  ('of', 'asset', 'the'),
#  ('Theory', '⊡buy', 'YArbitrage'),
#  ('price', '⊡the', 'of'),
#  ('There', 'case', 'Proof'),
#  ('The', 'payoff', 'functions'),
#  ('Suppose', 'that', 'respectively'),
#  ('is', 'put', 'max'),
#  ('following', 'interval', 'the'),
#  ('Management', 'Option', 'Basic'),
#  ('to', 'the', 'related'),
#  ('An', 'option', 'ATM'),
#  ('max', 'put', 'is'),
#  ('Portfolio', 'Management', 'Option'),
#  ('Basics', 'Chapter', 'The'),
#  ('Delivery', 'Maturity', 'price'),
#  ('date', 'long', 'and'),
#  ('called', 'is', 'ITM'),
#  ('for', 'in', 'yields'),
#  ('underlying', 'the', 'during'),
#  ('the', 'expiration', 'at'),
#  ('some', 'for', 'the'),
#  ('of', 'principle', 'no'),
#  ('with', 'strike', 'contract'),
#  ('is', 'payoff', 'The'),
#  ('payoff', 'is', 'The'),
#  ('portfolio', 'with', 'consider'),
#  ('of', 'Properties', 'YElementary'),
#  ('Berlin', 'Universität', 'zu'),
#  ('two', 'Management', 'Consider'),
#  ('Management', 'Option', 'YPerfect'),
#  ('functions', 'The', 'Payoff'),
#  ('payment', 'we', 'dividend'),
#  ('are', 'price', 'forward'),
#  ('changes', 'Since', 'in'),
#  ('uni', '−t', 'CamK'),
#  ('respectively', 'value', 'and'),
#  ('not', 'permit', 'must'),
#  ('option', 'is', 'American'),
#  ('only', 'differing', 'and'),
#  ('contracts', 'future', 'with'),
#  ('we', 'continuous', 'have'),
#  ('Steb', 'Ft', 'uni'),
#  ('at', 'only', 'day'),
#  ('option', 'at', 'European'),
#  ('St', 'hence', 'VFt'),
#  ('YOption', 'Management', 'Pricing'),
#  ('the', 'money', 'In'),
#  ('of', 'in', 'payments'),
#  ('current', 'zerobond', 'with'),
#  ('loss', 'calculation', 'proﬁt'),
#  ('non', 'are', 'prices'),
#  ('two', 'Management', '⊡for'),
#  ('uni', 'uni', 'Ste−r'),
#  ('Management', 'If', 'Option'),
#  ('shares', 'of', 'buy'),
#  ('is', 'day', 'on'),
#  ('Management', 'we', 'If'),
#  ('value', 'all', 'of'),
#  ('de', 'hu', 'berlin'),
#  ('discount', 'If', 'if'),
#  ('contract', 'forward', 'to'),
#  ('in', 'dividend', 'payments'),
#  ('date', 'the', 'expiration'),
#  ('VFt', 'that', 'uni'),
#  ('the', 'price', 'to'),
#  ('price', 'to', 'the'),
#  ('Management', None, ''),
#  ('time', 'we', 'at'),
#  ('lvb', 'Center', 'Research'),
#  ('long', 'Portfolio', 'position'),
#  ('total', 'contains', 'of'),
#  ('at', 'time', 'calculated'),
#  ('position', 'zerobond', 'in'),
#  ('StThus', 'Fte−r', 'uni'),
#  ('prices', 'non', 'are'),
#  ('are', 'negative', 'non'),
#  ('is', 'price', 'forward'),
#  ('continuous', 'have', 'we'),
#  ('price', '⊡the', 'negative'),
#  ('Inserting', 'uni', 'in'),
#  ('dividend', 'all', 'payments'),
#  ('and', 'market', 'the'),
#  ('of', 'dividendsCoupon', 'payments'),
#  ('the', 'of', 'price'),
#  ('interest', 'is', 'rate'),
#  ('the', 'principle', 'violates'),
#  ('and', 'with', 'portfolios'),
#  ('maturity', 'and', 'date'),
#  ('day', 'at', 'only'),
#  ('the', 'price', 'of'),
#  ('related', 'costs', 'and'),
#  ('rate', 'the', 'during'),
#  ('Management', 'Proposition', 'Option'),
#  ('Stet', 'FT', 'uni'),
#  ('for', 'interest', 'rate'),
#  ('every', 'settled', 'are'),
#  ('change', 'we', 'portfolio'),
#  ('ATM', 'money', 'the'),
#  ('dividends', 'pays', 'discrete'),
#  ('are', 'prices', '⊡option'),
#  ('Option', 'YOption', 'Management'),
#  ('prices', 'zerobonds', 'of'),
#  ('Price', 'of', 'Management'),
#  ('and', 'portfolios', 'two'),
#  ('the', 'day', 'at'),
#  ('assumption', 'of', 'additional'),
#  ('ITM', 'if', 'called'),
#  ('the', 'same', 'with'),
#  ('current', 'value', 'same'),
#  ('consider', 'Now', 'Portfolio'),
#  ('arbitrage', 'no', 'of'),
#  ('No', 'remainder', 'the'),
#  ('Portfolio', 'position', 'long'),
#  ('Proof', 'equal', 'are'),
#  ('have', 'we', 'If'),
#  ('future', 'the', 'contract'),
#  ('corresponding', 'the', 'European'),
#  ('taxes', 'costs', '⊡no'),
#  ('uni', 'is', 'NN'),
#  ('forward', 'is', 'price'),
#  ('YOption', 'Pricing', 'Management'),
#  ('de', 'Charles', 'berlin'),
#  ('XMU', 'NYCU', 'WISE'),
#  ('Stet', 'FT', 'yields'),
#  ('to', 'by', 'time'),
#  ('maturity', 'to', 'time'),
#  ('time', 'interval', 'the'),
#  ('risk', 'proﬁt', 'less'),
#  ('of', 'an', 'price'),
#  ('we', 'change', 'payment'),
#  ('during', 'rate', 'interest'),
#  ('Management', 'cases', 'Option'),
#  ('lvb', 'hu', 'wiwi'),
#  ('in', 'Inserting', 'for'),
#  ('of', 'the', 'principle'),
#  ('the', 'maturity', 'following'),
#  ('St', 'Delivery', 'uni'),
#  ('nonzero', 'is', 'value'),
#  ('the', 'of', 'shares'),
#  ('This', 'inﬁnitely', 'rich'),
#  ('hu', 'de', 'berlin'),
#  ('of', 'perfect', 'assumption'),
#  ('loss', 'of', 'calculation'),
#  ('the', 'additional', 'and'),
#  ('in', 'of', 'payments'),
#  ('its', 'if', 'ITM'),
#  ('YArbitrage', 'Management', 'Option'),
#  ('return', 'the', 'cumulative'),
#  ('dividend', 'have', 'continuous'),
#  ('StThus', 'and', 'uni'),
#  ('Consider', 'Management', 'Option'),
#  ('⊡stocks', 'are', 'allowed'),
#  ('an', 'price', 'of'),
#  ('', None, None),
#  ('CamK', '−t', 'St'),
#  ('of', 'all', 'value'),
#  ('to', 'the', 'equal'),
#  ('Price', 'price', 'Underlying'),
#  ('future', 'the', 'and'),
#  ('the', 'money', 'At'),
#  ('by', 'to', 'time'),
#  ('⊡for', 'Management', 'Option'),
#  ('the', 'constant', 'during'),
#  ('Suppose', 'and', 'respectively'),
#  ('⊡no', 'costs', 'transaction'),
#  ('that', 'VFt', 'show'),
#  ('forward', 'with', 'contract'),
#  ('BRC', 'Berlin', 'Blockchain'),
#  ('of', 'the', 'price'),
#  ('changes', 'in', 'Since'),
#  ('de', 'berlin', 'Charles'),
#  ('position', 'the', 'in'),
#  ('Prices', '⊡option', 'Option'),
#  ('case', 'There', 'Proof'),
#  ('asset', 'and', 'the'),
#  ('⊡debit', 'Financial', 'Market'),
#  ('nonzero', 'At', 'is'),
#  ('zu', 'Universität', 'Berlin'),
#  ('of', 'contains', 'total'),
#  ('⊡call', 'prices', 'option'),
#  ('interest', 'rate', 'the'),
#  ('is', 'option', 'An'),
#  ('of', 'at', 'zero'),
#  ('value', 'the', 'is'),
#  ('during', 'time', 'the'),
#  ('of', 'additional', 'assumption'),
#  ('and', 'then', 'If'),
#  ('is', 'intrinsic', 'value'),
#  ('contract', 'Example', 'Forward'),
#  ('⊡call', 'option', 'European'),
#  ('following', 'maturity', 'the'),
#  ('and', 'maturity', 'date'),
#  ('and', 'asset', 'reinvest'),
#  ('prices', 'only', 'the'),
#  ('we', 'time', 'at'),
#  ('of', 'the', 'calculation'),
#  ('change', 'payment', 'we'),
#  ('−t', 'uni', 'St'),
#  ('the', 'position', 'in'),
#  ('St', 'KTStVK', 'uni'),
#  ('interest', '⊡debit', 'Market'),
#  ('NN', 'Ft−Ft−', 'uni'),
#  ('position', 'short', 'and'),
#  ('payment', 'change', 'we'),
#  ('Management', 'Forward', 'Example'),
#  ('months', 'have', 'We'),
#  ('money', 'the', 'ATM'),
#  ('earnings', 'costs', 'and'),
#  ('Underlying', 'price', 'date'),
#  ('of', 'Bortkiewicz', 'Professor'),
#  ('intrinsic', 'is', 'value'),
#  ('arbitrage', 'permit', ''),
#  ('all', 'dividend', 'reinvest'),
#  ('perfect', 'of', 'market'),
#  ('max', 'Intrinsic', 'K−ST'),
#  ('total', 'zerobonds', 'of'),
#  ('At', 'the', 'nonzero'),
#  ('Center', 'lvb', 'Research'),
#  ('YOption', 'Option', 'Management'),
#  ('derivatives', 'of', 'must'),
#  ('Financial', '⊡debit', 'Market'),
#  ('asset', 'the', 'in'),
#  ('Ft', 'then', 'Steb'),
#  ('After', 'Portfolio', 'day'),
#  ('the', 'of', 'maturity'),
#  ('price', 'forward', 'the'),
#  ('price', 'Underlying', 'Price'),
#  ('with', 'contract', 'Forward'),
#  ('are', 'used', 'which'),
#  ('zerobonds', 'of', 'prices'),
#  ('er', 'uni', 'uni'),
#  ('value', 'K−ST', 'Intrinsic'),
#  ('At', 'money', 'the'),
#  ('equal', 'is', 'to'),
#  ('prices', '⊡two', 'different'),
#  ('call', 'is', 'of'),
#  ('in', 'position', 'long'),
#  ('WISE', 'NYCU', 'XMU'),
#  ('violates', 'the', 'This'),
#  ('must', 'permit', 'not'),
#  ('forward', 'are', 'price'),
#  ('max', 'max', 'ST−K'),
#  ('divisible', 'unlimitedly', 'are'),
#  ('of', 'Humboldt', 'Statistics'),
#  ('not', 'must', 'permit'),
#  ('portfolio', 'date', 'contains'),
#  ('asset', 'the', 'and'),
#  ('prices', 'Arbitrage', 'No'),
#  ('zerobond', 'with', 'in'),
#  ('different', 'on', 'asset'),
#  ('⊡for', 'Option', 'Management'),
#  ('Management', 'After', 'Portfolio'),
#  ('the', 'In', 'money'),
#  ('in', 'Management', 'However'),
#  ('an', 'sell', 'and'),
#  ('Payoff', 'functions', 'Pricing'),
#  ('As', 'Option', 'Management'),
#  ('European', 'corresponding', 'option'),
#  ('portfolio', 'expiration', 'date'),
#  ('Option', 'Basics', 'of'),
#  ('For', 'is', 'we'),
#  ('constant', 'the', 'during'),
#  ('with', 'forward', 'contract'),
#  ('ITM', 'called', 'if'),
#  ('the', 'At', 'nonzero'),
#  ('that', 'uni', 'VFt'),
#  ('for', 'the', 'some'),
#  ('long', 'DtPortfolio', 'position'),
#  ('show', 'have', 'to'),
#  ('same', 'current', 'the'),
#  ('be', 'even', 'could'),
#  ('interest', 'Continuous', 'now'),
#  ('payments', 'no', 'dividend'),
#  ('Under', 'Proposition', 'Management'),
#  ('change', 'we', 'payment'),
#  ('option', '⊡call', 'European'),
#  ('Blockchain', 'BRC', 'Berlin'),
#  ('Payoff', 'YOption', 'Pricing'),
#  ('No', 'prices', 'Arbitrage'),
#  ('If', 'if', 'discount'),
#  ('European', 'of', 'price'),
#  ('assumption', 'Under', 'the'),
#  ('in', 'of', 'and'),
#  ('⊡the', 'non', 'negative'),
#  ('Management', 'However', 'Option'),
#  ('the', 'date', 'expiration'),
#  ('calculation', 'the', 'of'),
#  ('and', 'position', 'long'),
#  ('during', 'interest', 'rate'),
#  ('−t', 'CamK', 'St'),
#  ('of', 'zerobonds', 'total'),
#  ('', 'Option', 'Management'),
#  ('contract', 'value', 'have'),
#  ('Payoff', 'Pricing', 'functions'),
#  ('and', 'asset', 'short'),
#  ('Management', 'We', 'Option'),
#  ('than', 'always', 'bigger'),
#  ('less', 'proﬁt', 'risk'),
#  ('of', 'prices', 'Arbitrage'),
#  ('of', 'Management', 'Option'),
#  ('and', 'earnings', 'all'),
#  ('yields', 'the', 'Throughout'),
#  ('be', 'could', 'inﬁnitely'),
#  ('to', 'time', 'maturity'),
#  ('costs', 'related', 'and'),
#  ('wiwi', 'hu', 'lvb'),
#  ('dividend', 'continuous', 'have'),
#  ('have', 'be', 'to'),
#  ('and', '⊡buy', 'sell'),
#  ('the', 'to', 'equal'),
#  ('payments', 'in', 'dividend'),
#  ('of', 'Option', 'Basics'),
#  ('only', 'and', 'differing'),
#  ('forward', 'contract', 'of'),
#  ('CamK', 'uni', '−t'),
#  ('proﬁt', 'risk', 'less'),
#  ('contracts', 'The', 'future'),
#  ('berlin', 'hu', 'de'),
#  ('Ste−r', 'uni', 'uni'),
#  ('yields', 'day', 'of'),
#  ('call', 'of', 'function'),
#  ('cases', 'Assume', 'and'),
#  ('interest', 'rate', 'credit'),
#  ('the', 'futures', 'of'),
#  ('price', '⊡the', 'Management'),
#  ('fulﬁl', 'to', 'the'),
#  ('have', 'show', 'to'),
#  ('uni', 'CamK', '−t'),
#  ('The', 'function', 'payoff'),
#  ('in', 'short', 'position'),
#  ('that', 'some', 'for'),
#  ('Suppose', 'respectively', 'and'),
#  ('must', 'not', 'derivatives'),
#  ('time', 'have', 'we'),
#  ('the', 'asset', 'Assume'),
#  ('von', 'Bortkiewicz', 'Ladislaus'),
#  ('an', 'of', 'American'),
#  ('same', 'current', 'value'),
#  ('time', 'to', 'by'),
#  ('rich', 'be', 'inﬁnitely'),
#  ('in', 'with', 'zerobond'),
#  ('with', 'portfolio', 'consider'),
#  ('is', 'value', 'intrinsic'),
#  ('American', 'an', 'option'),
#  ('we', 'have', 'If'),
#  ('zerobonds', 'of', 'have'),
#  ('Option', 'YPerfect', 'Management'),
#  ('functions', 'Pricing', 'Payoff'),
#  ('Assume', 'and', 'cases'),
#  (None, '', None),
#  ('rate', 'transaction', '⊡no'),
#  ('for', 'rate', 'months'),
#  ('total', 'portfolio', 'contains'),
#  ('continuous', 'we', 'have'),
#  ('contract', 'Forward', 'with'),
#  ('of', 'and', 'in'),
#  ('Charles', 'University', 'de'),
#  ('Cam', 'CamK', 'uni'),
#  ('dividends', 'discrete', 'pays'),
#  ('DtPortfolio', 'dividends', 'long'),
#  ('the', 'ITM', 'money'),
#  ('Center', 'Research', 'Blockchain'),
#  ('contains', 'total', 'portfolio'),
#  ('The', 'contracts', 'future'),
#  ('zerobonds', 'have', 'of'),
#  ('⊡the', 'negative', 'price'),
#  ('Price', 'Management', 'of'),
#  ('the', 'asset', 'of'),
#  ('contract', 'strike', 'with'),
#  ('stock', 'on', 'different'),
#  ('of', 'must', 'derivatives'),
#  ('the', 'value', 'terminal'),
#  ('in', 'position', 'the'),
#  ('strike', 'maturity', 'with'),
#  ('KThus', 'Stet', 'uni'),
#  ('uni', 'Fte−r', 'St'),
#  ('Management', 'Option', 'Since'),
#  ('Option', 'of', 'Management'),
#  ('The', 'payoff', 'is'),
#  ('calculation', 'of', 'loss'),
#  ('that', 'show', 'VFt'),
#  ('of', 'assumption', 'perfect'),
#  ('option', 'of', 'European'),
#  ('Bortkiewicz', 'of', 'Professor'),
#  ('date', 'contains', 'portfolio'),
#  ('and', 'in', 'of'),
#  ('zero', 'of', 'value'),
#  ('Jürgen', '⽟⼭學者', 'NYCU'),
#  ('and', 'VFt', 'hence'),
#  ('payments', 'dividendsCoupon', 'of'),
#  ('price', 'negative', '⊡the'),
#  ('used', 'are', 'to'),
#  ('of', 'zero', 'value'),
#  ('ABWA', 'some', 'for'),
#  ('equal', 'than', 'or'),
#  ('is', 'price', 'For'),
#  ('the', 'ATM', 'money'),
#  ('for', 'months', 'rate'),
#  ('of', 'total', 'contains'),
#  ('for', 'yields', 'in'),
#  ('allowed', 'selling', 'is'),
#  ('wiwi', 'lvb', 'hu'),
#  ('This', 'rich', 'inﬁnitely'),
#  ('in', 'contract', 'forward'),
#  ('uni', 'St', 'KTStVK'),
#  ('less', 'be', 'risk'),
#  ('SFEThe', 'of', 'Basics'),
#  ('at', 'zero', 'of'),
#  ('and', 'months', 'in'),
#  ('calculation', 'loss', 'proﬁt'),
#  ('is', 'during', 'constant'),
#  ('⊡short', 'selling', 'taxes'),
#  ('max', 'is', 'put'),
#  ('⊡the', 'of', 'price'),
#  ('KTStVK', 'contract', 'forward'),
#  ('the', 'at', 'futures'),
#  ('assumption', 'perfect', 'of'),
#  ('Ft', 'uni', 'Steb'),
#  ('forward', 'to', 'contract'),
#  ('of', 'function', 'payoff'),
#  ('the', 'terminal', 'some'),
#  ('Management', 'of', 'Price'),
#  ('for', 'Inserting', 'in'),
#  ('pays', 'asset', 'discrete'),
#  ('K−ST', 'value', 'Intrinsic'),
#  ('the', 'violates', 'This'),
#  ('Portfolio', 'payments', 'dividend'),
#  ('of', 'function', 'put'),
#  ('violates', 'principle', 'the'),
#  ('St', 'Ste−r', 'uni'),
#  ('THe', 'proﬁt', 'of'),
#  ('is', 'on', 'day'),
#  ('interest', '⊡debit', 'rate'),
#  ('for', 'Basic', 'assumption'),
#  ('to', 'time', 'by'),
#  ('futures', 'the', 'at'),
#  ('This', 'the', 'violates'),
#  ('all', 'earnings', 'of'),
#  ('FT', 'yields', 'for'),
#  ('if', 'ITM', 'its'),
#  ('⊡for', 'American', 'two'),
#  ('with', 'dividendsCoupon', 'discrete'),
#  ('intrinsic', 'its', 'if'),
#  ('with', 'zerobond', 'current'),
#  ('Maturity', 'Delivery', 'price'),
#  ('There', 'case', 'are'),
#  ('KTStVK', 'contract', 'St'),
#  ('Proposition', 'If', 'Management'),
#  ('is', 'always', 'option'),
#  ('reinvest', 'asset', 'and'),
#  ('reinvest', 'and', 'asset'),
#  ('day', 'the', 'at'),
#  ('dividend', 'payment', 'continuous'),
#  ('and', 'value', 'that'),
#  ('additional', 'assumption', 'the'),
#  ('perfect', 'market', 'of'),
#  ('An', 'money', 'ATM'),
#  ('dividends\nThen', 'continuous', 'with'),
#  ('University', 'WISE', 'Charles'),
#  ('principle', 'no', 'of'),
#  ('now', 'Continuous', 'from'),
#  ('on', 'return', 'day'),
#  ('the', 'period', 'time'),
#  ('constant', 'of', 'interest'),
#  ('market', 'the', 'and'),
#  ('at', 'of', 'zero'),
#  ('corresponding', 'option', 'European'),
#  ('less', 'risk', 'be'),
#  ('and', 'cases', 'Assume'),
#  ('is', 'uni', 'NN'),
#  ('YOption', 'Payoff', 'Pricing'),
#  ('day', 'Portfolio', 'After'),
#  ('of', 'total', 'zerobonds'),
#  ('maturity', 'time', 'to'),
#  ('Portfolio', 'day', 'After'),
#  ('future', 'portfolio', 'with'),
#  ('now', 'months', 'from'),
#  ('of', 'day', 'beginning'),
#  ('prices', 'No', 'Arbitrage'),
#  ('Basics', 'of', 'The'),
#  ('payoff', 'function', 'The'),
#  ('VFt', 'Inserting', 'uni'),
#  ('and', 'perfect', 'market'),
#  ('Fte−r', 'uni', 'uni'),
#  ('differing', 'only', 'and'),
#  ('no', 'arbitrage', 'of'),
#  ('hu', 'berlin', 'wiwi'),
#  ('prices', 'portfolios', '⊡two'),
#  ('interest', 'Continuous', 'rate'),
#  ('Delivery', 'St', 'uni'),
#  ('day', 'is', 'on'),
#  ('loss', 'proﬁt', 'calculation'),
#  ('is', 'called', 'option'),
#  ('assumption', 'of', 'the'),
#  ('the', 'time', 'interval'),
#  ('If', 'Proposition', 'the'),
#  ('DtPortfolio', 'position', 'long'),
#  ('Consider', 'two', 'Management'),
#  ('is', '⊡stocks', 'allowed'),
#  ('hu', 'wiwi', 'lvb'),
#  ('are', 'prices', 'non'),
#  ('Franke', '⽟⼭學者', 'Jürgen'),
#  ('is', 'equal', 'maturity'),
#  ('discrete', 'payments', 'dividendsCoupon'),
#  ('futures', 'the', 'of'),
#  ('An', 'ITM', 'option'),
#  ('the', 'interval', 'time'),
#  ('Management', 'Financial', 'YPerfect'),
#  ('from', 'and', 'months'),
#  ('rate', 'interest', '⊡no'),
#  ('on', 'asset', 'different'),
#  ('of', 'Basics', 'Option'),
#  ('premium', 'have', 'if'),
#  ('time', '', 'at'),
#  ('transaction', '⊡no', 'rate'),
#  ('for', 'that', 'and'),
#  ('YElementary', 'Management', 'Option'),
#  ('if', 'premium', 'have'),
#  ('even', 'THe', 'of'),
#  ('strike', 'with', 'maturity'),
#  ('uni', 'St', 'CamK'),
#  ('the', 'dividends\nThen', 'continuous'),
#  ('prices', 'different', 'for'),
#  ('bigger', 'always', 'than'),
#  ('in', 'months', 'and'),
#  ('No', 'Arbitrage', 'remainder'),
#  ('Option', 'YElementary', 'Management'),
#  ('is', 'The', 'call'),
#  ('of', 'option', 'European'),
#  ('for', 'stock', 'markets'),
#  ('portfolio', 'consider', 'Now'),
#  ('Option', '⊡for', 'Management'),
#  ('the', 'underlying', 'to'),
#  ('allowed', 'is', 'selling'),
#  ('corresponding', 'the', 'of'),
#  ('terminal', 'some', 'the'),
#  ('position', 'in', 'short'),
#  ('portfolios', 'two', 'and'),
#  ('An', 'ATM', 'option'),
#  ('date', 'maturity', 'strike'),
#  ('different', '⊡two', 'prices'),
#  ('arbitrage', 'of', 'no'),
#  ('principle', 'violates', 'the'),
#  ('and', 'uni', 'KThus'),
#  ('unlimitedly', 'are', 'divisible'),
#  ('of', 'SFEThe', 'Basics'),
#  ('option', 'American', 'is'),
#  ('for', 'markets', 'different'),
#  ('price', 'the', 'to'),
#  ('to', 'related', 'the'),
#  ('loss', 'The', 'proﬁt'),
#  ('Throughout', 'yields', 'day'),
#  ('Payoff', 'Pricing', 'YOption'),
#  ('The', 'proﬁt', 'contracts'),
#  ('Underlying', 'Price', 'price'),
#  ('of', 'futures', 'the'),
#  ('equal', 'or', 'than'),
#  ('some', 'the', 'for'),
#  ('the', 'and', 'asset'),
#  ('of', 'market', 'perfect'),
#  ('and', 'future', 'the'),
#  ('Basics', 'SFEThe', 'of'),
#  ('Fte−r', 'St', 'uni'),
#  ('interest', 'constant', 'rate'),
#  ('After', 'at', 'day'),
#  ('are', 'which', 'used'),
#  ('of', 'is', 'put'),
#  ('Inserting', 'in', 'uni'),
#  ('that', 'Suppose', 'for'),
#  ('of', 'constant', 'assumption'),
#  ('if', 'If', 'discount'),
#  ('and', 'of', 'in'),
#  ('StThus', 'uni', 'and'),
#  ('the', 'of', 'assumption'),
#  ('price', 'Delivery', 'Maturity'),
#  ('cumulative', 'return', 'the'),
#  ('contains', 'date', 'portfolio'),
#  ('costs', 'taxes', '⊡no'),
#  ('that', 'for', 'and'),
#  ('the', 'day', 'cumulative'),
#  ('by', 'time', 'only'),
#  ('period', 'time', 'the'),
#  ('corresponding', 'European', 'the'),
#  ('holds', 'Cam', 'Cam'),
#  ('⽟⼭學者', 'Jürgen', 'NYCU'),
#  ('will', 'be', 'there'),
#  ('As', 'Management', 'the'),
#  ('Intrinsic', 'K−ST', 'value'),
#  ('and', 'Suppose', 'respectively'),
#  ('The', 'functions', 'Payoff'),
#  ('fulﬁl', 'to', 'used'),
#  ('uni', 'KThus', 'Stet'),
#  ('with', 'consider', 'portfolio'),
#  ('Prices', 'Option', 'of'),
#  ('the', 'contract', 'forward'),
#  ('Theory', 'Management', 'YArbitrage'),
#  ('VFt', 'VFt', 'uni'),
#  ('for', 'that', 'some'),
#  ('American', 'an', 'of'),
#  ('stock', 'markets', 'different'),
#  ('Option', 'Proof', 'Management'),
#  ('time', 'calculated', 'at'),
#  ('hence', 'and', 'VFt'),
#  ('all', 'and', 'reinvest'),
#  ('portfolios', '⊡two', 'with'),
#  ('underlying', 'to', 'the'),
#  ('Proof', 'are', 'equal'),
#  ('However', 'in', 'Management'),
#  ('to', 'used', 'fulﬁl'),
#  ('Since', 'Option', 'Management'),
#  ('payoff', 'The', 'functions'),
#  ('respectively', 'and', 'value'),
#  ('than', 'bigger', 'always'),
#  ('interest', 'the', 'If'),
#  ('ABWA', 'for', 'some'),
#  ('have', 'continuous', 'we'),
#  ('at', 'Price', 'time'),
#  ('of', 'loss', 'calculation'),
#  ('YElementary', 'of', 'Properties'),
#  ('called', 'is', 'option'),
#  ('than', 'bigger', 'or'),
#  ('the', 'Under', 'assumption'),
#  ('⊡stocks', 'allowed', 'are'),
#  ('negative', '⊡the', 'non'),
#  ('case', 'are', 'There'),
#  ('are', '⊡stocks', 'unlimitedly'),
#  ('KTStVK', 'forward', 'contract'),
#  ('are', '⊡option', 'prices'),
#  ('function', 'The', 'payoff'),
#  ('Underlying', 'date', 'price'),
#  ('We', 'Option', 'Management'),
#  ('⊡stocks', 'is', 'allowed'),
#  ('Portfolio', 'shares', 'buy'),
#  ('for', 'We', 'have'),
#  ('markets', 'stock', 'for'),
#  ('⊡option', 'prices', 'Prices'),
#  ('every', 'are', 'settled'),
#  ('rate', 'interest', 'constant'),
#  ('to', 'used', 'are'),
#  ('additional', 'of', 'assumption'),
#  ('different', 'for', 'markets'),
#  ('zerobonds', 'are', 'which'),
#  ('⊡two', 'portfolios', 'prices'),
#  ('same', 'value', 'current'),
#  (None, 'time', ''),
#  ('cumulative', 'the', 'return'),
#  ('von', 'Ladislaus', 'Bortkiewicz'),
#  ('of', 'The', 'Basics'),
#  ('zerobonds', 'which', 'of'),
#  ('the', 'Management', 'As'),
#  ('uni', 'Steb', 'Ft'),
#  ('that', 'to', 'show'),
#  ('then', 'Ft', 'and'),
#  ('the', 'of', 'beginning'),
#  ('Management', 'Option', ''),
#  ('of', 'prices', 'derivatives'),
#  ('are', 'There', 'case'),
#  ('the', 'of', 'value'),
#  ('forward', 'position', 'in'),
#  ('only', 'by', 'differing'),
#  ('Suppose', 'respectively', 'that'),
#  ('St', 'uni', 'KTStVK'),
#  ('Berlin', 'BRC', 'zu'),
#  ('of', 'Price', 'Management'),
#  ('YPerfect', 'Management', 'Financial'),
#  ('We', 'have', 'Management'),
#  ('If', 'we', 'Management'),
#  ('max', 'ST−K', 'max'),
#  ('Throughout', 'yields', 'the'),
#  ('⊡short', 'taxes', '⊡no'),
#  ('only', 'the', 'day'),
#  ('equal', 'to', 'or'),
#  ('the', 'As', 'Management'),
#  ('asset', 'an', 'on'),
#  ('prices', 'of', 'the'),
#  ('total', 'of', 'contains'),
#  ('earnings', 'all', 'of'),
#  ('months', 'from', 'and'),
#  ('Steb', 'then', 'Ft'),
#  ('underlying', 'the', 'to'),
#  ('money', 'An', 'ATM'),
#  ('to', 'fulﬁl', 'used'),
#  ('call', 'function', 'of'),
#  ('uni', 'Inserting', 'VFt'),
#  ('show', 'VFt', 'that'),
#  ('payment', 'continuous', 'dividend'),
#  ('The', 'Payoff', 'functions'),
#  ('have', 'dividend', 'continuous'),
#  ('now', 'from', 'months'),
#  ('time', 'period', 'the'),
#  ('future', 'and', 'the'),
#  ('Option', 'Properties', 'of'),
#  ('The', 'Chapter', 'Basics'),
#  ('Delivery', 'uni', 'price'),
#  ('uni', 'Ste−r', 'uni'),
#  ('are', 'divisible', 'unlimitedly'),
#  ('Pricing', 'YOption', 'Payoff'),
#  ('rate', 'constant', 'is'),
#  ('the', 'to', 'price'),
#  ('dividends\nThen', 'forward', 'the'),
#  ('of', 'American', 'an'),
#  ('with', '⊡two', 'portfolios'),
#  ('contract', 'the', 'of'),
#  ('option', 'an', 'American'),
#  ('portfolios', 'with', 'and'),
#  ('to', 'price', 'the'),
#  ('buy', 'to', 'Portfolio'),
#  ('is', 'If', 'the'),
#  ('uni', 'Stet', 'KThus'),
#  ('always', 'is', 'option'),
#  ('Arbitrage', 'remainder', 'No'),
#  ('bigger', 'is', 'always'),
#  ('proﬁt', 'less', 'of'),
#  ('asset', 'different', 'on'),
#  ('all', 'of', 'value'),
#  ('zerobonds', 'of', 'which'),
#  ('⊡debit', 'Market', 'Financial'),
#  ('during', 'is', 'constant'),
#  ('dividend', 'no', 'payments'),
#  ('for', 'We', 'months'),
#  ('European', 'option', 'corresponding'),
#  ('we', 'time', 'have'),
#  ('day', 'only', 'at'),
#  ('the', 'As', 'future'),
#  ('portfolio', 'Now', 'consider'),
#  ('Continuous', 'from', 'now'),
#  ('YOption', 'Management', 'Option'),
#  ('Basic', 'Management', 'Option'),
#  ('respectively', 'and', 'Suppose'),
#  ('price', 'Delivery', 'uni'),
#  ('price', 'of', 'the'),
#  ('with', 'current', 'and'),
#  ('markets', 'different', 'stock'),
#  ('portfolios', 'the', 'with'),
#  ('total', 'contains', 'portfolio'),
#  ('Berlin', 'zu', 'Universität'),
#  ('arbitrage', '', 'permit'),
#  ('no', 'principle', 'of'),
#  ('calculation', 'proﬁt', 'loss'),
#  ('Professor', 'of', 'Bortkiewicz'),
#  ('Cam', 'holds', 'Cam'),
#  ('Management', 'assumption', 'Basic'),
#  ('Humboldt', 'Statistics', 'Universität'),
#  ('discrete', 'pays', 'dividends'),
#  ('asset', 'reinvest', 'and'),
#  ('expiration', 'the', 'date'),
#  ('constant', 'during', 'is'),
#  ('and', 'StThus', 'uni'),
#  ('⊡the', 'price', 'negative'),
#  ('value', 'respectively', 'and'),
#  ('no', 'of', 'arbitrage'),
#  ('portfolio', 'date', 'expiration'),
#  ('equal', 'or', 'to'),
#  ('expiration', 'date', 'the'),
#  ('price', 'are', 'forward'),
#  ('day', 'of', 'beginning'),
#  ('the', 'following', 'maturity'),
#  ('⽟⼭學者', 'NYCU', 'Jürgen'),
#  ('Ste−r', 'uni', 'St'),
#  ('during', 'the', 'rate'),
#  ('at', 'beginning', 'the'),
#  ('American', 'of', 'an'),
#  ('is', 'constant', 'rate'),
#  ('equal', 'Proof', 'are'),
#  ('bigger', 'than', 'always'),
#  ('of', 'price', 'European'),
#  ('prices', 'different', '⊡two'),
#  ('and', 'costs', 'earnings'),
#  ('day', 'every', 'the'),
#  ('at', 'period', 'calculated'),
#  ('have', 'We', 'to'),
#  ('value', 'have', 'of'),
#  ('always', 'is', 'bigger'),
#  ('cases', 'Management', 'and'),
#  ('Portfolio', 'Option', 'Management'),
#  ('maturity', 'strike', 'date'),
#  ('prices', 'Prices', '⊡option'),
#  ('market', 'and', 'perfect'),
#  ('option', 'prices', '⊡call'),
#  ('If', 'discount', 'if'),
#  ('months', 'and', 'in'),
#  ('in', 'value', 'the'),
#  ('the', 'for', 'some'),
#  ('of', 'Statistics', 'Professor'),
#  ('remainder', 'No', 'the'),
#  ('are', 'unlimitedly', '⊡stocks'),
#  ('Management', 'Option', 'Portfolio'),
#  ('of', 'proﬁt', 'THe'),
#  ('Management', 'case', 'Proof'),
#  ('Statistics', 'Universität', 'Humboldt'),
#  ('time', 'during', 'the'),
#  ('value', 'the', 'in'),
#  ('have', 'value', 'contract'),
#  ('⽟⼭學者', 'NYCU', 'XMU'),
#  ('then', 'and', 'Ft'),
#  ('zu', 'Universität', 'Humboldt'),
#  ('and', 'two', 'portfolios'),
#  ('wiwi', 'Center', 'lvb'),
#  ('allowed', '⊡stocks', 'is'),
#  ('in', 'position', 'zero'),
#  ('Portfolio', 'portfolio', 'to'),
#  ('No', 'the', 'remainder'),
#  ('premium', 'if', 'have'),
#  ('St', 'VFt', 'uni'),
#  ('in', 'Since', 'changes'),
#  ('and', 'an', 'sell'),
#  ('uni', 'VFt', 'VFt'),
#  ('options', 'American', 'two'),
#  ('Proof', 'Management', 'case'),
#  ('day', 'on', 'return'),
#  ('with', 'value', 'current'),
#  ('XMU', '⽟⼭學者', 'NYCU'),
#  ('different', 'markets', 'for'),
#  ('there', 'in', 'will'),
#  ('Cam', 'Cam', 'holds'),
#  ('CamK', 'St', 'uni'),
#  ('Berlin', 'Blockchain', 'BRC'),
#  ('VFt', 'hence', 'St'),
#  ('Continuous', 'now', 'from'),
#  ('by', 'only', 'time'),
#  ('are', 'There', 'no'),
#  ('value', 'of', 'the'),
#  ('is', 'we', 'For'),
#  ('Intrinsic', 'K−ST', 'max'),
#  ('of', 'European', 'price'),
#  ('have', 'contract', 'forward'),
#  ('non', 'prices', 'are'),
#  ('of', 'Basics', 'SFEThe'),
#  ('terminal', 'the', 'some'),
#  ('the', 'and', 'Assume'),
#  ('and', 'cases', 'Management'),
#  ('Suppose', 'for', 'that'),
#  ('we', 'If', 'Management'),
#  ('value', 'nonzero', 'is'),
#  ('Portfolio', 'payments', 'long'),
#  ('the', 'to', 'maturity'),
#  ('day', 'at', 'After'),
#  ('continuous', 'with', 'contract'),
#  ('', 'permit', 'arbitrage'),
#  ('day', 'After', 'Portfolio'),
#  ('rich', 'violates', 'This'),
#  ('than', 'or', 'bigger'),
#  ('Delivery', 'uni', 'St'),
#  ('Portfolio', 'After', 'Management'),
#  ('continuous', 'payment', 'dividend'),
#  ('the', 'value', 'is'),
#  ('are', 'no', 'There'),
#  ('of', 'have', 'value'),
#  ('uni', 'price', 'Delivery'),
#  ('Properties', 'Option', 'of'),
#  ('If', 'Management', 'Proposition'),
#  ('Option', 'In', 'Management'),
#  ('VFt', 'uni', 'St'),
#  ('asset', 'in', 'the'),
#  ('Management', 'Portfolio', 'Option'),
#  ('the', 'price', 'forward'),
#  ('In', 'Management', 'the'),
#  ('time', 'the', 'interval'),
#  ('zero', 'of', 'at'),
#  ('Prices', 'of', 'Option'),
#  ('same', 'the', 'current'),
#  ('Management', 'Consider', 'Option'),
#  ('An', 'option', 'ITM'),
#  ('zerobond', 'current', 'with'),
#  ('Universität', 'Humboldt', 'zu'),
#  ('be', 'will', 'there'),
#  ('Under', 'assumption', 'the'),
#  ('⊡no', 'transaction', 'rate'),
#  ('months', 'now', 'from'),
#  ('shares', 'buy', 'Portfolio'),
#  ('is', 'of', 'call'),
#  ('are', 'Proof', 'equal'),
#  ('Portfolio', 'Management', 'Now'),
#  ('for', 'some', 'that'),
#  ('berlin', 'hu', 'wiwi'),
#  ('Forward', 'contract', 'Example'),
#  ('the', 'Under', 'Proposition'),
#  ('uni', 'that', 'VFt'),
#  ('all', 'and', 'earnings'),
#  ('uni', 'VFt', 'Inserting'),
#  ('Steb', 'uni', 'Ft'),
#  ('are', 'dividend', 'no'),
#  ('time', 'maturity', 'to'),
#  ('KThus', 'hence', 'and'),
#  ('portfolios', '⊡two', 'prices'),
#  ('The', 'loss', 'proﬁt'),
#  ('The', 'call', 'is'),
#  ('selling', '⊡short', 'is'),
#  ('Now', 'consider', 'Portfolio'),
#  ('⊡no', 'interest', 'rate'),
#  ('and', 'current', 'with'),
#  ('time', 'at', ''),
#  ('Portfolio', 'to', 'buy'),
#  ('return', 'cumulative', 'on'),
#  ('considered', 'be', 'to'),
#  ('the', 'of', 'asset'),
#  ('Consider', 'Option', 'Management'),
#  ('value', 'that', 'and'),
#  ('Management', 'YPerfect', 'Option'),
#  ('time', 'the', 'during'),
#  ('dividendsCoupon', 'discrete', 'payments'),
#  ('er', 'Ste−r', 'uni'),
#  ('We', 'have', 'months'),
#  ('is', 'An', 'option'),
#  ...}

# %%
two_word_list = [[p for p in permutations(two_word[k])][1:] for k in range(len(two_word))]
two_word_list
# Out:
# [[('von', 'Ladislaus')],
#  [('Bortkiewicz', 'von')],
#  [('Professor', 'Bortkiewicz')],
#  [('of', 'Professor')],
#  [('Statistics', 'of')],
#  [('Humboldt', 'Statistics')],
#  [('Universität', 'Humboldt')],
#  [('zu', 'Universität')],
#  [('Berlin', 'zu')],
#  [('BRC', 'Berlin')],
#  [('Blockchain', 'BRC')],
#  [('Research', 'Blockchain')],
#  [('Center', 'Research')],
#  [('lvb', 'Center')],
#  [('wiwi', 'lvb')],
#  [('hu', 'wiwi')],
#  [('berlin', 'hu')],
#  [('de', 'berlin')],
#  [('Charles', 'de')],
#  [('University', 'Charles')],
#  [('WISE', 'University')],
#  [('XMU', 'WISE')],
#  [('NYCU', 'XMU')],
#  [('⽟⼭學者', 'NYCU')],
#  [('Jürgen', '⽟⼭學者')],
#  [('Franke', 'Jürgen')],
#  [('The', 'Chapter')],
#  [('Basics', 'The')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('', 'Management')],
#  [(None, '')],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('YArbitrage', 'Management')],
#  [('Theory', 'YArbitrage')],
#  [('⊡buy', 'Theory')],
#  [('and', '⊡buy')],
#  [('sell', 'and')],
#  [('an', 'sell')],
#  [('asset', 'an')],
#  [('on', 'asset')],
#  [('different', 'on')],
#  [('stock', 'different')],
#  [('markets', 'stock')],
#  [('for', 'markets')],
#  [('different', 'for')],
#  [('prices', 'different')],
#  [('⊡two', 'prices')],
#  [('portfolios', '⊡two')],
#  [('with', 'portfolios')],
#  [('the', 'with')],
#  [('same', 'the')],
#  [('current', 'same')],
#  [('value', 'current')],
#  [('same', 'value')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Consider', 'Management')],
#  [('two', 'Consider')],
#  [('portfolios', 'two')],
#  [('and', 'portfolios')],
#  [('with', 'and')],
#  [('current', 'with')],
#  [('value', 'current')],
#  [('and', 'value')],
#  [('respectively', 'and')],
#  [('Suppose', 'respectively')],
#  [('that', 'Suppose')],
#  [('for', 'that')],
#  [('some', 'for')],
#  [('the', 'some')],
#  [('terminal', 'the')],
#  [('value', 'terminal')],
#  [('and', 'value')],
#  [('that', 'and')],
#  [('for', 'that')],
#  [('some', 'for')],
#  [('ABWA', 'some')],
#  [('WB', 'ABWA')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('However', 'Management')],
#  [('in', 'However')],
#  [('there', 'in')],
#  [('will', 'there')],
#  [('be', 'will')],
#  [('risk', 'be')],
#  [('less', 'risk')],
#  [('proﬁt', 'less')],
#  [('of', 'proﬁt')],
#  [('THe', 'of')],
#  [('even', 'THe')],
#  [('could', 'even')],
#  [('be', 'could')],
#  [('inﬁnitely', 'be')],
#  [('rich', 'inﬁnitely')],
#  [('This', 'rich')],
#  [('violates', 'This')],
#  [('the', 'violates')],
#  [('principle', 'the')],
#  [('of', 'principle')],
#  [('no', 'of')],
#  [('arbitrage', 'no')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Basic', 'Management')],
#  [('assumption', 'Basic')],
#  [('for', 'assumption')],
#  [('the', 'for')],
#  [('remainder', 'the')],
#  [('No', 'remainder')],
#  [('Arbitrage', 'No')],
#  [('prices', 'Arbitrage')],
#  [('of', 'prices')],
#  [('derivatives', 'of')],
#  [('must', 'derivatives')],
#  [('not', 'must')],
#  [('permit', 'not')],
#  [('arbitrage', 'permit')],
#  [('', 'arbitrage')],
#  [(None, '')],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('YPerfect', 'Management')],
#  [('Financial', 'YPerfect')],
#  [('Market', 'Financial')],
#  [('⊡debit', 'Market')],
#  [('interest', '⊡debit')],
#  [('rate', 'interest')],
#  [('credit', 'rate')],
#  [('interest', 'credit')],
#  [('rate', 'interest')],
#  [('⊡no', 'rate')],
#  [('transaction', '⊡no')],
#  [('costs', 'transaction')],
#  [('⊡no', 'costs')],
#  [('taxes', '⊡no')],
#  [('⊡short', 'taxes')],
#  [('selling', '⊡short')],
#  [('is', 'selling')],
#  [('allowed', 'is')],
#  [('⊡stocks', 'allowed')],
#  [('are', '⊡stocks')],
#  [('unlimitedly', 'are')],
#  [('divisible', 'unlimitedly')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Price', 'Management')],
#  [('of', 'Price')],
#  [('forward', 'of')],
#  [('contract', 'forward')],
#  [('KTStVK', 'contract')],
#  [('St', 'KTStVK')],
#  [('uni', 'St')],
#  [('Delivery', 'uni')],
#  [('price', 'Delivery')],
#  [('Maturity', 'price')],
#  [('date', 'Maturity')],
#  [('Underlying', 'date')],
#  [('price', 'Underlying')],
#  [('Price', 'price')],
#  [('at', 'Price')],
#  [('time', 'at')],
#  [('', 'time')],
#  [(None, '')],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [(None, None)],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Proposition', 'Management')],
#  [('Under', 'Proposition')],
#  [('the', 'Under')],
#  [('assumption', 'the')],
#  [('of', 'assumption')],
#  [('perfect', 'of')],
#  [('market', 'perfect')],
#  [('and', 'market')],
#  [('the', 'and')],
#  [('additional', 'the')],
#  [('assumption', 'additional')],
#  [('of', 'assumption')],
#  [('constant', 'of')],
#  [('interest', 'constant')],
#  [('rate', 'interest')],
#  [('during', 'rate')],
#  [('the', 'during')],
#  [('time', 'the')],
#  [('interval', 'time')],
#  [('the', 'interval')],
#  [('following', 'the')],
#  [('holds', 'following')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('If', 'Management')],
#  [('is', 'If')],
#  [('the', 'is')],
#  [('value', 'the')],
#  [('of', 'value')],
#  [('all', 'of')],
#  [('earnings', 'all')],
#  [('and', 'earnings')],
#  [('costs', 'and')],
#  [('related', 'costs')],
#  [('to', 'related')],
#  [('the', 'to')],
#  [('underlying', 'the')],
#  [('during', 'underlying')],
#  [('the', 'during')],
#  [('time', 'the')],
#  [('period', 'time')],
#  [('calculated', 'period')],
#  [('at', 'calculated')],
#  [('time', 'at')],
#  [('we', 'time')],
#  [('have', 'we')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Proof', 'Management')],
#  [('case', 'Proof')],
#  [('There', 'case')],
#  [('are', 'There')],
#  [('no', 'are')],
#  [('dividend', 'no')],
#  [('payments', 'dividend')],
#  [('Portfolio', 'payments')],
#  [('long', 'Portfolio')],
#  [('position', 'long')],
#  [('in', 'position')],
#  [('forward', 'in')],
#  [('contract', 'forward')],
#  [('with', 'contract')],
#  [('strike', 'with')],
#  [('maturity', 'strike')],
#  [('date', 'maturity')],
#  [('and', 'date')],
#  [('long', 'and')],
#  [('position', 'long')],
#  [('in', 'position')],
#  [('zero', 'in')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('We', 'Management')],
#  [('have', 'We')],
#  [('to', 'have')],
#  [('show', 'to')],
#  [('that', 'show')],
#  [('VFt', 'that')],
#  [('uni', 'VFt')],
#  [('Inserting', 'uni')],
#  [('in', 'Inserting')],
#  [('for', 'in')],
#  [('yields', 'for')],
#  [('FT', 'yields')],
#  [('Stet', 'FT')],
#  [('uni', 'Stet')],
#  [('KThus', 'uni')],
#  [('and', 'KThus')],
#  [('hence', 'and')],
#  [('VFt', 'hence')],
#  [('St', 'VFt')],
#  [('uni', 'St')],
#  [('Ste−r', 'uni')],
#  [('uni', 'Ste−r')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('cases', 'Management')],
#  [('and', 'cases')],
#  [('Assume', 'and')],
#  [('the', 'Assume')],
#  [('asset', 'the')],
#  [('pays', 'asset')],
#  [('discrete', 'pays')],
#  [('dividends', 'discrete')],
#  [('DtPortfolio', 'dividends')],
#  [('long', 'DtPortfolio')],
#  [('position', 'long')],
#  [('in', 'position')],
#  [('the', 'in')],
#  [('asset', 'the')],
#  [('and', 'asset')],
#  [('short', 'and')],
#  [('position', 'short')],
#  [('in', 'position')],
#  [('zerobond', 'in')],
#  [('with', 'zerobond')],
#  [('current', 'with')],
#  [('value', 'current')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('We', 'Management')],
#  [('have', 'We')],
#  [('to', 'have')],
#  [('show', 'to')],
#  [('that', 'show')],
#  [('VFt', 'that')],
#  [('uni', 'VFt')],
#  [('VFt', 'uni')],
#  [('St', 'VFt')],
#  [('uni', 'St')],
#  [('Fte−r', 'uni')],
#  [('uni', 'Fte−r')],
#  [('StThus', 'uni')],
#  [('and', 'StThus')],
#  [('hence', 'and')],
#  [('VFt', 'hence')],
#  [('St', 'VFt')],
#  [('uni', 'St')],
#  [('Ste−r', 'uni')],
#  [('uni', 'Ste−r')],
#  [('er', 'uni')],
#  [('uni', 'er')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('If', 'Management')],
#  [('we', 'If')],
#  [('have', 'we')],
#  [('continuous', 'have')],
#  [('dividend', 'continuous')],
#  [('payment', 'dividend')],
#  [('we', 'payment')],
#  [('change', 'we')],
#  [('portfolio', 'change')],
#  [('to', 'portfolio')],
#  [('Portfolio', 'to')],
#  [('buy', 'Portfolio')],
#  [('shares', 'buy')],
#  [('of', 'shares')],
#  [('the', 'of')],
#  [('asset', 'the')],
#  [('and', 'asset')],
#  [('reinvest', 'and')],
#  [('all', 'reinvest')],
#  [('dividend', 'all')],
#  [('payments', 'dividend')],
#  [('in', 'payments')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Example', 'Management')],
#  [('Forward', 'Example')],
#  [('contract', 'Forward')],
#  [('with', 'contract')],
#  [('discrete', 'with')],
#  [('dividendsCoupon', 'discrete')],
#  [('payments', 'dividendsCoupon')],
#  [('of', 'payments')],
#  [('in', 'of')],
#  [('and', 'in')],
#  [('months', 'and')],
#  [('from', 'months')],
#  [('now', 'from')],
#  [('Continuous', 'now')],
#  [('interest', 'Continuous')],
#  [('rate', 'interest')],
#  [('for', 'rate')],
#  [('months', 'for')],
#  [('We', 'months')],
#  [('have', 'We')],
#  [('for', 'have')],
#  [('and', 'for')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Example', 'Management')],
#  [('Forward', 'Example')],
#  [('contract', 'Forward')],
#  [('with', 'contract')],
#  [('continuous', 'with')],
#  [('dividends\nThen', 'continuous')],
#  [('the', 'dividends\nThen')],
#  [('forward', 'the')],
#  [('price', 'forward')],
#  [('is', 'price')],
#  [('For', 'is')],
#  [('we', 'For')],
#  [('have', 'we')],
#  [('premium', 'have')],
#  [('if', 'premium')],
#  [('discount', 'if')],
#  [('If', 'discount')],
#  [('and', 'If')],
#  [('then', 'and')],
#  [('Ft', 'then')],
#  [('Steb', 'Ft')],
#  [('uni', 'Steb')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Proposition', 'Management')],
#  [('If', 'Proposition')],
#  [('the', 'If')],
#  [('interest', 'the')],
#  [('rate', 'interest')],
#  [('is', 'rate')],
#  [('constant', 'is')],
#  [('during', 'constant')],
#  [('the', 'during')],
#  [('maturity', 'the')],
#  [('of', 'maturity')],
#  [('the', 'of')],
#  [('contract', 'the')],
#  [('the', 'contract')],
#  [('future', 'the')],
#  [('and', 'future')],
#  [('the', 'and')],
#  [('forward', 'the')],
#  [('price', 'forward')],
#  [('are', 'price')],
#  [('equal', 'are')],
#  [('Proof', 'equal')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Portfolio', 'Management')],
#  [('After', 'Portfolio')],
#  [('day', 'After')],
#  [('at', 'day')],
#  [('the', 'at')],
#  [('expiration', 'the')],
#  [('date', 'expiration')],
#  [('portfolio', 'date')],
#  [('contains', 'portfolio')],
#  [('total', 'contains')],
#  [('of', 'total')],
#  [('zerobonds', 'of')],
#  [('which', 'zerobonds')],
#  [('are', 'which')],
#  [('used', 'are')],
#  [('to', 'used')],
#  [('fulﬁl', 'to')],
#  [('the', 'fulﬁl')],
#  [('forward', 'the')],
#  [('contract', 'forward')],
#  [('to', 'contract')],
#  [('buy', 'to')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Portfolio', 'Management')],
#  [('Now', 'Portfolio')],
#  [('consider', 'Now')],
#  [('portfolio', 'consider')],
#  [('with', 'portfolio')],
#  [('future', 'with')],
#  [('contracts', 'future')],
#  [('The', 'contracts')],
#  [('proﬁt', 'The')],
#  [('loss', 'proﬁt')],
#  [('calculation', 'loss')],
#  [('of', 'calculation')],
#  [('the', 'of')],
#  [('futures', 'the')],
#  [('at', 'futures')],
#  [('the', 'at')],
#  [('beginning', 'the')],
#  [('of', 'beginning')],
#  [('day', 'of')],
#  [('yields', 'day')],
#  [('Throughout', 'yields')],
#  [('the', 'Throughout')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('Since', 'Management')],
#  [('changes', 'Since')],
#  [('in', 'changes')],
#  [('the', 'in')],
#  [('value', 'the')],
#  [('of', 'value')],
#  [('the', 'of')],
#  [('future', 'the')],
#  [('are', 'future')],
#  [('settled', 'are')],
#  [('every', 'settled')],
#  [('day', 'every')],
#  [('the', 'day')],
#  [('cumulative', 'the')],
#  [('return', 'cumulative')],
#  [('on', 'return')],
#  [('day', 'on')],
#  [('is', 'day')],
#  [('NN', 'is')],
#  [('uni', 'NN')],
#  [('Ft−Ft−', 'uni')],
#  [('eN', 'Ft−Ft−')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('As', 'Management')],
#  [('the', 'As')],
#  [('future', 'the')],
#  [('and', 'future')],
#  [('the', 'and')],
#  [('forward', 'the')],
#  [('contract', 'forward')],
#  [('have', 'contract')],
#  [('value', 'have')],
#  [('of', 'value')],
#  [('zero', 'of')],
#  [('at', 'zero')],
#  [('day', 'at')],
#  [('only', 'day')],
#  [('the', 'only')],
#  [('prices', 'the')],
#  [('of', 'prices')],
#  [('zerobonds', 'of')],
#  [('have', 'zerobonds')],
#  [('to', 'have')],
#  [('be', 'to')],
#  [('considered', 'be')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('YOption', 'Management')],
#  [('Pricing', 'YOption')],
#  [('Payoff', 'Pricing')],
#  [('functions', 'Payoff')],
#  [('The', 'functions')],
#  [('payoff', 'The')],
#  [('function', 'payoff')],
#  [('of', 'function')],
#  [('call', 'of')],
#  [('is', 'call')],
#  [('The', 'is')],
#  [('payoff', 'The')],
#  [('function', 'payoff')],
#  [('of', 'function')],
#  [('put', 'of')],
#  [('is', 'put')],
#  [('max', 'is')],
#  [('ST−K', 'max')],
#  [('max', 'ST−K')],
#  [('K−ST', 'max')],
#  [('Intrinsic', 'K−ST')],
#  [('value', 'Intrinsic')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('In', 'Management')],
#  [('the', 'In')],
#  [('money', 'the')],
#  [('ITM', 'money')],
#  [('An', 'ITM')],
#  [('option', 'An')],
#  [('is', 'option')],
#  [('called', 'is')],
#  [('ITM', 'called')],
#  [('if', 'ITM')],
#  [('its', 'if')],
#  [('intrinsic', 'its')],
#  [('value', 'intrinsic')],
#  [('is', 'value')],
#  [('nonzero', 'is')],
#  [('At', 'nonzero')],
#  [('the', 'At')],
#  [('money', 'the')],
#  [('ATM', 'money')],
#  [('An', 'ATM')],
#  [('option', 'An')],
#  [('is', 'option')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('YElementary', 'Management')],
#  [('Properties', 'YElementary')],
#  [('of', 'Properties')],
#  [('Option', 'of')],
#  [('Prices', 'Option')],
#  [('⊡option', 'Prices')],
#  [('prices', '⊡option')],
#  [('are', 'prices')],
#  [('non', 'are')],
#  [('negative', 'non')],
#  [('⊡the', 'negative')],
#  [('price', '⊡the')],
#  [('of', 'price')],
#  [('European', 'of')],
#  [('option', 'European')],
#  [('at', 'option')],
#  [('maturity', 'at')],
#  [('is', 'maturity')],
#  [('equal', 'is')],
#  [('to', 'equal')],
#  [('the', 'to')],
#  [('price', 'the')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('⊡for', 'Management')],
#  [('two', '⊡for')],
#  [('American', 'two')],
#  [('options', 'American')],
#  [('and', 'options')],
#  [('differing', 'and')],
#  [('only', 'differing')],
#  [('by', 'only')],
#  [('time', 'by')],
#  [('to', 'time')],
#  [('maturity', 'to')],
#  [('the', 'maturity')],
#  [('following', 'the')],
#  [('holds', 'following')],
#  [('Cam', 'holds')],
#  [('Cam', 'Cam')],
#  [('uni', 'Cam')],
#  [('CamK', 'uni')],
#  [('St', 'CamK')],
#  [('−t', 'St')],
#  [('uni', '−t')],
#  [('CamK', 'uni')],
#  [('Basics', 'SFEThe')],
#  [('of', 'Basics')],
#  [('Option', 'of')],
#  [('Management', 'Option')],
#  [('⊡the', 'Management')],
#  [('price', '⊡the')],
#  [('of', 'price')],
#  [('an', 'of')],
#  [('American', 'an')],
#  [('option', 'American')],
#  [('is', 'option')],
#  [('always', 'is')],
#  [('bigger', 'always')],
#  [('than', 'bigger')],
#  [('or', 'than')],
#  [('equal', 'or')],
#  [('to', 'equal')],
#  [('the', 'to')],
#  [('price', 'the')],
#  [('of', 'price')],
#  [('the', 'of')],
#  [('corresponding', 'the')],
#  [('European', 'corresponding')],
#  [('option', 'European')],
#  [('⊡call', 'option')],
#  [('prices', '⊡call')]]

# %%
two_word_list = set(list(chain(*two_word_list)))
two_word_list
# Out:
# {('', 'Management'),
#  ('', 'arbitrage'),
#  ('', 'time'),
#  ('ABWA', 'some'),
#  ('ATM', 'money'),
#  ('After', 'Portfolio'),
#  ('American', 'an'),
#  ('American', 'two'),
#  ('An', 'ATM'),
#  ('An', 'ITM'),
#  ('Arbitrage', 'No'),
#  ('As', 'Management'),
#  ('Assume', 'and'),
#  ('At', 'nonzero'),
#  ('BRC', 'Berlin'),
#  ('Basic', 'Management'),
#  ('Basics', 'SFEThe'),
#  ('Basics', 'The'),
#  ('Berlin', 'zu'),
#  ('Blockchain', 'BRC'),
#  ('Bortkiewicz', 'von'),
#  ('Cam', 'Cam'),
#  ('Cam', 'holds'),
#  ('CamK', 'uni'),
#  ('Center', 'Research'),
#  ('Charles', 'de'),
#  ('Consider', 'Management'),
#  ('Continuous', 'now'),
#  ('Delivery', 'uni'),
#  ('DtPortfolio', 'dividends'),
#  ('European', 'corresponding'),
#  ('European', 'of'),
#  ('Example', 'Management'),
#  ('FT', 'yields'),
#  ('Financial', 'YPerfect'),
#  ('For', 'is'),
#  ('Forward', 'Example'),
#  ('Franke', 'Jürgen'),
#  ('Ft', 'then'),
#  ('Fte−r', 'uni'),
#  ('Ft−Ft−', 'uni'),
#  ('However', 'Management'),
#  ('Humboldt', 'Statistics'),
#  ('ITM', 'called'),
#  ('ITM', 'money'),
#  ('If', 'Management'),
#  ('If', 'Proposition'),
#  ('If', 'discount'),
#  ('In', 'Management'),
#  ('Inserting', 'uni'),
#  ('Intrinsic', 'K−ST'),
#  ('Jürgen', '⽟⼭學者'),
#  ('KTStVK', 'contract'),
#  ('KThus', 'uni'),
#  ('K−ST', 'max'),
#  ('Management', 'Option'),
#  ('Market', 'Financial'),
#  ('Maturity', 'price'),
#  ('NN', 'is'),
#  ('NYCU', 'XMU'),
#  ('No', 'remainder'),
#  ('Now', 'Portfolio'),
#  ('Option', 'of'),
#  ('Payoff', 'Pricing'),
#  ('Portfolio', 'Management'),
#  ('Portfolio', 'payments'),
#  ('Portfolio', 'to'),
#  ('Price', 'Management'),
#  ('Price', 'price'),
#  ('Prices', 'Option'),
#  ('Pricing', 'YOption'),
#  ('Professor', 'Bortkiewicz'),
#  ('Proof', 'Management'),
#  ('Proof', 'equal'),
#  ('Properties', 'YElementary'),
#  ('Proposition', 'Management'),
#  ('Research', 'Blockchain'),
#  ('ST−K', 'max'),
#  ('Since', 'Management'),
#  ('St', 'CamK'),
#  ('St', 'KTStVK'),
#  ('St', 'VFt'),
#  ('StThus', 'uni'),
#  ('Statistics', 'of'),
#  ('Steb', 'Ft'),
#  ('Stet', 'FT'),
#  ('Ste−r', 'uni'),
#  ('Suppose', 'respectively'),
#  ('THe', 'of'),
#  ('The', 'Chapter'),
#  ('The', 'contracts'),
#  ('The', 'functions'),
#  ('The', 'is'),
#  ('Theory', 'YArbitrage'),
#  ('There', 'case'),
#  ('This', 'rich'),
#  ('Throughout', 'yields'),
#  ('Under', 'Proposition'),
#  ('Underlying', 'date'),
#  ('University', 'Charles'),
#  ('Universität', 'Humboldt'),
#  ('VFt', 'hence'),
#  ('VFt', 'that'),
#  ('VFt', 'uni'),
#  ('WB', 'ABWA'),
#  ('WISE', 'University'),
#  ('We', 'Management'),
#  ('We', 'months'),
#  ('XMU', 'WISE'),
#  ('YArbitrage', 'Management'),
#  ('YElementary', 'Management'),
#  ('YOption', 'Management'),
#  ('YPerfect', 'Management'),
#  ('additional', 'the'),
#  ('all', 'of'),
#  ('all', 'reinvest'),
#  ('allowed', 'is'),
#  ('always', 'is'),
#  ('an', 'of'),
#  ('an', 'sell'),
#  ('and', 'If'),
#  ('and', 'KThus'),
#  ('and', 'StThus'),
#  ('and', 'asset'),
#  ('and', 'cases'),
#  ('and', 'date'),
#  ('and', 'earnings'),
#  ('and', 'for'),
#  ('and', 'future'),
#  ('and', 'in'),
#  ('and', 'market'),
#  ('and', 'options'),
#  ('and', 'portfolios'),
#  ('and', 'value'),
#  ('and', '⊡buy'),
#  ('arbitrage', 'no'),
#  ('arbitrage', 'permit'),
#  ('are', 'There'),
#  ('are', 'future'),
#  ('are', 'price'),
#  ('are', 'prices'),
#  ('are', 'which'),
#  ('are', '⊡stocks'),
#  ('asset', 'an'),
#  ('asset', 'the'),
#  ('assumption', 'Basic'),
#  ('assumption', 'additional'),
#  ('assumption', 'the'),
#  ('at', 'Price'),
#  ('at', 'calculated'),
#  ('at', 'day'),
#  ('at', 'futures'),
#  ('at', 'option'),
#  ('at', 'zero'),
#  ('be', 'could'),
#  ('be', 'to'),
#  ('be', 'will'),
#  ('beginning', 'the'),
#  ('berlin', 'hu'),
#  ('bigger', 'always'),
#  ('buy', 'Portfolio'),
#  ('buy', 'to'),
#  ('by', 'only'),
#  ('calculated', 'period'),
#  ('calculation', 'loss'),
#  ('call', 'of'),
#  ('called', 'is'),
#  ('case', 'Proof'),
#  ('cases', 'Management'),
#  ('change', 'we'),
#  ('changes', 'Since'),
#  ('consider', 'Now'),
#  ('considered', 'be'),
#  ('constant', 'is'),
#  ('constant', 'of'),
#  ('contains', 'portfolio'),
#  ('continuous', 'have'),
#  ('continuous', 'with'),
#  ('contract', 'Forward'),
#  ('contract', 'forward'),
#  ('contract', 'the'),
#  ('contracts', 'future'),
#  ('corresponding', 'the'),
#  ('costs', 'and'),
#  ('costs', 'transaction'),
#  ('could', 'even'),
#  ('credit', 'rate'),
#  ('cumulative', 'the'),
#  ('current', 'same'),
#  ('current', 'with'),
#  ('date', 'Maturity'),
#  ('date', 'expiration'),
#  ('date', 'maturity'),
#  ('day', 'After'),
#  ('day', 'at'),
#  ('day', 'every'),
#  ('day', 'of'),
#  ('day', 'on'),
#  ('de', 'berlin'),
#  ('derivatives', 'of'),
#  ('different', 'for'),
#  ('different', 'on'),
#  ('differing', 'and'),
#  ('discount', 'if'),
#  ('discrete', 'pays'),
#  ('discrete', 'with'),
#  ('dividend', 'all'),
#  ('dividend', 'continuous'),
#  ('dividend', 'no'),
#  ('dividends', 'discrete'),
#  ('dividendsCoupon', 'discrete'),
#  ('dividends\nThen', 'continuous'),
#  ('divisible', 'unlimitedly'),
#  ('during', 'constant'),
#  ('during', 'rate'),
#  ('during', 'underlying'),
#  ('eN', 'Ft−Ft−'),
#  ('earnings', 'all'),
#  ('equal', 'are'),
#  ('equal', 'is'),
#  ('equal', 'or'),
#  ('er', 'uni'),
#  ('even', 'THe'),
#  ('every', 'settled'),
#  ('expiration', 'the'),
#  ('following', 'the'),
#  ('for', 'assumption'),
#  ('for', 'have'),
#  ('for', 'in'),
#  ('for', 'markets'),
#  ('for', 'rate'),
#  ('for', 'that'),
#  ('forward', 'in'),
#  ('forward', 'of'),
#  ('forward', 'the'),
#  ('from', 'months'),
#  ('fulﬁl', 'to'),
#  ('function', 'payoff'),
#  ('functions', 'Payoff'),
#  ('future', 'the'),
#  ('future', 'with'),
#  ('futures', 'the'),
#  ('have', 'We'),
#  ('have', 'contract'),
#  ('have', 'we'),
#  ('have', 'zerobonds'),
#  ('hence', 'and'),
#  ('holds', 'following'),
#  ('hu', 'wiwi'),
#  ('if', 'ITM'),
#  ('if', 'premium'),
#  ('in', 'However'),
#  ('in', 'Inserting'),
#  ('in', 'changes'),
#  ('in', 'of'),
#  ('in', 'payments'),
#  ('in', 'position'),
#  ('interest', 'Continuous'),
#  ('interest', 'constant'),
#  ('interest', 'credit'),
#  ('interest', 'the'),
#  ('interest', '⊡debit'),
#  ('interval', 'time'),
#  ('intrinsic', 'its'),
#  ('inﬁnitely', 'be'),
#  ('is', 'If'),
#  ('is', 'call'),
#  ('is', 'day'),
#  ('is', 'maturity'),
#  ('is', 'option'),
#  ('is', 'price'),
#  ('is', 'put'),
#  ('is', 'rate'),
#  ('is', 'selling'),
#  ('is', 'value'),
#  ('its', 'if'),
#  ('less', 'risk'),
#  ('long', 'DtPortfolio'),
#  ('long', 'Portfolio'),
#  ('long', 'and'),
#  ('loss', 'proﬁt'),
#  ('lvb', 'Center'),
#  ('market', 'perfect'),
#  ('markets', 'stock'),
#  ('maturity', 'at'),
#  ('maturity', 'strike'),
#  ('maturity', 'the'),
#  ('maturity', 'to'),
#  ('max', 'ST−K'),
#  ('max', 'is'),
#  ('money', 'the'),
#  ('months', 'and'),
#  ('months', 'for'),
#  ('must', 'derivatives'),
#  ('negative', 'non'),
#  ('no', 'are'),
#  ('no', 'of'),
#  ('non', 'are'),
#  ('nonzero', 'is'),
#  ('not', 'must'),
#  ('now', 'from'),
#  ('of', 'Basics'),
#  ('of', 'Price'),
#  ('of', 'Professor'),
#  ('of', 'Properties'),
#  ('of', 'assumption'),
#  ('of', 'beginning'),
#  ('of', 'calculation'),
#  ('of', 'function'),
#  ('of', 'maturity'),
#  ('of', 'payments'),
#  ('of', 'price'),
#  ('of', 'prices'),
#  ('of', 'principle'),
#  ('of', 'proﬁt'),
#  ('of', 'shares'),
#  ('of', 'total'),
#  ('of', 'value'),
#  ('on', 'asset'),
#  ('on', 'return'),
#  ('only', 'day'),
#  ('only', 'differing'),
#  ('option', 'American'),
#  ('option', 'An'),
#  ('option', 'European'),
#  ('options', 'American'),
#  ('or', 'than'),
#  ('payment', 'dividend'),
#  ('payments', 'dividend'),
#  ('payments', 'dividendsCoupon'),
#  ('payoff', 'The'),
#  ('pays', 'asset'),
#  ('perfect', 'of'),
#  ('period', 'time'),
#  ('permit', 'not'),
#  ('portfolio', 'change'),
#  ('portfolio', 'consider'),
#  ('portfolio', 'date'),
#  ('portfolios', 'two'),
#  ('portfolios', '⊡two'),
#  ('position', 'long'),
#  ('position', 'short'),
#  ('premium', 'have'),
#  ('price', 'Delivery'),
#  ('price', 'Underlying'),
#  ('price', 'forward'),
#  ('price', 'the'),
#  ('price', '⊡the'),
#  ('prices', 'Arbitrage'),
#  ('prices', 'different'),
#  ('prices', 'the'),
#  ('prices', '⊡call'),
#  ('prices', '⊡option'),
#  ('principle', 'the'),
#  ('proﬁt', 'The'),
#  ('proﬁt', 'less'),
#  ('put', 'of'),
#  ('rate', 'interest'),
#  ('reinvest', 'and'),
#  ('related', 'costs'),
#  ('remainder', 'the'),
#  ('respectively', 'and'),
#  ('return', 'cumulative'),
#  ('rich', 'inﬁnitely'),
#  ('risk', 'be'),
#  ('same', 'the'),
#  ('same', 'value'),
#  ('sell', 'and'),
#  ('selling', '⊡short'),
#  ('settled', 'are'),
#  ('shares', 'buy'),
#  ('short', 'and'),
#  ('show', 'to'),
#  ('some', 'for'),
#  ('stock', 'different'),
#  ('strike', 'with'),
#  ('taxes', '⊡no'),
#  ('terminal', 'the'),
#  ('than', 'bigger'),
#  ('that', 'Suppose'),
#  ('that', 'and'),
#  ('that', 'show'),
#  ('the', 'As'),
#  ('the', 'Assume'),
#  ('the', 'At'),
#  ('the', 'If'),
#  ('the', 'In'),
#  ('the', 'Throughout'),
#  ('the', 'Under'),
#  ('the', 'and'),
#  ('the', 'at'),
#  ('the', 'contract'),
#  ('the', 'day'),
#  ('the', 'dividends\nThen'),
#  ('the', 'during'),
#  ('the', 'for'),
#  ('the', 'fulﬁl'),
#  ('the', 'in'),
#  ('the', 'interval'),
#  ('the', 'is'),
#  ('the', 'maturity'),
#  ('the', 'of'),
#  ('the', 'only'),
#  ('the', 'some'),
#  ('the', 'to'),
#  ('the', 'violates'),
#  ('the', 'with'),
#  ('then', 'and'),
#  ('there', 'in'),
#  ('time', 'at'),
#  ('time', 'by'),
#  ('time', 'the'),
#  ('to', 'contract'),
#  ('to', 'equal'),
#  ('to', 'have'),
#  ('to', 'portfolio'),
#  ('to', 'related'),
#  ('to', 'time'),
#  ('to', 'used'),
#  ('total', 'contains'),
#  ('transaction', '⊡no'),
#  ('two', 'Consider'),
#  ('two', '⊡for'),
#  ('underlying', 'the'),
#  ('uni', 'Cam'),
#  ('uni', 'Fte−r'),
#  ('uni', 'NN'),
#  ('uni', 'St'),
#  ('uni', 'Steb'),
#  ('uni', 'Stet'),
#  ('uni', 'Ste−r'),
#  ('uni', 'VFt'),
#  ('uni', 'er'),
#  ('uni', '−t'),
#  ('unlimitedly', 'are'),
#  ('used', 'are'),
#  ('value', 'Intrinsic'),
#  ('value', 'current'),
#  ('value', 'have'),
#  ('value', 'intrinsic'),
#  ('value', 'terminal'),
#  ('value', 'the'),
#  ('violates', 'This'),
#  ('von', 'Ladislaus'),
#  ('we', 'For'),
#  ('we', 'If'),
#  ('we', 'payment'),
#  ('we', 'time'),
#  ('which', 'zerobonds'),
#  ('will', 'there'),
#  ('with', 'and'),
#  ('with', 'contract'),
#  ('with', 'portfolio'),
#  ('with', 'portfolios'),
#  ('with', 'zerobond'),
#  ('wiwi', 'lvb'),
#  ('yields', 'day'),
#  ('yields', 'for'),
#  ('zero', 'in'),
#  ('zero', 'of'),
#  ('zerobond', 'in'),
#  ('zerobonds', 'of'),
#  ('zu', 'Universität'),
#  ('−t', 'St'),
#  ('⊡buy', 'Theory'),
#  ('⊡call', 'option'),
#  ('⊡debit', 'Market'),
#  ('⊡for', 'Management'),
#  ('⊡no', 'costs'),
#  ('⊡no', 'rate'),
#  ('⊡option', 'Prices'),
#  ('⊡short', 'taxes'),
#  ('⊡stocks', 'allowed'),
#  ('⊡the', 'Management'),
#  ('⊡the', 'negative'),
#  ('⊡two', 'prices'),
#  ('⽟⼭學者', 'NYCU'),
#  (None, ''),
#  (None, None)}

# %% [markdown]
# -------------------------------

# %%
# deleting spaces
combined_pages_w = combined_pages.strip()

# lowercase
combined_pages_w = combined_pages_w.lower()

# deleting the newline command
combined_pages_w = re.sub(pattern = "\n", repl = " ", string = combined_pages_w)

# deleting the weblinks
combined_pages_w = re.sub(pattern = "http[^ ]*", repl = " ", string = combined_pages_w)

# deleting numbers and brackets etc.
combined_pages_w = re.sub(pattern = "\d", repl = "", string = combined_pages_w)
combined_pages_w = re.sub(pattern = "(\)|\(|,|\.|!|=|:|\[|\]|\{|\}|\'|\"|#|<|>|\%|\&|\?|\*|\/|-|\$|\+)", repl = "", string = combined_pages_w)

# deleting extra spaces
combined_pages_w = re.sub(pattern = "\s{2,}", repl = " ", string = combined_pages_w)
