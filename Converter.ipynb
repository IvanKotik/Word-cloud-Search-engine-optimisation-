# %% [markdown]
# # PDF converter

# %% [markdown]
# # Importing the PDF.
# Important to set the initial addresses of the import and export file

# %%
import PyPDF2
file_address = "/Users/ivankotik/Documents/NLP/testpdf2.pdf"
file_location = "/Users/ivankotik/Documents/NLP/"
file_name = "testjson2.json"
file_export = file_location + file_name
imported_pdf = open(file_address, 'rb')
transformed_pdf = PyPDF2.PdfFileReader(imported_pdf)
print(transformed_pdf.numPages)
# Out:
# 51

# %% [markdown]
# ## Convertation of the PDF to a string
# Transforming the PDF to string by page and combining it into one file

# %%
# setting initial variables
pageObjc_zero = transformed_pdf.getPage(1)
combined_pages = pageObjc_zero.extractText()

# initiating cycle
for i in range(2, transformed_pdf.numPages):
    pageObjc_placeholder = transformed_pdf.getPage(i)
    combined_pages = combined_pages + pageObjc_placeholder.extractText()

print(combined_pages)
# Out:
# The attractiveness of
# p-hackingMotivationDei Ex MachinisUnexpected powers or events,  saving a seemingly hopeless situation,  especially as a contrived plot device in a play or novel.Personae social role(s) or character(s) played by an actor;
#  originally referred to theatrical masks.
# The attractiveness of
# p-hackingMotivationScientiÞc progress ! (?)
# ÒNo editor wants to be the one !that rejects the next Black Scholes paper.Ó
#        Campbell R. Harvey!Black & Scholes formula for pricing a stock option 1965/1969-1970 !J Political Econ: reject without review
#  !Review of Economics and Statistics: analogous rejection
#  !J Finance published article 1972 !J Political Econ hesitantly published revised article in 1973
# http://gar
# Þeld.library.upenn.edu/classics1987/A1987J461500001.pdf
# Black, ScholesThe attractiveness of
# p-hacking!construct portfolii via 1st, 2nd, 3rd letter of ticker
#  !time frame 1926 - today; 1963 - today !do value weighting and equal weighting !id best long!short portfolio based on smallest p-value !# portfolii = 25 280 (max)p-hacking vs. $$$p-hacking http://eoddata.com/stocklist/NYSE/P.htm
# MotivationThe attractiveness of
# p-hackingp-hacking = outstanding results / citations
# Percent of research papers reporting support
#  for the tested hypothesis by Þeld (Fanelli, 2010)MotivationThe attractiveness of
# p-hackingMotivationChocolateThe attractiveness of
# p-hacking!case study with low carb diet +/- chocolate !small p-values  (spv) !conclusion: Chocolate in, weight loss out !Consumption of chocolate with a high cocoa content can signiÞcantly increase the
# success of weight-loss diets. The weight-loss effect of this diet occurs with a certain
# delay. Long-term weight loss, however, seems to occur easier and more successfully
# by adding chocolate. The effect of the chocolate, the so-called "weight loss turboÓ,
#  seems to go hand in hand with personal well-being, which was signiÞcantly higher than in the control groups.
# Motivationp-hacking chocolateDetails, Source
#  ; Spring 2015The attractiveness of
# p-hackingMotivationThe attractiveness of
# p-hacking!are spv's a
# win ? !conclusions from spv ?
#  !unconscious p-hacking ?MotivationChallengesThe attractiveness of
# p-hackingOutline1.Motivation ! 2.Case Study 3.Massaging, dredging,
# p-hacking 4.Asymptopia hackers 5.Critical examples 6.Redo it and show it! 7.Conclusions The attractiveness of
# p-hackingChocolate Case Study
# !standard clinical trial
#  !sample size n = 15 !18 variables !5 men, 11 women (19-67 Y) via Facebook (150 EUR p.P.), 1 dropout
#  !eat bitter chocolate as supplement to low-carb diet for 3W !create +/- chocolate groups
#  !measure weight, cholesterol, sodium,
# blood protein levels, sleep quality,
# well-being, etc.The attractiveness of
# p-hackingCase Study
# Ò [É] the subjects of the chocolate group found a signi
# Þcant improvement in their well-being
# (physically and mentally). The controlled improvement compared to the results of the low-
# carb group was
# highly signiÞcant (p<0.001). [É] A higher amount of ketones could be detected in the participants of the chocolate group than in the low-carb group. The measured results were found to be
# highly signiÞcant (p<0.01). [É] Exhaustion symptoms in particular, such as fatigue or the sensation of heavy legs,
# signiÞcantly decreased in the chocolate group. The signi
# Þcance of this survey was  p<0.001.Chocolate !erroneous statistically signi
# Þcant result (false positive)
#  !massaged (e.g. winsorized) data and p-hacking !Bohannon: ÒYou have to know how to read a scienti
# Þc paperÓThe attractiveness of
# p-hackingSidekick: SimpsonÕs paradox
# Massaging, dredging,
# p-hackingTreatment X
# Dr. med. A
# Dr. med. B
# Success Rate
# 83!%46!%!phenomenon in probability and statistics
#  !trend appears in several different groups of data
#  !but disappears or reverses when these groups are combined
# Success Rate for
# Dr. med. A
# Dr. med. B
# M90!%100!%F??Dr. med. A
# #MFSuccess
# 81020Failure9080Total
# 900100Dr. med. B
# #MFSuccess
# 100360Failure-540Total
# 100900Theorem 1: Always question your results!
# The attractiveness of
# p-hacking!Òmeasure of the strength of the evidence against
# Ò   (originally no ) !objectively separate Þndings of interest from noise
#  !get the observed value of the test statistic, or a value with even greater evidence against
# , if  is actually true.H0H1H0H0Massaging, dredging,
# p-hackingp-value (R. A. Fisher, 1925)
# Starting STAT studies                                                             A few weeks later
# The attractiveness of
# p-hacking!focuses on behavior/decision-making regime
#  between  /  !Ò[É] divide set by a system of ordered boundaries [É] such that
# as we pass across one boundary and proceed to the next, we
# come to a class of results
# which makes us more and more
# inclined, on the information available, to reject the hypothesis
# tested in favour of alternatives which differ from it by increasing
# amounts [É]Ó !Ò[É] associate with each contour level the  chance that, if [] is true, a result will occur
#  in random sampling lying beyond that level  [É] tells us nothing as to whether a  particular case [] is true [É]ÓH0H1H0H0Massaging, dredging,
# p-hackingÒMost e"cientÓ H-tests (Neyman & E. Pearson, 1933)Neyman & E. Pearson (son of K. Pearson)Neyman; PearsonThe attractiveness of
# p-hacking!Fisher (1925) contrasted use of the p-value  for statistical inference with NP method
# (ÒAcceptance ProceduresÓ)
#  !Fisher (1925 & 1971): Þxed signiÞcance levels especially , ,  convenient !Fisher (1935): ÒLady tasting teaÓ-experiment  !=0.05!=0.02!=0.01NeymanÐPearson vs. FisherMassaging, dredging,
# p-hackingFisherThe attractiveness of
# p-hacking!Ò : There is no difference in eating chocolate
# , yet how surprising could be the experimental evidence in real life?Ó
#  !p-value is a quantitative tool to challenge our initial belief (). !an spv experimental scenario is called statistically signiÞcant !standard experiment: fair coin
# ßips with :  !data = 1, 0, 1, 0, 1, 1, 1, 0, 0, É            B(n, ) distributedH0H0H0"=0.5"Massaging, dredging,
# p-hackingPurpose of the p-valueThe attractiveness of
# p-hackingMassaging, dredging,
# p-hackingLady tasting tea !Tea party in Cambridge in the
# twenties !Muriel Bristol: can taste whether milk or tea Þrst poured in cup
#  !Fisher: Sure, letÕs check for
# spv!The attractiveness of
# p-hackingMassaging, dredging,
# p-hackingLady tasting tea P(! ! allcorrect! ! )=1! ! numberofwaystoguess! ! =1(84)=170"0.014Answer! Truth
# Tea #1
# Milk #1Margin
# Tea #1
# 314Milk #1134Margin
# 448(k = # correct guesses)
# !8 randomly ordered cups of tea (70 variations in total)
#  !preparation methods
#  !4 prepared by
# Þrst pouring the tea, then adding milk !4 prepared by
# Þrst pouring the milk, then adding the tea !Select only 4 cups of one preparation method
# , e.g. Òall Tea #1
# Ó#k$3      The attractiveness of
# p-hacking! : lady not able to discriminate tea/milk Þrst poured;
#   !chance of result at least
#  as favourable towards her claim = 24%
#  !all  determined by  !row & column sums
# ,  & ,  Þxed; Truth/Answer independent
#  !  follows hypergeometric distribution                                H0"=0.5k$3xijx11n1n0s1s0x11x11%Hypergeometric(n,n1,s1)Massaging, dredging,
# p-hackingLady tasting tea Answer! Truth
# Tea #1
# Milk #1Margin
# Tea #1
# x11x10n1Milk #1x01x00n0Margin
# s1s0n#k$3The attractiveness of
# p-hacking!Tea-Tasting distribution assuming
# , e.g. Òchoose all 4 tea #1Ó  (o = correct cup chosen, x = correct not chosen)
#  !5 possible outcomes  !# successes"follows hypergeometric distributionH0p(0)=170,p(1)=1670,p(2)=3670,p(3)=1670,p(4)=170Success
# Selection Combinations
# # Combinations
# 0oooo1
# " 1 =
# 11ooox, ooxo, oxoo, xooo
# 4
# " 4 =
# 162ooxx, oxox, oxxo, xoxo, xxoo, xoox
# 6
# " 6 =
# 363oxxx, xoxx, xxox, xxxo
# 4
# " 4 =
# 164xxxx1
# " 1 =
# 1Total
# 70Massaging, dredging,
# p-hackingLady tasting tea The attractiveness of
# p-hackingSidekick: YatesÕ continuity correction
# !small samples ( !): approximation not quite correct (CLT)
#  !Yates correction
#                          !correction may tend to overcorrect (Type II error)
#  n=8#2Yates
# =n!i=1(!Oi&Ei!&0.5)2Ei#2Yates
# =n(!ad&bc!&n/2)2(a+c)(b+d)(a+b)(c+d)=8(!9&1!&4)2(4)(4)(4)(4)=128256=0.5Massaging, dredging,
# p-hackingYates:
#             Fisher:  p=0.23975p=0.24286The attractiveness of
# p-hackingMassaging, dredging,
# p-hackingSigniÞcance testing1.deÞne data stochastics 2.formulate initial belief  3.create a test statistic
# t 4.Þx signiÞcance level  5.deÞne critical values =  under the ÒNullÓ  6.Compare
# t with critical value, spv corresponds to Ò
#  Ò  7.Does it make sense ?H0!F&1(!)H0F(t)'!Theorem 1: Always question your results!
# The attractiveness of
# p-hackingAsymptopia hackers
# False Positives Experimentn   = 10 J   = 100 p   = 0.025 q_p  = -qnorm(0.025, 0, 1) t   = c( rep(0, J) ) for (j in 1:J){   x   = runif(n)   t[j]= sqrt(n) * ((mean(x) - 0.5)/sd(x))      if (abs(t[j]) > q_p)    {     p_Value = pnorm(abs(t[j]))     print(t[j])     print(1 - p_Value)     }   } plot( abs(t), pch = 16 ) abline(h = q_p, col = "blue")With higher ,  of crossing the
#  approaches 5%
# nPqp  The attractiveness of
# p-hackingAsymptopia hackers
# Sidekick: Edgeworth Expansion!Distribution of studentized t is approximated via normal cdf:
#     As ,  ÒresemblesÓ the Gaussian CDF more and more
# Fn(x)=((x)+n&1/2$(x)%(x)+)(n&1)n*+Fn(x) Figures: P-P plots for
# n=10 (left) and n=1000 (right)For n=10, 4.9% of the points have a value above 0.99The attractiveness of
# p-hackingAsymptopia hackers
# Sidekick: Cornish-Fisher Expansion
# !Critical values from the quantile function:
#     F&1n(!)=(&1(!)+n&1/2&(x)(&1(!)+)(n&1)Figures: Q-Q plots for
# n=10 (left) and n=1000 (right)For n=10, 6.3% of the points are smaller than 99% critical value
# The attractiveness of
# p-hackingR-based ExperimentAsymptopia hackers
# Probabilities to randomly reject
#   (  if uniform or  otherwise) in %  Uniform, Laplace, Student t (=1) and Cauchy distributions given n, J=1000 H0,[X]=0.5,[X]=0df !Student t and Cauchy probabilities do not converge to 5%, as their variance is
# undeÞnedThe attractiveness of
# p-hackingSidekick: Cauchy Robber!A bank robber shoots in uniform U(0,pi) angles on a wall
#  !A non STAT trained cop calc the mean of the bullet locations
#  !Cop is not happy, bullet hits are Cauchy distributed
#  !Cauchy pdf has no mean, moment,É !The distance and the angle then follow the relationship:
#  !=arctan
# (xs)Asymptopia hackers
# CauchyThe attractiveness of
# p-hackingSidekick: Extreme Value Theory
# !The Gumbel distribution can be used to estimate the distribution of maxima/minima of  samples of certain distributions, however, convergence is slow
# nF{x,'(n),((n)}=exp
# {&exp
# (&x&'(n)((n))}library("evd") n   = 100                      # n=10000 in green J   = 10000 x_c = c( rep(0, J) ) for (i in 1:J){     x      = max(rnorm(n))     x_c[i] = x } mu_n   = qnorm(1 - (1/n)) beta_n = qnorm(1 - (1/n) * exp(-1)) - mu_n y      = rgumbel(J, mu_n, beta_n) plot(sort(x_c), sort(y), pch=16, col="steelblue") lines(c(-10,10), c(-10,10))Gumbel  Asymptopia hackers
# The attractiveness of
# p-hackingUniform conÞdence bands (CB)!CB re
# ßects uncertainty about the curve  !conÞdence intervals (CI) idem but for a point  on the curve  !CI = covers with  probability the true
# ,  Þxed (narrower
# ) !CB = covers the whole curve m(.) with   probability (
# broader
# ) !CB  with coverage probability
#   m(.)m(x)1&!m(x)x1&!-m(x)±w(x)1&!P{supx!-m(x)&m(x)!/w(x)<c!}=1&!Asymptopia hackers
# The attractiveness of
# p-hackingUniform conÞdence bands (cont.)!M-smoothers : nonparametric curve estimators !deÞned as zero (w.r.t.
# )                         !with
#  denoting bounded monotone, antisymmetric
# function with    being suitable scaling parameters         mn(x)"GN(")=(nhn)&1n!i=1K{(x&Xi)/hn})(Yi&")):.*.&,r(t),dnP{(2&logn)1/2[suptr(t)!-m(t)&m(t)!/*(K)1/2&dn]<x}*n*+exp
# {&2exp
# (&x)}Asymptopia hackers
# The attractiveness of
# p-hackingCB & Bootstrap!CB precision improved by bootstrap (
# even broader
# ) !asymptotic theory methods = natural drawbacks w/ Þnite samples !smoothed asymptotic CB = much lower coverage probability
# Asymptopia hackers
# Theoretical signal curve:
# true curve
# , robust estimate with Tukey biweight loss and 5% con
# Þdence bands (dashed), local polynomial estimate, bootstrap band, n = 150.The attractiveness of
# p-hacking!Susan Athey CIÕs represented / interpreted as CBÕs
#  !CBÕs could include 0 (approximated function insigni
# Þcant) !no existing framework to compute CBÕs
# Modern application = Generalized RFÕs
# GRF-based treatment effect estimates with
# pointwise 95% CI that mother works for pay the year after third child
# Asymptopia hackers
# Asymptopia hackers
# The attractiveness of
# p-hackingCritical examples
# ÒIt is
# usual and convenient
#  for experimenters
# to take 5 per cent as a
# standard level of signi
# Þcance, [É]
# they are prepared to ignore all
# results which fail to reach this standard
# [É]  eliminate [É] further discussion [É]Ó R. A. Fisherp-value vs. wetware survival
# The Space Shuttle Challenger Explosion and the O-ringThe attractiveness of
# p-hackingp-value vs. nCOV-19 data controversy ?
# Critical examples
# Details, Source
#  ; Die Welt, 27.05.2020
# Details, Source
#  ; Deutschlandfunk Kultur, 26.05.2020
# The attractiveness of
# p-hackingp-value vs. model selectionCritical examples
# !variable selection using p-values is a bad idea !signiÞcant variables get included, insigniÞcant ones do not !variables that are collinear (high correlation) = big
# p-values  (does not mean the variables are not important)
#  !variable coefÞcient # 0 will eventually ("$) have arbitrarily large test statistic and arbitrarily small p-valuen!18 measurements = 60% chance of getting some spv result
#  !measurements not independent: probability can be even higher
#  !Þddling with the testÕs design (e.g. males/females,
# Þat/cryptocurrency
# etc.) and data to push p under 0.05Chocolate p-hacking The attractiveness of
# p-hackingCritical examples
# Publishing      The attractiveness of
# p-hackingCritical examples
# Why most FinE articles ÒsupportÓ stated Õs ?
# H0!better theories & hypotheses = better empirical Þndings ? !unlikely & hard to compare, c.f. particle physics
#  !HARKing (Hypothesizing After the Results are Known)
#  !data manipulation & interaction effects researcher/hypothesis
#  !un-/willingly, con
# Þrmation bias, data interpretation/handling
#  !lack of a replication/transparency culture
#  !data disclosure rarely requested in top journals
# The attractiveness of
# p-hackingCritical examples
# ASA statement on p-values!p-values can indicate problems data vs. speci
# Þed statistical model  !p-values # good measure of evidence for model/hypothesis.
#  !p-values # measure
#  of hypothesis = true, data = produced by
# random chance alone. !conclusions & decisions # based only on p-values !full reporting & transparency needed
# PThe attractiveness of
# p-hackingCorrect interpretation of
# p-values!p-values do not answer the question ÒGiven the data, what is the probability that
#  is trueÓ, but rather ÒGiven , what is the probability
# of this or more extreme dataÓ:
#   !Example: Schizophrenia detection test
#  !1000 cases,  - normal case,  - schizophrenia
#  !2% of cases are schizophrenic
#  !Test accuracy: 95% true positives, 97% true negatives
#  ! !However: ! !The test performance is much worse than the p-value would suggest H0H0P(D!H0)/P(H0!D)H0H1P(D!H0)=0.05P(H0!D)=0.9800.030.9800.03+0.0200.95=0.607Critical examples
# The attractiveness of
# p-hackingÒThe QuestionnaireÓ - testing for signi
# Þcance!treatment that may alter performance on a certain task.
#  !control & experimental groups (
# )  !independent means t-test (, , ) !which statements are ÒtrueÓ, ÒfalseÓ, or neither
#  1.absolutely disproved the null hypothesis
#  2.found the probability of the null hypothesis being true
#  3.absolutely proved experimental/alternative hypothesis
#  4.can deduce the prob of the experimental hypothesis being true
#  5.know, if one decides to reject the null, the probability that one is
# making the wrong decision
#  6.have a reliable experimental
# Þnding in the sense that if,  hypothetically, the experiment were repeated a great number of
# times, you would obtain a signiÞcant result on 99% of occasions
#  !several/none statements may be correct
# n1=n2=20t=2.7df=18p=0.01Redo it and show it!The attractiveness of
# p-hacking!1, 3: signiÞcance tests can never prove
#  (or disprove
# ) Õs; only
# provide probabilistic information, at best
# corroborate
#  theories. !2, 4, 5: generally impossible to assign a probability to any
# hypothesis by applying signiÞcance tests !(1, 3) can not assign a probability of 1
#  !(2, 4) can not assign any other probability
#  !(1, 2, 3, 4) statements about probabilities of
# Õs only possible
# in alternative approach of Bayesian statistics.
#  !(5) similar to deÞnition of Type I error
# , but having rejected
# , decision would be wrong, if and only if the
#  is true !(2, 5)  in (5) Òmaking the wrong decisionÓ =
# ;  as (2) cannot be derived with  signiÞcance testing (NHST) !6: Òreplication fallacyÓ É
#  HHH0H0Pp(H0)PH0ÒThe QuestionnaireÓ (cont.)
# Redo it and show it!The attractiveness of
# p-hackingÒThe QuestionnaireÓ (cont.)
# !6: Òreplication fallacyÓ É
#  !NP: interpret
#  = relative frequency of rejections of
#  if  is true, here
# : no evidence of  being true !ÒIn the minds of many,
#  erroneously turned into the relative
# frequency of rejections of
# , that is, into the probability that
# signiÞcant results could be replicatedÓ (Gigerenzer, 1993)
#  !ÒThe level of signiÞcance measures the con
# Þdence that the results of the experiment would be repeatable under the
# conditions describedÓ (A.W. Melton, 1962)
# p=0.01H0H0H01&pH0Participants % who made at least one mistake; comparison to OakesÕ original study (1986)Redo it and show it!The attractiveness of
# p-hackingFurther literature
# !Loftus, G.R. (1991):  On the tyranny of hypothesis testing in the social sciences. !Gigerenzer, G. (1993):
#  ƒber den mechanischen Umgang mit statistischen Methoden. !Cohen, J. (1994):  The earth is round (p < .05).
#  !Loftus, G.R. (1994):  Why psychology will never be a real science until we change the
# way we analyze data. !Dar, R., Serlin, D., & Omer, H. (1994):
#  Misuse of statistical tests in three decades of psychotherapy
# research.
#  !Falk, R., & Greenbaum, W. (1995):
#  SigniÞcance tests die hard.
# Redo it and show it!The attractiveness of
# p-hackingQuantlets move science: Be Q-able!!Quantnet: share
# data and programs - easy!
#  !Collaboration via seamless GitHub integration !Boosting transparent
#  and reproducible
#  scienceRedo it and show it!The attractiveness of
# p-hackingRedo it and show it!The attractiveness of
# p-hackingWe choose to go to the Moon É
# Ò [É]
# not because [it is] easy, but because [it is] hard
# ; because that goal will serve to
# organize and measure the best of our energies and skills, because that challenge is one
# that we are willing to accept, one we are unwilling to postpone, and one we intend to win
# [É] .ÓRedo it and show it!The attractiveness of
# p-hackingThe pÕersIAWKHR2Redo it and show it!Ladislaus von Bortkiewicz Professor of Statistics
#  Humboldt-Universit−t zu Berlin  BRC Blockchain Research Center
#  lvb.wiwi.hu-berlin.de Charles University, WISE XMU, NCTU
# Thank you!!The attractiveness of
# p-hackingAppendixReferences
# !Wang et al. (2020) Clinical Characteristics of 138 Hospitalized Patients With 2019 Novel
# Coronavirus-Infected Pneumonia in Wuhan, China. JAMA. 2020 Feb 7. doi: 10.1001/
# jama.2020.1585. [Epub ahead of print] https://www.ncbi.nlm.nih.gov/pubmed/32031570
#  !iMedPub Journal ÒChocolateÓ
# https://web.archive.org/web/20181004164627/https://
# www.scribd.com/doc/266969860/Chocolate-causes-weight-loss
#  !ARTE Chocolate Documentary
# https://info.arte.tv/de/schlank-durch-schokolade
#  !ASA on P-Values
# https://www.amstat.org/asa/
# Þles/pdfs/P-ValueStatement.pdf
#  !Nature on P-Values
# https://www.nature.com/news/polopoly_fs/1.19503!/menu/main/
# topColumns/topLeftColumn/pdf/nature.2016.19503.pdf
#  !Cocoa Bean & Machete https://chocolatephayanak.com/the-chocolate-making-process/
#  !Fanelli, Daniele, 2010, ÔÔPositiveÕÕ results increase down the Hierarchy of the Sciences, PLoS
# ONE 5, e10068 !Auguste Compte https://commons.wikimedia.org/wiki/Category:Auguste_Comte !Tea Tasting
# https://www.eastamericangroup.com/products/beverages/tea-tisanes/
#  !Neyman & Pearson https://errorstatistics.com/2018/12/01/neyman-pearson-tests-an-episode-
# in-anglo-polish-collaboration-excerpt-from-excursion-1-3-2/
# The attractiveness of
# p-hackingAppendix!Silke Janitza, Harald Binder, Anne-Laure Boulesteix (2014) Pitfalls of hypothesis tests and model
# selection on bootstrap samples: causes and consequences in biometrical applications. https://epub.ub.uni-muenchen.de/21889/7/TR.pdf !Wolfgang H−rdle. 9. April 1992. Applied Nonparametric Regression. Econometric Society
# Monographs, Band 19. !H−rdle, W, Ritov, Y, Wang, W (2013) Tie the Straps: Uniform Bootstrap Con
# Þdence Bands for Bounded Inßuence Curve Estimators. J. Multivariate Analysis, 134, 129-145, doi: https://doi.org/10.1016/j.jmva.2014.11.003

# %% [markdown]
# ## REGEX-pattern cleaning
# Data must be cleaned of empty spaces, web links and other junk

# %%
combined_pages_w = combined_pages.strip()
combined_pages_w

import re
combined_pages_w = re.sub(pattern = "\n", repl = "", string = combined_pages_w)
combined_pages_w = re.sub(pattern = "http[^ ]*", repl = " ", string = combined_pages_w)
combined_pages_w = re.sub(pattern = "[^\w\-]", repl = " ", string = combined_pages_w)
combined_pages_w = re.sub(pattern = "\d", repl = " ", string = combined_pages_w)
combined_pages_w = re.sub(pattern = " +", repl = " ", string = combined_pages_w)

combined_pages_w = combined_pages_w.lower()

combined_pages_w
# Out:
# 'the attractiveness of p-hackingmotivationdei ex machinisunexpected powers or events saving a seemingly hopeless situation especially as a contrived plot device in a play or novel personae social role s or character s played by an actor originally referred to theatrical masks the attractiveness of p-hackingmotivationscientiþc progress òno editor wants to be the one that rejects the next black scholes paper ó campbell r harvey black scholes formula for pricing a stock option - j political econ reject without review review of economics and statistics analogous rejection j finance published article j political econ hesitantly published revised article in scholesthe attractiveness of p-hacking construct portfolii via st nd rd letter of ticker time frame - today - today do value weighting and equal weighting id best long short portfolio based on smallest p-value portfolii max p-hacking vs p-hacking attractiveness of p-hackingp-hacking outstanding results citationspercent of research papers reporting support for the tested hypothesis by þeld fanelli motivationthe attractiveness of p-hackingmotivationchocolatethe attractiveness of p-hacking case study with low carb diet - chocolate small p-values spv conclusion chocolate in weight loss out consumption of chocolate with a high cocoa content can signiþcantly increase the success of weight-loss diets the weight-loss effect of this diet occurs with a certain delay long-term weight loss however seems to occur easier and more successfully by adding chocolate the effect of the chocolate the so-called weight loss turboó seems to go hand in hand with personal well-being which was signiþcantly higher than in the control groups motivationp-hacking chocolatedetails source spring the attractiveness of p-hackingmotivationthe attractiveness of p-hacking are spv s a win conclusions from spv unconscious p-hacking motivationchallengesthe attractiveness of p-hackingoutline motivation case study massaging dredging p-hacking asymptopia hackers critical examples redo it and show it conclusions the attractiveness of p-hackingchocolate case study standard clinical trial sample size n variables men women - y via facebook eur p p dropout eat bitter chocolate as supplement to low-carb diet for w create - chocolate groups measure weight cholesterol sodium blood protein levels sleep quality well-being etc the attractiveness of p-hackingcase studyò é the subjects of the chocolate group found a signiþcant improvement in their well-being physically and mentally the controlled improvement compared to the results of the low-carb group was highly signiþcant p é a higher amount of ketones could be detected in the participants of the chocolate group than in the low-carb group the measured results were found to be highly signiþcant p é exhaustion symptoms in particular such as fatigue or the sensation of heavy legs signiþcantly decreased in the chocolate group the signiþcance of this survey was p chocolate erroneous statistically signiþcant result false positive massaged e g winsorized data and p-hacking bohannon òyou have to know how to read a scientiþc paperóthe attractiveness of p-hackingsidekick simpsonõs paradoxmassaging dredging p-hackingtreatment xdr med adr med bsuccess rate phenomenon in probability and statistics trend appears in several different groups of data but disappears or reverses when these groups are combinedsuccess rate fordr med adr med bm f dr med a mfsuccess failure total dr med b mfsuccess failure- total theorem always question your results the attractiveness of p-hacking òmeasure of the strength of the evidence against ò originally no objectively separate þndings of interest from noise get the observed value of the test statistic or a value with even greater evidence against if is actually true h h h h massaging dredging p-hackingp-value r a fisher starting stat studies a few weeks laterthe attractiveness of p-hacking focuses on behavior decision-making regime between ò é divide set by a system  ...

# %% [markdown]
# *~unfortunately not all cases can be accounted for due to the unorganised nature of the imported presentations*

# %% [markdown]
# ## Dictionary creation
# Splitting the string into words

# %%
dictionary = dict()
combined_pages_w
words = combined_pages_w.split(" ")
words
# Out:
# ['the',
#  'attractiveness',
#  'of',
#  'p-hackingmotivationdei',
#  'ex',
#  'machinisunexpected',
#  'powers',
#  'or',
#  'events',
#  'saving',
#  'a',
#  'seemingly',
#  'hopeless',
#  'situation',
#  'especially',
#  'as',
#  'a',
#  'contrived',
#  'plot',
#  'device',
#  'in',
#  'a',
#  'play',
#  'or',
#  'novel',
#  'personae',
#  'social',
#  'role',
#  's',
#  'or',
#  'character',
#  's',
#  'played',
#  'by',
#  'an',
#  'actor',
#  'originally',
#  'referred',
#  'to',
#  'theatrical',
#  'masks',
#  'the',
#  'attractiveness',
#  'of',
#  'p-hackingmotivationscientiþc',
#  'progress',
#  'òno',
#  'editor',
#  'wants',
#  'to',
#  'be',
#  'the',
#  'one',
#  'that',
#  'rejects',
#  'the',
#  'next',
#  'black',
#  'scholes',
#  'paper',
#  'ó',
#  'campbell',
#  'r',
#  'harvey',
#  'black',
#  'scholes',
#  'formula',
#  'for',
#  'pricing',
#  'a',
#  'stock',
#  'option',
#  '-',
#  'j',
#  'political',
#  'econ',
#  'reject',
#  'without',
#  'review',
#  'review',
#  'of',
#  'economics',
#  'and',
#  'statistics',
#  'analogous',
#  'rejection',
#  'j',
#  'finance',
#  'published',
#  'article',
#  'j',
#  'political',
#  'econ',
#  'hesitantly',
#  'published',
#  'revised',
#  'article',
#  'in',
#  'scholesthe',
#  'attractiveness',
#  'of',
#  'p-hacking',
#  'construct',
#  'portfolii',
#  'via',
#  'st',
#  'nd',
#  'rd',
#  'letter',
#  'of',
#  'ticker',
#  'time',
#  'frame',
#  '-',
#  'today',
#  '-',
#  'today',
#  'do',
#  'value',
#  'weighting',
#  'and',
#  'equal',
#  'weighting',
#  'id',
#  'best',
#  'long',
#  'short',
#  'portfolio',
#  'based',
#  'on',
#  'smallest',
#  'p-value',
#  'portfolii',
#  'max',
#  'p-hacking',
#  'vs',
#  'p-hacking',
#  'attractiveness',
#  'of',
#  'p-hackingp-hacking',
#  'outstanding',
#  'results',
#  'citationspercent',
#  'of',
#  'research',
#  'papers',
#  'reporting',
#  'support',
#  'for',
#  'the',
#  'tested',
#  'hypothesis',
#  'by',
#  'þeld',
#  'fanelli',
#  'motivationthe',
#  'attractiveness',
#  'of',
#  'p-hackingmotivationchocolatethe',
#  'attractiveness',
#  'of',
#  'p-hacking',
#  'case',
#  'study',
#  'with',
#  'low',
#  'carb',
#  'diet',
#  '-',
#  'chocolate',
#  'small',
#  'p-values',
#  'spv',
#  'conclusion',
#  'chocolate',
#  'in',
#  'weight',
#  'loss',
#  'out',
#  'consumption',
#  'of',
#  'chocolate',
#  'with',
#  'a',
#  'high',
#  'cocoa',
#  'content',
#  'can',
#  'signiþcantly',
#  'increase',
#  'the',
#  'success',
#  'of',
#  'weight-loss',
#  'diets',
#  'the',
#  'weight-loss',
#  'effect',
#  'of',
#  'this',
#  'diet',
#  'occurs',
#  'with',
#  'a',
#  'certain',
#  'delay',
#  'long-term',
#  'weight',
#  'loss',
#  'however',
#  'seems',
#  'to',
#  'occur',
#  'easier',
#  'and',
#  'more',
#  'successfully',
#  'by',
#  'adding',
#  'chocolate',
#  'the',
#  'effect',
#  'of',
#  'the',
#  'chocolate',
#  'the',
#  'so-called',
#  'weight',
#  'loss',
#  'turboó',
#  'seems',
#  'to',
#  'go',
#  'hand',
#  'in',
#  'hand',
#  'with',
#  'personal',
#  'well-being',
#  'which',
#  'was',
#  'signiþcantly',
#  'higher',
#  'than',
#  'in',
#  'the',
#  'control',
#  'groups',
#  'motivationp-hacking',
#  'chocolatedetails',
#  'source',
#  'spring',
#  'the',
#  'attractiveness',
#  'of',
#  'p-hackingmotivationthe',
#  'attractiveness',
#  'of',
#  'p-hacking',
#  'are',
#  'spv',
#  's',
#  'a',
#  'win',
#  'conclusions',
#  'from',
#  'spv',
#  'unconscious',
#  'p-hacking',
#  'motivationchallengesthe',
#  'attractiveness',
#  'of',
#  'p-hackingoutline',
#  'motivation',
#  'case',
#  'study',
#  'massaging',
#  'dredging',
#  'p-hacking',
#  'asymptopia',
#  'hackers',
#  'critical',
#  'examples',
#  'redo',
#  'it',
#  'and',
#  'show',
#  'it',
#  'conclusions',
#  'the',
#  'attractiveness',
#  'of',
#  'p-hackingchocolate',
#  'case',
#  'study',
#  'standard',
#  'clinical',
#  'trial',
#  'sample',
#  'size',
#  'n',
#  'variables',
#  'men',
#  'women',
#  '-',
#  'y',
#  'via',
#  'facebook',
#  'eur',
#  'p',
#  'p',
#  'dropout',
#  'eat',
#  'bitter',
#  'chocolate',
#  'as',
#  'supplement',
#  'to',
#  'low-carb',
#  'diet',
#  'for',
#  'w',
#  'create',
#  '-',
#  'chocolate',
#  'groups',
#  'measure',
#  'weight',
#  'cholesterol',
#  'sodium',
#  'blood',
#  'protein',
#  'levels',
#  'sleep',
#  'quality',
#  'well-being',
#  'etc',
#  'the',
#  'attractiveness',
#  'of',
#  'p-hackingcase',
#  'studyò',
#  'é',
#  'the',
#  'subjects',
#  'of',
#  'the',
#  'chocolate',
#  'group',
#  'found',
#  'a',
#  'signiþcant',
#  'improvement',
#  'in',
#  'their',
#  'well-being',
#  'physically',
#  'and',
#  'mentally',
#  'the',
#  'controlled',
#  'improvement',
#  'compared',
#  'to',
#  'the',
#  'results',
#  'of',
#  'the',
#  'low-carb',
#  'group',
#  'was',
#  'highly',
#  'signiþcant',
#  'p',
#  'é',
#  'a',
#  'higher',
#  'amount',
#  'of',
#  'ketones',
#  'could',
#  'be',
#  'detected',
#  'in',
#  'the',
#  'participants',
#  'of',
#  'the',
#  'chocolate',
#  'group',
#  'than',
#  'in',
#  'the',
#  'low-carb',
#  'group',
#  'the',
#  'measured',
#  'results',
#  'were',
#  'found',
#  'to',
#  'be',
#  'highly',
#  'signiþcant',
#  'p',
#  'é',
#  'exhaustion',
#  'symptoms',
#  'in',
#  'particular',
#  'such',
#  'as',
#  'fatigue',
#  'or',
#  'the',
#  'sensation',
#  'of',
#  'heavy',
#  'legs',
#  'signiþcantly',
#  'decreased',
#  'in',
#  'the',
#  'chocolate',
#  'group',
#  'the',
#  'signiþcance',
#  'of',
#  'this',
#  'survey',
#  'was',
#  'p',
#  'chocolate',
#  'erroneous',
#  'statistically',
#  'signiþcant',
#  'result',
#  'false',
#  'positive',
#  'massaged',
#  'e',
#  'g',
#  'winsorized',
#  'data',
#  'and',
#  'p-hacking',
#  'bohannon',
#  'òyou',
#  'have',
#  'to',
#  'know',
#  'how',
#  'to',
#  'read',
#  'a',
#  'scientiþc',
#  'paperóthe',
#  'attractiveness',
#  'of',
#  'p-hackingsidekick',
#  'simpsonõs',
#  'paradoxmassaging',
#  'dredging',
#  'p-hackingtreatment',
#  'xdr',
#  'med',
#  'adr',
#  'med',
#  'bsuccess',
#  'rate',
#  'phenomenon',
#  'in',
#  'probability',
#  'and',
#  'statistics',
#  'trend',
#  'appears',
#  'in',
#  'several',
#  'different',
#  'groups',
#  'of',
#  'data',
#  'but',
#  'disappears',
#  'or',
#  'reverses',
#  'when',
#  'these',
#  'groups',
#  'are',
#  'combinedsuccess',
#  'rate',
#  'fordr',
#  'med',
#  'adr',
#  'med',
#  'bm',
#  'f',
#  'dr',
#  'med',
#  'a',
#  'mfsuccess',
#  'failure',
#  'total',
#  'dr',
#  'med',
#  'b',
#  'mfsuccess',
#  'failure-',
#  'total',
#  'theorem',
#  'always',
#  'question',
#  'your',
#  'results',
#  'the',
#  'attractiveness',
#  'of',
#  'p-hacking',
#  'òmeasure',
#  'of',
#  'the',
#  'strength',
#  'of',
#  'the',
#  'evidence',
#  'against',
#  'ò',
#  'originally',
#  'no',
#  'objectively',
#  'separate',
#  'þndings',
#  'of',
#  'interest',
#  'from',
#  'noise',
#  'get',
#  'the',
#  'observed',
#  'value',
#  'of',
#  'the',
#  'test',
#  'statistic',
#  'or',
#  'a',
#  'value',
#  'with',
#  'even',
#  'greater',
#  'evidence',
#  'against',
#  'if',
#  'is',
#  'actually',
#  'true',
#  'h',
#  'h',
#  'h',
#  'h',
#  'massaging',
#  'dredging',
#  'p-hackingp-value',
#  'r',
#  'a',
#  'fisher',
#  'starting',
#  'stat',
#  'studies',
#  'a',
#  'few',
#  'weeks',
#  'laterthe',
#  'attractiveness',
#  'of',
#  'p-hacking',
#  'focuses',
#  'on',
#  'behavior',
#  'decision-making',
#  'regime',
#  'between',
#  'ò',
#  'é',
#  'divide',
#  'set',
#  'by',
#  'a',
#  'system',
#  'of',
#  'ordered',
#  'boundaries',
#  'é',
#  'such',
#  'that',
#  'as',
#  'we',
#  'pass',
#  'across',
#  'one',
#  'boundary',
#  'and',
#  'proceed',
#  'to',
#  'the',
#  'next',
#  'we',
#  'come',
#  'to',
#  'a',
#  'class',
#  'of',
#  'results',
#  'which',
#  'makes',
#  'us',
#  'more',
#  'and',
#  'more',
#  'inclined',
#  'on',
#  'the',
#  'information',
#  'available',
#  'to',
#  'reject',
#  'the',
#  'hypothesis',
#  'tested',
#  'in',
#  'favour',
#  'of',
#  'alternatives',
#  'which',
#  'differ',
#  'from',
#  'it',
#  'by',
#  'increasing',
#  'amounts',
#  'é',
#  'ó',
#  'ò',
#  'é',
#  'associate',
#  'with',
#  'each',
#  'contour',
#  'level',
#  'the',
#  'chance',
#  'that',
#  'if',
#  'is',
#  'true',
#  'a',
#  'result',
#  'will',
#  'occur',
#  'in',
#  'random',
#  'sampling',
#  'lying',
#  'beyond',
#  'that',
#  'level',
#  'é',
#  'tells',
#  'us',
#  'nothing',
#  'as',
#  'to',
#  'whether',
#  'a',
#  'particular',
#  'case',
#  'is',
#  'true',
#  'é',
#  'óh',
#  'h',
#  'h',
#  'h',
#  'massaging',
#  'dredging',
#  'p-hackingòmost',
#  'e',
#  'cientó',
#  'h-tests',
#  'neyman',
#  'e',
#  'pearson',
#  'neyman',
#  'e',
#  'pearson',
#  'son',
#  'of',
#  'k',
#  'pearson',
#  'neyman',
#  'pearsonthe',
#  'attractiveness',
#  'of',
#  'p-hacking',
#  'fisher',
#  'contrasted',
#  'use',
#  'of',
#  'the',
#  'p-value',
#  'for',
#  'statistical',
#  'inference',
#  'with',
#  'np',
#  'method',
#  'òacceptance',
#  'proceduresó',
#  'fisher',
#  'þxed',
#  'signiþcance',
#  'levels',
#  'especially',
#  'convenient',
#  'fisher',
#  'òlady',
#  'tasting',
#  'teaó-experiment',
#  'neymanðpearson',
#  'vs',
#  'fishermassaging',
#  'dredging',
#  'p-hackingfisherthe',
#  'attractiveness',
#  'of',
#  'p-hacking',
#  'ò',
#  'there',
#  'is',
#  'no',
#  'difference',
#  'in',
#  'eating',
#  'chocolate',
#  'yet',
#  'how',
#  'surprising',
#  'could',
#  'be',
#  'the',
#  'experimental',
#  'evidence',
#  'in',
#  'real',
#  'life',
#  'ó',
#  'p-value',
#  'is',
#  'a',
#  'quantitative',
#  'tool',
#  'to',
#  'challenge',
#  'our',
#  'initial',
#  'belief',
#  'an',
#  'spv',
#  'experimental',
#  'scenario',
#  'is',
#  'called',
#  'statistically',
#  'signiþcant',
#  'standard',
#  'experiment',
#  'fair',
#  'coin',
#  'ßips',
#  'with',
#  'data',
#  'é',
#  'b',
#  'n',
#  'distributedh',
#  'h',
#  'h',
#  'massaging',
#  'dredging',
#  'p-hackingpurpose',
#  'of',
#  'the',
#  'p-valuethe',
#  'attractiveness',
#  'of',
#  'p-hackingmassaging',
#  'dredging',
#  'p-hackinglady',
#  'tasting',
#  'tea',
#  'tea',
#  'party',
#  'in',
#  'cambridge',
#  'in',
#  'the',
#  'twenties',
#  'muriel',
#  'bristol',
#  'can',
#  'taste',
#  'whether',
#  'milk',
#  'or',
#  'tea',
#  'þrst',
#  'poured',
#  'in',
#  'cup',
#  'fisher',
#  'sure',
#  'letõs',
#  'check',
#  'for',
#  'spv',
#  'the',
#  'attractiveness',
#  'of',
#  'p-hackingmassaging',
#  'dredging',
#  'p-hackinglady',
#  'tasting',
#  'tea',
#  'p',
#  'allcorrect',
#  'numberofwaystoguess',
#  'answer',
#  'truthtea',
#  'milk',
#  'margintea',
#  'milk',
#  'margin',
#  'k',
#  'correct',
#  'guesses',
#  'randomly',
#  'ordered',
#  'cups',
#  'of',
#  'tea',
#  'variations',
#  'in',
#  'total',
#  'preparation',
#  'methods',
#  'prepared',
#  'by',
#  'þrst',
#  'pouring',
#  'the',
#  'tea',
#  'then',
#  'adding',
#  'milk',
#  'prepared',
#  'by',
#  'þrst',
#  'pouring',
#  'the',
#  'milk',
#  'then',
#  'adding',
#  'the',
#  'tea',
#  'select',
#  'only',
#  'cups',
#  'of',
#  'one',
#  'preparation',
#  'method',
#  'e',
#  'g',
#  'òall',
#  'tea',
#  'ó',
#  'k',
#  'the',
#  'attractiveness',
#  'of',
#  'p-hacking',
#  'lady',
#  'not',
#  'able',
#  'to',
#  'discriminate',
#  'tea',
#  'milk',
#  'þrst',
#  'poured',
#  'chance',
#  'of',
#  'result',
#  'at',
#  'least',
#  'as',
#  'favourable',
#  'towards',
#  'her',
#  'claim',
#  'all',
#  'determined',
#  'by',
#  'row',
#  'column',
#  'sums',
#  'þxed',
#  'truth',
#  'answer',
#  'independent',
#  'follows',
#  'hypergeometric',
#  'distribution',
#  'h',
#  'k',
#  'xijx',
#  'n',
#  'n',
#  's',
#  's',
#  'x',
#  'x',
#  'hypergeometric',
#  'n',
#  'n',
#  's',
#  'massaging',
#  'dredging',
#  'p-hackinglady',
#  'tasting',
#  'tea',
#  'answer',
#  'truthtea',
#  'milk',
#  'margintea',
#  'x',
#  'x',
#  'n',
#  'milk',
#  'x',
#  'x',
#  'n',
#  'margins',
#  's',
#  'n',
#  'k',
#  'the',
#  'attractiveness',
#  'of',
#  'p-hacking',
#  'tea-tasting',
#  'distribution',
#  'assuming',
#  'e',
#  'g',
#  'òchoose',
#  'all',
#  'tea',
#  'ó',
#  'o',
#  'correct',
#  'cup',
#  'chosen',
#  'x',
#  'correct',
#  'not',
#  'chosen',
#  'possible',
#  'outcomes',
#  'successes',
#  'follows',
#  'hypergeometric',
#  'distributionh',
#  'p',
#  'p',
#  'p',
#  'p',
#  'p',
#  'successselection',
#  'combinations',
#  'combinations',
#  'oooo',
#  'ooox',
#  'ooxo',
#  'oxoo',
#  'xooo',
#  'ooxx',
#  'oxox',
#  ...]

# %% [markdown]
# ## Counting all of the occurances

# %%
for word in words:
    if word in dictionary:
        dictionary[word] = dictionary[word] + 1
    else:
        dictionary[word] = 1

dictionary
# Out:
# {'the': 118,
#  'attractiveness': 49,
#  'of': 117,
#  'p-hackingmotivationdei': 1,
#  'ex': 1,
#  'machinisunexpected': 1,
#  'powers': 1,
#  'or': 11,
#  'events': 1,
#  'saving': 1,
#  'a': 39,
#  'seemingly': 1,
#  'hopeless': 1,
#  'situation': 1,
#  'especially': 2,
#  'as': 12,
#  'contrived': 1,
#  'plot': 3,
#  'device': 1,
#  'in': 33,
#  'play': 1,
#  'novel': 2,
#  'personae': 1,
#  'social': 2,
#  'role': 1,
#  's': 7,
#  'character': 1,
#  'played': 1,
#  'by': 11,
#  'an': 2,
#  'actor': 1,
#  'originally': 2,
#  'referred': 1,
#  'to': 37,
#  'theatrical': 1,
#  'masks': 1,
#  'p-hackingmotivationscientiþc': 1,
#  'progress': 1,
#  'òno': 1,
#  'editor': 1,
#  'wants': 1,
#  'be': 13,
#  'one': 10,
#  'that': 16,
#  'rejects': 1,
#  'next': 2,
#  'black': 2,
#  'scholes': 2,
#  'paper': 1,
#  'ó': 6,
#  'campbell': 1,
#  'r': 9,
#  'harvey': 1,
#  'formula': 1,
#  'for': 17,
#  'pricing': 1,
#  'stock': 1,
#  'option': 1,
#  '-': 19,
#  'j': 18,
#  'political': 2,
#  'econ': 2,
#  'reject': 4,
#  'without': 1,
#  'review': 2,
#  'economics': 1,
#  'and': 36,
#  'statistics': 4,
#  'analogous': 1,
#  'rejection': 1,
#  'finance': 1,
#  'published': 2,
#  'article': 2,
#  'hesitantly': 1,
#  'revised': 1,
#  'scholesthe': 1,
#  'p-hacking': 17,
#  'construct': 1,
#  'portfolii': 2,
#  'via': 4,
#  'st': 1,
#  'nd': 1,
#  'rd': 1,
#  'letter': 1,
#  'ticker': 1,
#  'time': 1,
#  'frame': 1,
#  'today': 2,
#  'do': 4,
#  'value': 6,
#  'weighting': 2,
#  'equal': 1,
#  'id': 1,
#  'best': 3,
#  'long': 1,
#  'short': 1,
#  'portfolio': 1,
#  'based': 2,
#  'on': 13,
#  'smallest': 1,
#  'p-value': 4,
#  'max': 2,
#  'vs': 6,
#  'p-hackingp-hacking': 1,
#  'outstanding': 1,
#  'results': 11,
#  'citationspercent': 1,
#  'research': 3,
#  'papers': 1,
#  'reporting': 2,
#  'support': 1,
#  'tested': 2,
#  'hypothesis': 12,
#  'þeld': 1,
#  'fanelli': 2,
#  'motivationthe': 1,
#  'p-hackingmotivationchocolatethe': 1,
#  'case': 5,
#  'study': 4,
#  'with': 20,
#  'low': 1,
#  'carb': 1,
#  'diet': 3,
#  'chocolate': 14,
#  'small': 3,
#  'p-values': 12,
#  'spv': 7,
#  'conclusion': 1,
#  'weight': 4,
#  'loss': 4,
#  'out': 1,
#  'consumption': 1,
#  'high': 2,
#  'cocoa': 2,
#  'content': 1,
#  'can': 9,
#  'signiþcantly': 3,
#  'increase': 2,
#  'success': 1,
#  'weight-loss': 2,
#  'diets': 1,
#  'effect': 3,
#  'this': 4,
#  'occurs': 1,
#  'certain': 3,
#  'delay': 1,
#  'long-term': 1,
#  'however': 3,
#  'seems': 2,
#  'occur': 2,
#  'easier': 1,
#  'more': 5,
#  'successfully': 1,
#  'adding': 3,
#  'so-called': 1,
#  'turboó': 1,
#  'go': 2,
#  'hand': 2,
#  'personal': 1,
#  'well-being': 3,
#  'which': 5,
#  'was': 3,
#  'higher': 4,
#  'than': 4,
#  'control': 2,
#  'groups': 5,
#  'motivationp-hacking': 1,
#  'chocolatedetails': 1,
#  'source': 3,
#  'spring': 1,
#  'p-hackingmotivationthe': 1,
#  'are': 12,
#  'win': 2,
#  'conclusions': 3,
#  'from': 4,
#  'unconscious': 1,
#  'motivationchallengesthe': 1,
#  'p-hackingoutline': 1,
#  'motivation': 1,
#  'massaging': 7,
#  'dredging': 12,
#  'asymptopia': 6,
#  'hackers': 1,
#  'critical': 7,
#  'examples': 2,
#  'redo': 6,
#  'it': 22,
#  'show': 9,
#  'p-hackingchocolate': 1,
#  'standard': 4,
#  'clinical': 2,
#  'trial': 1,
#  'sample': 1,
#  'size': 1,
#  'n': 41,
#  'variables': 4,
#  'men': 1,
#  'women': 1,
#  'y': 4,
#  'facebook': 1,
#  'eur': 1,
#  'p': 23,
#  'dropout': 1,
#  'eat': 1,
#  'bitter': 1,
#  'supplement': 1,
#  'low-carb': 3,
#  'w': 9,
#  'create': 2,
#  'measure': 4,
#  'cholesterol': 1,
#  'sodium': 1,
#  'blood': 1,
#  'protein': 1,
#  'levels': 2,
#  'sleep': 1,
#  'quality': 1,
#  'etc': 2,
#  'p-hackingcase': 1,
#  'studyò': 1,
#  'é': 19,
#  'subjects': 1,
#  'group': 5,
#  'found': 3,
#  'signiþcant': 8,
#  'improvement': 2,
#  'their': 2,
#  'physically': 1,
#  'mentally': 1,
#  'controlled': 1,
#  'compared': 1,
#  'highly': 2,
#  'amount': 1,
#  'ketones': 1,
#  'could': 4,
#  'detected': 1,
#  'participants': 2,
#  'measured': 1,
#  'were': 2,
#  'exhaustion': 1,
#  'symptoms': 1,
#  'particular': 2,
#  'such': 2,
#  'fatigue': 1,
#  'sensation': 1,
#  'heavy': 1,
#  'legs': 1,
#  'decreased': 1,
#  'signiþcance': 10,
#  'survey': 1,
#  'erroneous': 1,
#  'statistically': 2,
#  'result': 5,
#  'false': 1,
#  'positive': 1,
#  'massaged': 1,
#  'e': 8,
#  'g': 7,
#  'winsorized': 1,
#  'data': 14,
#  'bohannon': 1,
#  'òyou': 1,
#  'have': 4,
#  'know': 2,
#  'how': 2,
#  'read': 1,
#  'scientiþc': 1,
#  'paperóthe': 1,
#  'p-hackingsidekick': 4,
#  'simpsonõs': 1,
#  'paradoxmassaging': 1,
#  'p-hackingtreatment': 1,
#  'xdr': 1,
#  'med': 6,
#  'adr': 2,
#  'bsuccess': 1,
#  'rate': 2,
#  'phenomenon': 1,
#  'probability': 14,
#  'trend': 1,
#  'appears': 1,
#  'several': 2,
#  'different': 1,
#  'but': 5,
#  'disappears': 1,
#  'reverses': 1,
#  'when': 1,
#  'these': 1,
#  'combinedsuccess': 1,
#  'fordr': 1,
#  'bm': 1,
#  'f': 5,
#  'dr': 2,
#  'mfsuccess': 2,
#  'failure': 1,
#  'total': 4,
#  'b': 4,
#  'failure-': 1,
#  'theorem': 2,
#  'always': 2,
#  'question': 3,
#  'your': 2,
#  'òmeasure': 1,
#  'strength': 1,
#  'evidence': 5,
#  'against': 2,
#  'ò': 6,
#  'no': 5,
#  'objectively': 1,
#  'separate': 1,
#  'þndings': 2,
#  'interest': 1,
#  'noise': 1,
#  'get': 2,
#  'observed': 1,
#  'test': 6,
#  'statistic': 3,
#  'even': 3,
#  'greater': 1,
#  'if': 9,
#  'is': 24,
#  'actually': 1,
#  'true': 13,
#  'h': 31,
#  'p-hackingp-value': 3,
#  'fisher': 6,
#  'starting': 1,
#  'stat': 2,
#  'studies': 1,
#  'few': 1,
#  'weeks': 1,
#  'laterthe': 1,
#  'focuses': 1,
#  'behavior': 1,
#  'decision-making': 1,
#  'regime': 1,
#  'between': 1,
#  'divide': 1,
#  'set': 1,
#  'system': 1,
#  'ordered': 2,
#  'boundaries': 1,
#  'we': 7,
#  'pass': 1,
#  'across': 1,
#  'boundary': 1,
#  'proceed': 1,
#  'come': 1,
#  'class': 1,
#  'makes': 1,
#  'us': 2,
#  'inclined': 1,
#  'information': 2,
#  'available': 1,
#  'favour': 1,
#  'alternatives': 1,
#  'differ': 1,
#  'increasing': 1,
#  'amounts': 1,
#  'associate': 1,
#  'each': 1,
#  'contour': 1,
#  'level': 5,
#  'chance': 4,
#  'will': 4,
#  'random': 2,
#  'sampling': 1,
#  'lying': 1,
#  'beyond': 1,
#  'tells': 1,
#  'nothing': 1,
#  'whether': 2,
#  'óh': 1,
#  'p-hackingòmost': 1,
#  'cientó': 1,
#  'h-tests': 1,
#  'neyman': 4,
#  'pearson': 4,
#  'son': 1,
#  'k': 7,
#  'pearsonthe': 1,
#  'contrasted': 1,
#  'use': 1,
#  'statistical': 3,
#  'inference': 1,
#  'np': 2,
#  'method': 2,
#  'òacceptance': 1,
#  'proceduresó': 1,
#  'þxed': 3,
#  'convenient': 2,
#  'òlady': 1,
#  'tasting': 6,
#  'teaó-experiment': 1,
#  'neymanðpearson': 1,
#  'fishermassaging': 1,
#  'p-hackingfisherthe': 1,
#  'there': 1,
#  'difference': 1,
#  'eating': 1,
#  'yet': 1,
#  'surprising': 1,
#  'experimental': 6,
#  'real': 2,
#  'life': 1,
#  'quantitative': 1,
#  'tool': 1,
#  'challenge': 2,
#  'our': 2,
#  'initial': 2,
#  'belief': 2,
#  'scenario': 1,
#  'called': 1,
#  'experiment': 3,
#  'fair': 1,
#  'coin': 1,
#  'ßips': 1,
#  'distributedh': 1,
#  'p-hackingpurpose': 1,
#  'p-valuethe': 1,
#  'p-hackingmassaging': 3,
#  'p-hackinglady': 4,
#  'tea': 13,
#  'party': 1,
#  'cambridge': 1,
#  'twenties': 1,
#  'muriel': 1,
#  'bristol': 1,
#  'taste': 1,
#  'milk': 8,
#  'þrst': 4,
#  'poured': 2,
#  'cup': 2,
#  'sure': 1,
#  'letõs': 1,
#  'check': 1,
#  'allcorrect': 1,
#  'numberofwaystoguess': 1,
#  'answer': 4,
#  'truthtea': 2,
#  'margintea': 2,
#  'margin': 1,
#  'correct': 4,
#  'guesses': 1,
#  'randomly': 2,
#  'cups': 2,
#  'variations': 1,
#  'preparation': 2,
#  'methods': 2,
#  'prepared': 3,
#  'pouring': 2,
#  'then': 3,
#  'select': 1,
#  'only': 5,
#  'òall': 1,
#  'lady': 1,
#  'not': 13,
#  'able': 1,
#  'discriminate': 1,
#  'at': 3,
#  'least': 2,
#  'favourable': 1,
#  'towards': 1,
#  'her': 1,
#  'claim': 1,
#  'all': 3,
#  'determined': 1,
#  'row': 1,
#  'column': 1,
#  'sums': 1,
#  'truth': 1,
#  'independent': 3,
#  'follows': 2,
#  'hypergeometric': 3,
#  'distribution': 5,
#  'xijx': 1,
#  'x': 34,
#  'margins': 1,
#  'tea-tasting': 1,
#  'assuming': 1,
#  'òchoose': 1,
#  'o': 1,
#  'chosen': 2,
#  'possible': 2,
#  'outcomes': 1,
#  'successes': 1,
#  'distributionh': 1,
#  'successselection': 1,
#  'combinations': 2,
#  'oooo': 1,
#  'ooox': 1,
#  'ooxo': 1,
#  'oxoo': 1,
#  'xooo': 1,
#  'ooxx': 1,
#  'oxox': 1,
#  'oxxo': 1,
#  'xoxo': 1,
#  'xxoo': 1,
#  'xoox': 1,
#  'oxxx': 1,
#  'xoxx': 1,
#  'xxox': 1,
#  'xxxo': 1,
#  'xxxx': 1,
#  'yatesõ': 1,
#  'continuity': 1,
#  'correction': 3,
#  'samples': 4,
#  'approximation': 1,
#  'quite': 1,
#  'clt': 1,
#  'yates': 3,
#  'may': 3,
#  'tend': 1,
#  'overcorrect': 1,
#  'type': 2,
#  'ii': 1,
#  'error': 2,
#  'i': 5,
#  'oi': 1,
#  'ei': 2,
#  'ad': 1,
#  'bc': 1,
#  'c': 8,
#  'd': 7,
#  'p-hackingyates': 1,
#  'p-hackingsigniþcance': 1,
#  'testing': 4,
#  'deþne': 2,
#  'stochastics': 1,
#  'formulate': 1,
#  't': 19,
#  'þx': 1,
#  'values': 2,
#  'under': 3,
#  'ònulló': 1,
#  'compare': 2,
#  'corresponds': 1,
#  'does': 2,
#  'make': 1,
#  'sense': 2,
#  'p-hackingasymptopia': 3,
#  'hackersfalse': 1,
#  'positives': 2,
#  'experimentn': 1,
#  'q_p': 3,
#  '-qnorm': 1,
#  'rep': 2,
#  'runif': 1,
#  'sqrt': 1,
#  'mean': 4,
#  'sd': 1,
#  'abs': 3,
#  'p_value': 2,
#  'pnorm': 1,
#  'print': 3,
#  'pch': 2,
#  'abline': 1,
#  'col': 2,
#  'blue': 1,
#  'crossing': 1,
#  'approaches': 1,
#  'npqp': 1,
#  'hackerssidekick': 2,
#  'edgeworth': 1,
#  'expansion': 2,
#  'studentized': 1,
#  'approximated': 2,
#  'normal': 2,
#  'cdf': 2,
#  'òresemblesó': 1,
#  'gaussian': 1,
#  'morefn': 1,
#  'fn': 1,
#  'figures': 2,
#  'p-p': 1,
#  'plots': 2,
#  'left': 2,
#  'right': 2,
#  'points': 2,
#  'above': 1,
#  'cornish-fisher': 1,
#  'quantile': 1,
#  'function': 3,
#  'q-q': 1,
#  'smaller': 1,
#  'valuethe': 1,
#  'p-hackingr-based': 1,
#  'experimentasymptopia': 1,
#  'hackersprobabilities': 1,
#  'uniform': 4,
#  'otherwise': 1,
#  'laplace': 1,
#  'student': 2,
#  'cauchy': 5,
#  'distributions': 2,
#  'given': 1,
#  'df': 2,
#  'probabilities': 2,
#  'converge': 1,
#  'variance': 1,
#  'undeþnedthe': 1,
#  'robber': 2,
#  'bank': 1,
#  'shoots': 1,
#  'u': 1,
#  'pi': 1,
#  'angles': 1,
#  'wall': 1,
#  'non': 1,
#  'trained': 1,
#  'cop': 2,
#  'calc': 1,
#  'bullet': 2,
#  'locations': 1,
#  'happy': 1,
#  'hits': 1,
#  'distributed': 1,
#  'pdf': 1,
#  'has': 1,
#  'moment': 1,
#  'distance': 1,
#  'angle': 1,
#  'follow': 1,
#  'relationship': 1,
#  'arctan': 1,
#  'xs': 1,
#  'hackerscauchythe': 1,
#  'extreme': 2,
#  'theory': 2,
#  'gumbel': 2,
#  'used': 1,
#  'estimate': 3,
#  'maxima': 1,
#  'minima': 1,
#  'convergence': 1,
#  'slownf': 1,
#  'exp': 5,
#  'library': 1,
#  'evd': 1,
#  'green': 1,
#  'x_c': 3,
#  'rnorm': 1,
#  'mu_n': 3,
#  'qnorm': 2,
#  'beta_n': 2,
#  'rgumbel': 1,
#  'sort': 2,
#  'steelblue': 1,
#  'lines': 1,
#  'hackersthe': 4,
#  'p-hackinguniform': 2,
#  'conþdence': 6,
#  'bands': 4,
#  'cb': 6,
#  'reßects': 1,
#  'uncertainty': 1,
#  'about': 2,
#  'curve': 7,
#  'intervals': 1,
#  'ci': 3,
#  'idem': 1,
#  'point': 1,
#  'covers': 2,
#  'narrower': 1,
#  'whole': 1,
#  'm': 6,
#  'broader': 2,
#  'coverage': 2,
#  '-m': 3,
#  'supx': 1,
#  'cont': 3,
#  'm-smoothers': 1,
#  'nonparametric': 2,
#  'estimators': 2,
#  'deþned': 1,
#  'zero': 1,
#  'denoting': 1,
#  'bounded': 2,
#  'monotone': 1,
#  'antisymmetric': 1,
#  'being': 4,
#  'suitable': 1,
#  'scaling': 1,
#  'parameters': 1,
#  'mn': 1,
#  'gn': 1,
#  'nhn': 1,
#  'xi': 1,
#  'hn': 1,
#  'yi': 1,
#  'dnp': 1,
#  'logn': 1,
#  'suptr': 1,
#  'dn': 1,
#  'p-hackingcb': 1,
#  'bootstrap': 5,
#  'precision': 1,
#  'improved': 1,
#  'asymptotic': 2,
#  'natural': 1,
#  'drawbacks': 1,
#  'þnite': 1,
#  'smoothed': 1,
#  'much': 2,
#  'lower': 1,
#  'hackerstheoretical': 1,
#  'signal': 1,
#  'robust': 1,
#  'tukey': 1,
#  'biweight': 1,
#  'dashed': 1,
#  'local': 1,
#  'polynomial': 1,
#  'band': 2,
#  'susan': 1,
#  'athey': 1,
#  'ciõs': 1,
#  'represented': 1,
#  'interpreted': 1,
#  'cbõs': 2,
#  'include': 1,
#  'insigniþcant': 2,
#  'existing': 1,
#  'framework': 1,
#  'compute': 1,
#  'cbõsmodern': 1,
#  'application': 1,
#  'generalized': 1,
#  'rfõsgrf-based': 1,
#  'treatment': 2,
#  'estimates': 1,
#  'pointwise': 1,
#  'mother': 1,
#  'works': 1,
#  'pay': 1,
#  'year': 1,
#  'after': 2,
#  'third': 1,
#  'childasymptopia': 1,
#  'hackersasymptopia': 1,
#  'p-hackingcritical': 4,
#  'examplesòit': 1,
#  'usual': 1,
#  'experimenters': 1,
#  'take': 1,
#  'per': 1,
#  'cent': 1,
#  'they': 1,
#  'ignore': 1,
#  'fail': 1,
#  'reach': 1,
#  'eliminate': 1,
#  'further': 1,
#  'discussion': 1,
#  'fisherp-value': 1,
#  'wetware': 1,
#  'survivalthe': 1,
#  'space': 1,
#  'shuttle': 1,
#  'challenger': 1,
#  'explosion': 1,
#  'o-ringthe': 1,
#  'ncov-': 1,
#  'controversy': 1,
#  'examplesdetails': 1,
#  'die': 2,
#  'welt': 1,
#  'details': 1,
#  'deutschlandfunk': 1,
#  'kultur': 1,
#  'model': 4,
#  'selectioncritical': 1,
#  'variable': 2,
#  'selection': 2,
#  'using': 1,
#  'bad': 1,
#  'idea': 1,
#  'included': 1,
#  'ones': 1,
#  'collinear': 1,
#  'correlation': 1,
#  'big': 1,
#  'important': 1,
#  'coefþcient': 1,
#  'eventually': 1,
#  'arbitrarily': 2,
#  'large': 1,
#  'p-valuen': 1,
#  'measurements': 2,
#  'getting': 1,
#  'some': 1,
#  'þddling': 1,
#  'testõs': 1,
#  'design': 1,
#  'males': 1,
#  'females': 1,
#  'þat': 1,
#  'cryptocurrency': 1,
#  'push': 1,
#  'examplespublishing': 1,
#  'exampleswhy': 1,
#  'most': 1,
#  'fine': 1,
#  'articles': 1,
#  'òsupportó': 1,
#  'stated': 1,
#  'õs': 3,
#  'better': 2,
#  'theories': 2,
#  'hypotheses': 1,
#  'empirical': 1,
#  'unlikely': 1,
#  'hard': 3,
#  'particle': 1,
#  'physics': 1,
#  'harking': 1,
#  'hypothesizing': 1,
#  'known': 1,
#  'manipulation': 1,
#  'interaction': 1,
#  'effects': 1,
#  'researcher': 1,
#  'un-': 1,
#  'willingly': 1,
#  'conþrmation': 1,
#  'bias': 1,
#  'interpretation': 2,
#  'handling': 1,
#  'lack': 1,
#  'replication': 1,
#  'transparency': 2,
#  'culture': 1,
#  'disclosure': 1,
#  'rarely': 1,
#  'requested': 1,
#  'top': 1,
#  'journalsthe': 1,
#  'examplesasa': 1,
#  'statement': 1,
#  'indicate': 1,
#  'problems': 1,
#  'speciþed': 1,
#  'good': 1,
#  'produced': 1,
#  'alone': 1,
#  'decisions': 1,
#  'full': 1,
#  'neededpthe': 1,
#  'p-hackingcorrect': 1,
#  'ògiven': 2,
#  'what': 2,
#  'trueó': 1,
#  'rather': 1,
#  'dataó': 1,
#  'example': 1,
#  'schizophrenia': 2,
#  'detection': 1,
#  'cases': 2,
#  'schizophrenic': 1,
#  'accuracy': 1,
#  'negatives': 1,
#  'performance': 2,
#  'worse': 1,
#  'would': 4,
#  'suggest': 1,
#  'examplesthe': 1,
#  'p-hackingòthe': 2,
#  'questionnaireó': 3,
#  'alter': 1,
#  'task': 1,
#  'means': 1,
#  't-test': 1,
#  'statements': 3,
#  'òtrueó': 1,
#  'òfalseó': 1,
#  'neither': 1,
#  'absolutely': 2,
#  'disproved': 1,
#  'null': 3,
#  'proved': 1,
#  'alternative': 2,
#  'deduce': 1,
#  'prob': 1,
#  'decides': 1,
#  'making': 1,
#  'wrong': 3,
#  'decision': 2,
#  'reliable': 1,
#  'þnding': 1,
#  'hypothetically': 1,
#  'repeated': 1,
#  'great': 1,
#  'number': 1,
#  'times': 1,
#  'you': 2,
#  'obtain': 1,
#  'occasions': 1,
#  'none': 1,
#  'correctn': 1,
#  'tests': 5,
#  'never': 2,
#  'prove': 1,
#  'disprove': 1,
#  'provide': 1,
#  'probabilistic': 1,
#  'corroborate': 1,
#  'generally': 1,
#  'impossible': 1,
#  'assign': 3,
#  'any': 2,
#  'applying': 1,
#  'other': 1,
#  'approach': 1,
#  'bayesian': 1,
#  'similar': 1,
#  'deþnition': 1,
#  'having': 1,
#  'rejected': 1,
#  'òmaking': 1,
#  'decisionó': 1,
#  'cannot': 1,
#  'derived': 1,
#  'nhst': 1,
#  'òreplication': 2,
#  'fallacyó': 2,
#  'hhh': 1,
#  'pp': 1,
#  'ph': 2,
#  'òthe': 2,
#  'interpret': 1,
#  'relative': 2,
#  'frequency': 2,
#  'rejections': 2,
#  'here': 1,
#  'òin': 1,
#  'minds': 1,
#  'many': 1,
#  'erroneously': 1,
#  'turned': 1,
#  'into': 2,
#  'replicatedó': 1,
#  'gigerenzer': 2,
#  'measures': 1,
#  'repeatable': 1,
#  'conditions': 1,
#  'describedó': 1,
#  'melton': 1,
#  'who': 1,
#  'made': 1,
#  'mistake': 1,
#  'comparison': 1,
#  'oakesõ': 1,
#  'original': 1,
#  'p-hackingfurther': 1,
#  'literature': 1,
#  'loftus': 2,
#  'tyranny': 1,
#  'sciences': 2,
#  'ƒber': 1,
#  'den': 1,
#  'mechanischen': 1,
#  'umgang': 1,
#  'mit': 1,
#  'statistischen': 1,
#  'methoden': 1,
#  'cohen': 1,
#  'earth': 1,
#  'round': 1,
#  'why': 1,
#  'psychology': 1,
#  'science': 2,
#  'until': 1,
#  'change': 1,
#  'way': 1,
#  'analyze': 1,
#  'dar': 1,
#  'serlin': 1,
#  'omer': 1,
#  'misuse': 1,
#  'three': 1,
#  'decades': 1,
#  'psychotherapy': 1,
#  'falk': 1,
#  'greenbaum': 1,
#  'p-hackingquantlets': 1,
#  'move': 1,
#  'q-able': 1,
#  'quantnet': 1,
#  'share': 1,
#  'programs': 1,
#  'easy': 2,
#  'collaboration': 1,
#  'seamless': 1,
#  'github': 1,
#  'integration': 1,
#  'boosting': 1,
#  'transparent': 1,
#  'reproducible': 1,
#  ...}

# %% [markdown]
# ## Creating the dataframe to sort the words
# Also deleting "-"'s that are thought as of words

# %%
import pandas as pd
import numpy as np

dictionary_words = dictionary.items()
dictionary_list = list(dictionary_words)

df_dictionary = pd.DataFrame(dictionary_list)
df_dictionary = df_dictionary.rename(columns={0:"word", 1:"occurance"})
df_dictionary = df_dictionary.drop(df_dictionary[df_dictionary.word == "-"].index)

df_dictionary.sort_values("occurance", ascending=False)
# Out:
#                 word  occurance
# 0                the        118
# 2                 of        117
# 1     attractiveness         49
# 194                n         41
# 10                 a         39
# ...              ...        ...
# 489             oooo          1
# 490             ooox          1
# 491             ooxo          1
# 492             oxoo          1
# 1098                          1
#
# [1098 rows x 2 columns]

# %% [markdown]
# ## Filtering the final dictionary
# Counting the number of letters in the words and setting a barrier for 0.75 percentile to be the cutoff for word counter

# %%
df_dictionary["lenght"] = df_dictionary["word"].apply(lambda x: len(x))
condition_lenght = df_dictionary["lenght"] > np.quantile(df_dictionary.occurance, 0.75)
condition_lenght
df_dictionary_filtered = df_dictionary[condition_lenght]
df_dictionary_filtered
# Out:
#                         word  occurance  lenght
# 0                        the        118       3
# 1             attractiveness         49      14
# 3     p-hackingmotivationdei          1      22
# 5         machinisunexpected          1      18
# 6                     powers          1       6
# ...                      ...        ...     ...
# 1093                     tie          1       3
# 1094                  straps          1       6
# 1095                inßuence          1       8
# 1096            multivariate          1      12
# 1097                analysis          1       8
#
# [1016 rows x 3 columns]

# %% [markdown]
# ## Exporting the JSON

# %%
file_export
df_dictionary_filtered.to_json(file_export)
